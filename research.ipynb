# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
from pathlib import Path

clear_data = Path("dataset_1937770_3.txt")
fixed_data = Path("dataset.csv")

with clear_data.open("r", encoding="utf-8-sig") as fin, fixed_data.open("w", encoding="utf-8") as fout:
    for i, line in enumerate(fin, 1):
        line = line.rstrip("\n\r")
        if i == 1:
            fout.write("id,text\n")
            continue
        if "," not in line:
            raise ValueError(f"Строка {i} без запятой: {line!r}")
        left, right = line.split(",", 1)
        right_escaped = right.replace('"', '""')
        fout.write(f'{left},"{right_escaped}"\n')

task_data = pd.read_csv("dataset.csv")

# %%
task_data.head()
# Out:
#    id                           text
# 0   0                куплюайфон14про
# 1   1             ищудомвПодмосковье
# 2   2  сдаюквартирусмебельюитехникой
# 3   3     новыйдивандоставканедорого
# 4   4                отдамдаромкошку

# %% [markdown]
# ## Обработка корпуса текста

# %%
# === ЭТАП 2. Настройки и импорты (Jupyter) ===

from pathlib import Path
import re
import html
import unicodedata
import json
import time
import random
from collections import Counter
import xml.etree.ElementTree as ET  # fallback по умолчанию

# Попытаться использовать быстрый парсер lxml, если установлен:
try:
    import lxml.etree as ET  # type: ignore
    PARSER_NAME = "lxml.etree"
except Exception:
    PARSER_NAME = "xml.etree.ElementTree"

print("XML parser:", PARSER_NAME)

# Пути
DATA_DIR = Path("ruwiki_dump")
XML_PATH = DATA_DIR / "ruwiki-latest-pages-meta-current.xml"   # РАСПАКОВАННЫЙ .xml
OUT_DIR = Path("prepared_corpus")
OUT_DIR.mkdir(parents=True, exist_ok=True)

TRAIN_PATH = OUT_DIR / "train.jsonl"
VAL_PATH = OUT_DIR / "val.jsonl"
UNIGRAM_PATH = OUT_DIR / "unigram_freq.tsv"

# Сплиты/лимиты/логи
SEED = 42
random.seed(SEED)

VAL_FRACTION = 0.05      # доля валидации
MAX_PAGES = None      # None = весь дамп; напр. 5000 для быстрого прогона
MAX_SENTENCES = 5_000_000      # None = все; напр. 100_000 для быстрого прогона
LOG_EVERY_PAGES = 100       # лог каждые N страниц
LOG_EVERY_SENTS = 5_000     # лог каждые N сохранённых предложений
STALL_SEC = 60        # watchdog: печать диагностики, если нет прогресса N секунд

# Фильтры длин
MIN_SENT_LEN = 10        # длина исходной строки (с пробелами)
MAX_SENT_LEN = 300
MIN_COMPACT_LEN = 5         # длина без пробелов
MAX_COMPACT_LEN = 180

assert XML_PATH.exists(
) and XML_PATH.suffix == ".xml", f"Нужен распакованный XML: {XML_PATH}"
print(f"XML size: {XML_PATH.stat().st_size/1e9:.2f} GB")
# Out:
# XML parser: xml.etree.ElementTree
# XML size: 41.11 GB

# %%
# === ЭТАП 2. Утилиты очистки и сегментации ===

def normalize_ws(text: str) -> str:
    text = html.unescape(text)
    text = text.replace("\u00A0", " ").replace(
        "\u202F", " ")  # NBSP/NNBSP -> space
    text = unicodedata.normalize("NFKC", text)
    text = re.sub(r"[ \t\f\v]+", " ", text)
    text = text.replace("\r\n", "\n").replace("\r", "\n")
    text = re.sub(r"\n{3,}", "\n\n", text)
    return text.strip()


# Регексы для грубой очистки вики-разметки
WIKI_LINK = re.compile(r"\[\[(?:[^|\]]+\|)?([^\]]+)\]\]")
WIKI_EXT = re.compile(r"\[https?://[^\s\]]+(?:\s+([^\]]+))?\]")
TAG_REF = re.compile(r"<ref[^>/]*?/?>.*?</ref>",
                     flags=re.IGNORECASE | re.DOTALL)
TAG_REF_SELF = re.compile(r"<ref[^>]*?/?>", flags=re.IGNORECASE)
HTML_TAGS = re.compile(r"</?(nowiki|math|code|syntaxhighlight|gallery|blockquote|poem|small|sup|sub|ref|br|hr)[^>]*?>",
                       flags=re.IGNORECASE)
HEADINGS = re.compile(r"^=+[^=]+=+$", flags=re.MULTILINE)
COMMENTS = re.compile(r"<!--.*?-->", flags=re.DOTALL)
TABLES = re.compile(r"\{\|.*?\|\}", flags=re.DOTALL)
CAT_FILES = re.compile(
    r"\[\[(Категория|Category|Файл|File|Изображение|Image):[^\]]+\]\]", flags=re.IGNORECASE)
TEMPL_RE = re.compile(r"\{\{[^{}]*\}\}")


def _strip_templates_fast(text: str) -> str:
    # Ускорение: максимум 2 прохода вместо «до стабилизации»
    for _ in range(2):
        new = TEMPL_RE.sub(" ", text)
        if new == text:
            break
        text = new
    return text


def strip_wiki_markup(text: str) -> str:
    text = COMMENTS.sub(" ", text)
    text = TAG_REF.sub(" ", text)
    text = TAG_REF_SELF.sub(" ", text)
    text = HTML_TAGS.sub(" ", text)
    text = CAT_FILES.sub(" ", text)
    text = TABLES.sub(" ", text)
    # ссылку [[...|текст]] -> текст; [[текст]] -> текст
    text = WIKI_LINK.sub(lambda m: m.group(1), text)
    # внешнюю [http... текст] -> текст (или пробел)
    text = WIKI_EXT.sub(lambda m: (m.group(1) or " "), text)
    text = HEADINGS.sub(" ", text)
    text = text.replace("'''", "").replace("''", "")
    text = _strip_templates_fast(text)
    return normalize_ws(text)


# Разделение на предложения
SENT_SPLIT = re.compile(r"(?<=[\.\!\?])\s+")


def split_sentences(text: str) -> list[str]:
    parts = []
    for para in text.split("\n"):
        para = para.strip()
        if not para:
            continue
        parts.extend(SENT_SPLIT.split(para))
    out = []
    for s in parts:
        s = s.strip()
        s = re.sub(r"^[\-\*\•\·]+", "", s).strip()
        if s:
            out.append(s)
    return out

# Построение пары (слитный текст + позиции пробелов)


def to_compact_and_boundaries(s: str) -> tuple[str, list[int]]:
    chars = []
    boundaries = []
    seen_space = False
    for ch in s:
        if ch.isspace():
            seen_space = True
            continue
        if seen_space and chars:
            boundaries.append(len(chars))
        chars.append(ch)
        seen_space = False
    return "".join(chars), boundaries


def tokenize_for_unigrams(s: str) -> list[str]:
    toks = []
    for t in s.split():
        t = t.strip(".,;:!?()[]{}«»\"'`~…/\\|+=*^<>")
        if not t:
            continue
        if 1 <= len(t) <= 30 and re.fullmatch(r"[A-Za-zА-Яа-яЁё0-9\-]+", t):
            toks.append(t.lower())
    return toks

# %%
# === ЭТАП 2. Namespace-агностичный итератор по страницам (ns == 0) ===

def _local(tag: str) -> str:
    """Локальное имя тега без {namespace} префикса."""
    return tag.split('}', 1)[-1] if '}' in tag else tag


def _child_text(elem, name: str) -> str:
    for ch in elem:
        if _local(ch.tag) == name:
            return ch.text or ""
    return ""


def _find_child(elem, name: str):
    for ch in elem:
        if _local(ch.tag) == name:
            return ch
    return None


def iter_wiki_pages_anyns(xml_path: Path):
    """
    Генерирует (title, text) для страниц ns==0, не завися от версии export-0.xx.
    """
    context = ET.iterparse(str(xml_path), events=("end",))
    for event, elem in context:
        if _local(elem.tag) == "page":
            if _child_text(elem, "ns") == "0":
                title = _child_text(elem, "title")
                rev = _find_child(elem, "revision")
                text = _child_text(rev, "text") if rev is not None else ""
                yield title, (text or "")
            elem.clear()


# Быстрая проверка на 2 страницы:
cnt = 0
for t, tx in iter_wiki_pages_anyns(XML_PATH):
    print("sample title:", (t or "")[:80], "| text_len:", len(tx))
    cnt += 1
    if cnt >= 2:
        break
print("iter_wiki_pages_anyns OK, first pages seen:", cnt)
# Out:
# sample title: Базовая статья | text_len: 32
# sample title: Литва | text_len: 115278
# iter_wiki_pages_anyns OK, first pages seen: 2

# %%
# === ЭТАП 2. Построение корпуса с прогрессом и watchdog ===

def build_corpus_with_progress(
    xml_path: Path,
    train_path: Path,
    val_path: Path,
    unigram_path: Path,
    max_pages=MAX_PAGES,
    max_sentences=MAX_SENTENCES,
    val_fraction=VAL_FRACTION,
):
    for p in [train_path, val_path, unigram_path]:
        if p.exists():
            p.unlink()

    rng = random.Random(SEED)
    uni = Counter()
    pages = 0
    sents_seen = 0
    sents_kept = 0
    sents_filtered_len = 0
    sents_no_spaces = 0

    t0 = time.time()
    t_last = t0
    kept_last = 0
    last_title = None
    last_raw_preview = None

    with train_path.open("w", encoding="utf-8") as f_train, \
            val_path.open("w", encoding="utf-8") as f_val:

        for title, raw in iter_wiki_pages_anyns(xml_path):
            pages += 1
            last_title = title
            last_raw_preview = (raw[:400] if raw else "").replace("\n", " ")

            cleaned = strip_wiki_markup(raw)
            if cleaned:
                for s in split_sentences(cleaned):
                    sents_seen += 1

                    if not (MIN_SENT_LEN <= len(s) <= MAX_SENT_LEN):
                        sents_filtered_len += 1
                        continue

                    text_no_spaces, boundaries = to_compact_and_boundaries(s)
                    if not (MIN_COMPACT_LEN <= len(text_no_spaces) <= MAX_COMPACT_LEN):
                        sents_filtered_len += 1
                        continue
                    if len(boundaries) == 0:
                        sents_no_spaces += 1
                        continue

                    rec = {"text_no_spaces": text_no_spaces,
                           "boundaries": boundaries}
                    if rng.random() < val_fraction:
                        f_val.write(json.dumps(rec, ensure_ascii=False) + "\n")
                    else:
                        f_train.write(json.dumps(
                            rec, ensure_ascii=False) + "\n")

                    uni.update(tokenize_for_unigrams(s))
                    sents_kept += 1

                    # Логи по предложениям
                    if LOG_EVERY_SENTS and (sents_kept % LOG_EVERY_SENTS == 0):
                        now = time.time()
                        speed = (sents_kept - kept_last) / \
                            max(1e-9, (now - t_last))
                        print(f"[SENTS] kept={sents_kept:,} seen={sents_seen:,} "
                              f"filtered_len={sents_filtered_len:,} no_space={sents_no_spaces:,} "
                              f"| ~{speed:.1f} kept/s | elapsed={now - t0:.1f}s",
                              flush=True)
                        kept_last = sents_kept
                        t_last = now

                    # Watchdog: долго нет роста kept
                    if (time.time() - t_last) > STALL_SEC:
                        print("\n[WATCHDOG] Нет роста kept > "
                              f"{STALL_SEC}s. Последняя страница:\n"
                              f"  title: {last_title!r}\n"
                              f"  raw[:400]: {last_raw_preview}\n", flush=True)
                        t_last = time.time()

                    if max_sentences and sents_kept >= max_sentences:
                        break

            if LOG_EVERY_PAGES and (pages % LOG_EVERY_PAGES == 0):
                print(
                    f"[PAGES] pages={pages:,} | kept={sents_kept:,} | seen={sents_seen:,}", flush=True)

            if max_pages and pages >= max_pages:
                break
            if max_sentences and sents_kept >= max_sentences:
                break

    with unigram_path.open("w", encoding="utf-8") as f_uni:
        for w, c in uni.most_common():
            f_uni.write(f"{w}\t{c}\n")

    print("=== ИТОГО ===")
    print(f"Страниц обработано: {pages:,}")
    print(f"Предложений рассмотрено: {sents_seen:,}")
    print(f"Сохранено (train+val): {sents_kept:,}")
    print(f"Отсеяно по длине: {sents_filtered_len:,}")
    print(f"Без пробелов (нет меток): {sents_no_spaces:,}")
    print(
        f"Train строк: {sum(1 for _ in train_path.open('r', encoding='utf-8')):,}")
    print(
        f"Val   строк: {sum(1 for _ in val_path.open('r', encoding='utf-8')):,}")
    print(
        f"Уникальных униграмм: {sum(1 for _ in unigram_path.open('r', encoding='utf-8')):,}")
    print(f"Время (факт): {time.time() - t0:.1f} s")


# Запуск построения корпуса (при необходимости поставьте лимиты MAX_PAGES / MAX_SENTENCES)
build_corpus_with_progress(
    XML_PATH,
    TRAIN_PATH,
    VAL_PATH,
    UNIGRAM_PATH,
    max_pages=MAX_PAGES,
    max_sentences=MAX_SENTENCES,
    val_fraction=VAL_FRACTION,
)
# Out:
# [SENTS] kept=5,000 seen=7,036 filtered_len=1,955 no_space=81 | ~37104.7 kept/s | elapsed=0.1s
# [SENTS] kept=10,000 seen=13,994 filtered_len=3,858 no_space=136 | ~37889.6 kept/s | elapsed=0.3s
# [SENTS] kept=15,000 seen=20,269 filtered_len=5,048 no_space=221 | ~43157.1 kept/s | elapsed=0.4s
# [SENTS] kept=20,000 seen=26,329 filtered_len=6,061 no_space=268 | ~46386.9 kept/s | elapsed=0.5s
# [SENTS] kept=25,000 seen=32,486 filtered_len=7,145 no_space=341 | ~38096.1 kept/s | elapsed=0.6s
# [PAGES] pages=100 | kept=26,223 | seen=34,009
# [SENTS] kept=30,000 seen=38,654 filtered_len=8,220 no_space=434 | ~39197.5 kept/s | elapsed=0.7s
# [PAGES] pages=200 | kept=33,328 | seen=42,956
# [SENTS] kept=35,000 seen=45,078 filtered_len=9,558 no_space=520 | ~37805.5 kept/s | elapsed=0.9s
# [PAGES] pages=300 | kept=39,547 | seen=51,016
# [SENTS] kept=40,000 seen=51,574 filtered_len=10,950 no_space=624 | ~38286.5 kept/s | elapsed=1.0s
# [SENTS] kept=45,000 seen=57,827 filtered_len=12,148 no_space=679 | ~38351.8 kept/s | elapsed=1.1s
# [SENTS] kept=50,000 seen=64,266 filtered_len=13,494 no_space=772 | ~41455.6 kept/s | elapsed=1.3s
# [PAGES] pages=400 | kept=50,382 | seen=64,699
# [SENTS] kept=55,000 seen=70,118 filtered_len=14,304 no_space=814 | ~49533.8 kept/s | elapsed=1.4s
# [SENTS] kept=60,000 seen=76,227 filtered_len=15,350 no_space=877 | ~50317.0 kept/s | elapsed=1.5s
# [SENTS] kept=65,000 seen=82,287 filtered_len=16,353 no_space=934 | ~39442.8 kept/s | elapsed=1.6s
# [PAGES] pages=500 | kept=66,169 | seen=83,752
# [SENTS] kept=70,000 seen=88,479 filtered_len=17,452 no_space=1,027 | ~46147.1 kept/s | elapsed=1.7s
# [SENTS] kept=75,000 seen=94,653 filtered_len=18,521 no_space=1,132 | ~40587.7 kept/s | elapsed=1.8s
# [PAGES] pages=600 | kept=76,899 | seen=97,288
# [SENTS] kept=80,000 seen=101,050 filtered_len=19,829 no_space=1,221 | ~42318.4 kept/s | elapsed=1.9s
# [SENTS] kept=85,000 seen=107,445 filtered_len=21,142 no_space=1,303 | ~41173.3 kept/s | elapsed=2.1s
# [SENTS] kept=90,000 seen=113,919 filtered_len=22,521 no_space=1,398 | ~46970.5 kept/s | elapsed=2.2s
# [PAGES] pages=700 | kept=91,475 | seen=115,829
# [SENTS] kept=95,000 seen=120,258 filtered_len=23,732 no_space=1,526 | ~48555.9 kept/s | elapsed=2.3s
# [SENTS] kept=100,000 seen=126,253 filtered_len=24,691 no_space=1,562 | ~40267.7 kept/s | elapsed=2.4s
# [SENTS] kept=105,000 seen=133,758 filtered_len=27,065 no_space=1,693 | ~47231.3 kept/s | elapsed=2.5s
# [SENTS] kept=110,000 seen=141,240 filtered_len=29,379 no_space=1,861 | ~49058.0 kept/s | elapsed=2.6s
# [PAGES] pages=800 | kept=113,017 | seen=145,577
# [SENTS] kept=115,000 seen=148,098 filtered_len=31,146 no_space=1,952 | ~50715.5 kept/s | elapsed=2.7s
# [SENTS] kept=120,000 seen=153,882 filtered_len=31,911 no_space=1,971 | ~56670.7 kept/s | elapsed=2.8s
# [PAGES] pages=900 | kept=124,006 | seen=159,037
# [SENTS] kept=125,000 seen=160,261 filtered_len=33,273 no_space=1,988 | ~52362.2 kept/s | elapsed=2.9s
# [SENTS] kept=130,000 seen=166,367 filtered_len=34,270 no_space=2,097 | ~53299.7 kept/s | elapsed=3.0s
# [SENTS] kept=135,000 seen=171,870 filtered_len=34,744 no_space=2,126 | ~66437.3 kept/s | elapsed=3.1s
# [SENTS] kept=140,000 seen=178,452 filtered_len=36,241 no_space=2,211 | ~41352.0 kept/s | elapsed=3.2s
# [PAGES] pages=1,000 | kept=142,644 | seen=181,493
# [SENTS] kept=145,000 seen=184,220 filtered_len=36,977 no_space=2,243 | ~44554.2 kept/s | elapsed=3.3s
# [SENTS] kept=150,000 seen=190,483 filtered_len=38,154 no_space=2,329 | ~41747.0 kept/s | elapsed=3.4s
# [PAGES] pages=1,100 | kept=151,836 | seen=192,745
# [SENTS] kept=155,000 seen=196,812 filtered_len=39,412 no_space=2,400 | ~40572.5 kept/s | elapsed=3.5s
# [SENTS] kept=160,000 seen=202,820 filtered_len=40,380 no_space=2,440 | ~40689.6 kept/s | elapsed=3.7s
# [PAGES] pages=1,200 | kept=164,386 | seen=208,208
# [SENTS] kept=165,000 seen=208,966 filtered_len=41,478 no_space=2,488 | ~45765.3 kept/s | elapsed=3.8s
# [SENTS] kept=170,000 seen=215,224 filtered_len=42,631 no_space=2,593 | ~41338.0 kept/s | elapsed=3.9s
# [SENTS] kept=175,000 seen=221,324 filtered_len=43,639 no_space=2,685 | ~46050.7 kept/s | elapsed=4.0s
# [SENTS] kept=180,000 seen=228,530 filtered_len=45,693 no_space=2,837 | ~44320.4 kept/s | elapsed=4.1s
# [PAGES] pages=1,300 | kept=180,840 | seen=229,576
# [SENTS] kept=185,000 seen=235,301 filtered_len=47,393 no_space=2,908 | ~48367.1 kept/s | elapsed=4.2s
# [SENTS] kept=190,000 seen=241,350 filtered_len=48,427 no_space=2,923 | ~52161.7 kept/s | elapsed=4.3s
# [SENTS] kept=195,000 seen=247,534 filtered_len=49,585 no_space=2,949 | ~52246.6 kept/s | elapsed=4.4s
# [SENTS] kept=200,000 seen=253,728 filtered_len=50,745 no_space=2,983 | ~50611.8 kept/s | elapsed=4.5s
# [SENTS] kept=205,000 seen=260,062 filtered_len=52,039 no_space=3,023 | ~44457.8 kept/s | elapsed=4.6s
# [PAGES] pages=1,400 | kept=205,032 | seen=260,131
# [SENTS] kept=210,000 seen=265,977 filtered_len=52,897 no_space=3,080 | ~45159.9 kept/s | elapsed=4.7s
# [SENTS] kept=215,000 seen=272,204 filtered_len=54,057 no_space=3,147 | ~42195.1 kept/s | elapsed=4.8s
# [SENTS] kept=220,000 seen=278,181 filtered_len=55,000 no_space=3,181 | ~43163.4 kept/s | elapsed=5.0s
# [SENTS] kept=225,000 seen=284,077 filtered_len=55,867 no_space=3,210 | ~42374.3 kept/s | elapsed=5.1s
# [PAGES] pages=1,500 | kept=225,525 | seen=284,891
# [SENTS] kept=230,000 seen=290,801 filtered_len=57,502 no_space=3,299 | ~43915.1 kept/s | elapsed=5.2s
# [SENTS] kept=235,000 seen=297,147 filtered_len=58,780 no_space=3,367 | ~45177.4 kept/s | elapsed=5.3s
# [SENTS] kept=240,000 seen=304,049 filtered_len=60,591 no_space=3,458 | ~39588.8 kept/s | elapsed=5.4s
# [PAGES] pages=1,600 | kept=242,160 | seen=306,707
# [SENTS] kept=245,000 seen=310,712 filtered_len=62,164 no_space=3,548 | ~46715.0 kept/s | elapsed=5.5s
# [SENTS] kept=250,000 seen=318,254 filtered_len=64,573 no_space=3,681 | ~50273.6 kept/s | elapsed=5.6s
# [PAGES] pages=1,700 | kept=254,004 | seen=323,505
# [SENTS] kept=255,000 seen=324,894 filtered_len=66,193 no_space=3,701 | ~52546.4 kept/s | elapsed=5.7s
# [SENTS] kept=260,000 seen=331,481 filtered_len=67,745 no_space=3,736 | ~49985.5 kept/s | elapsed=5.8s
# [PAGES] pages=1,800 | kept=261,278 | seen=333,167
# [SENTS] kept=265,000 seen=337,971 filtered_len=69,166 no_space=3,805 | ~65544.8 kept/s | elapsed=5.9s
# [SENTS] kept=270,000 seen=344,311 filtered_len=70,432 no_space=3,879 | ~45213.1 kept/s | elapsed=6.0s
# [PAGES] pages=1,900 | kept=270,003 | seen=344,314
# [SENTS] kept=275,000 seen=351,191 filtered_len=72,129 no_space=4,062 | ~42849.0 kept/s | elapsed=6.1s
# [PAGES] pages=2,000 | kept=279,454 | seen=357,019
# [SENTS] kept=280,000 seen=357,700 filtered_len=73,535 no_space=4,165 | ~50375.7 kept/s | elapsed=6.2s
# [SENTS] kept=285,000 seen=363,944 filtered_len=74,726 no_space=4,218 | ~49329.5 kept/s | elapsed=6.3s
# [PAGES] pages=2,100 | kept=286,258 | seen=365,503
# [SENTS] kept=290,000 seen=370,167 filtered_len=75,872 no_space=4,295 | ~42536.9 kept/s | elapsed=6.4s
# [SENTS] kept=295,000 seen=376,467 filtered_len=77,034 no_space=4,433 | ~45484.8 kept/s | elapsed=6.6s
# [PAGES] pages=2,200 | kept=295,554 | seen=377,112
# [PAGES] pages=2,300 | kept=297,497 | seen=379,605
# [SENTS] kept=300,000 seen=382,733 filtered_len=78,158 no_space=4,575 | ~43037.0 kept/s | elapsed=6.7s
# [SENTS] kept=305,000 seen=388,975 filtered_len=79,298 no_space=4,677 | ~46062.7 kept/s | elapsed=6.8s
# [PAGES] pages=2,400 | kept=307,064 | seen=391,676
# [SENTS] kept=310,000 seen=395,820 filtered_len=81,044 no_space=4,776 | ~48184.8 kept/s | elapsed=6.9s
# [SENTS] kept=315,000 seen=401,947 filtered_len=82,058 no_space=4,889 | ~50885.0 kept/s | elapsed=7.0s
# [PAGES] pages=2,500 | kept=316,434 | seen=403,714
# [SENTS] kept=320,000 seen=407,830 filtered_len=82,915 no_space=4,915 | ~50682.2 kept/s | elapsed=7.1s
# [SENTS] kept=325,000 seen=413,803 filtered_len=83,846 no_space=4,957 | ~46890.1 kept/s | elapsed=7.2s
# [PAGES] pages=2,600 | kept=325,367 | seen=414,261
# [SENTS] kept=330,000 seen=420,417 filtered_len=85,389 no_space=5,028 | ~44259.2 kept/s | elapsed=7.3s
# [PAGES] pages=2,700 | kept=333,267 | seen=424,185
# [SENTS] kept=335,000 seen=426,153 filtered_len=86,078 no_space=5,075 | ~56989.2 kept/s | elapsed=7.4s
# [SENTS] kept=340,000 seen=431,661 filtered_len=86,571 no_space=5,090 | ~76687.0 kept/s | elapsed=7.5s
# [SENTS] kept=345,000 seen=437,232 filtered_len=87,131 no_space=5,101 | ~77965.4 kept/s | elapsed=7.5s
# [SENTS] kept=350,000 seen=442,761 filtered_len=87,648 no_space=5,113 | ~74093.8 kept/s | elapsed=7.6s
# [PAGES] pages=2,800 | kept=352,682 | seen=445,705
# [SENTS] kept=355,000 seen=448,265 filtered_len=88,146 no_space=5,119 | ~79668.7 kept/s | elapsed=7.7s
# [SENTS] kept=360,000 seen=453,689 filtered_len=88,560 no_space=5,129 | ~75266.0 kept/s | elapsed=7.7s
# [SENTS] kept=365,000 seen=459,162 filtered_len=89,021 no_space=5,141 | ~78451.0 kept/s | elapsed=7.8s
# [SENTS] kept=370,000 seen=464,723 filtered_len=89,560 no_space=5,163 | ~69724.5 kept/s | elapsed=7.9s
# [SENTS] kept=375,000 seen=470,211 filtered_len=90,018 no_space=5,193 | ~67802.9 kept/s | elapsed=7.9s
# [SENTS] kept=380,000 seen=475,711 filtered_len=90,490 no_space=5,221 | ~76498.2 kept/s | elapsed=8.0s
# [PAGES] pages=2,900 | kept=381,048 | seen=476,863
# [SENTS] kept=385,000 seen=481,239 filtered_len=90,991 no_space=5,248 | ~75617.7 kept/s | elapsed=8.1s
# [SENTS] kept=390,000 seen=486,765 filtered_len=91,490 no_space=5,275 | ~80236.3 kept/s | elapsed=8.1s
# [SENTS] kept=395,000 seen=492,184 filtered_len=91,890 no_space=5,294 | ~74887.1 kept/s | elapsed=8.2s
# [SENTS] kept=400,000 seen=497,622 filtered_len=92,317 no_space=5,305 | ~77238.0 kept/s | elapsed=8.3s
# [SENTS] kept=405,000 seen=503,072 filtered_len=92,754 no_space=5,318 | ~79818.8 kept/s | elapsed=8.3s
# [PAGES] pages=3,000 | kept=409,723 | seen=508,223
# [SENTS] kept=410,000 seen=508,520 filtered_len=93,194 no_space=5,326 | ~79588.6 kept/s | elapsed=8.4s
# [SENTS] kept=415,000 seen=513,940 filtered_len=93,600 no_space=5,340 | ~80296.8 kept/s | elapsed=8.4s
# [SENTS] kept=420,000 seen=519,370 filtered_len=94,016 no_space=5,354 | ~82015.5 kept/s | elapsed=8.5s
# [PAGES] pages=3,100 | kept=424,713 | seen=525,037
# [SENTS] kept=425,000 seen=525,393 filtered_len=94,996 no_space=5,397 | ~48508.9 kept/s | elapsed=8.6s
# [SENTS] kept=430,000 seen=531,562 filtered_len=96,046 no_space=5,516 | ~48781.4 kept/s | elapsed=8.7s
# [PAGES] pages=3,200 | kept=433,272 | seen=535,448
# [SENTS] kept=435,000 seen=537,383 filtered_len=96,814 no_space=5,569 | ~52182.9 kept/s | elapsed=8.8s
# [PAGES] pages=3,300 | kept=438,377 | seen=541,467
# [SENTS] kept=440,000 seen=543,350 filtered_len=97,765 no_space=5,585 | ~47184.0 kept/s | elapsed=8.9s
# [PAGES] pages=3,400 | kept=442,258 | seen=546,045
# [SENTS] kept=445,000 seen=549,282 filtered_len=98,652 no_space=5,630 | ~58392.9 kept/s | elapsed=9.0s
# [PAGES] pages=3,500 | kept=445,310 | seen=549,637
# [SENTS] kept=450,000 seen=555,419 filtered_len=99,704 no_space=5,715 | ~51063.0 kept/s | elapsed=9.1s
# [PAGES] pages=3,600 | kept=450,042 | seen=555,467
# [PAGES] pages=3,700 | kept=452,528 | seen=558,323
# [SENTS] kept=455,000 seen=561,290 filtered_len=100,519 no_space=5,771 | ~47846.4 kept/s | elapsed=9.2s
# [PAGES] pages=3,800 | kept=458,231 | seen=565,221
# [SENTS] kept=460,000 seen=567,495 filtered_len=101,635 no_space=5,860 | ~53232.9 kept/s | elapsed=9.3s
# [PAGES] pages=3,900 | kept=463,016 | seen=571,286
# [PAGES] pages=4,000 | kept=464,791 | seen=573,255
# [SENTS] kept=465,000 seen=573,491 filtered_len=102,608 no_space=5,883 | ~65028.8 kept/s | elapsed=9.4s
# [PAGES] pages=4,100 | kept=467,357 | seen=576,295
# [PAGES] pages=4,200 | kept=468,931 | seen=577,932
# [SENTS] kept=470,000 seen=579,093 filtered_len=103,162 no_space=5,931 | ~72383.0 kept/s | elapsed=9.4s
# [PAGES] pages=4,300 | kept=470,633 | seen=579,813
# [PAGES] pages=4,400 | kept=471,772 | seen=581,078
# [PAGES] pages=4,500 | kept=473,501 | seen=583,091
# [SENTS] kept=475,000 seen=585,001 filtered_len=104,017 no_space=5,984 | ~53331.7 kept/s | elapsed=9.5s
# [SENTS] kept=480,000 seen=591,452 filtered_len=105,341 no_space=6,111 | ~46676.6 kept/s | elapsed=9.6s
# [PAGES] pages=4,600 | kept=482,324 | seen=594,478
# [SENTS] kept=485,000 seen=597,855 filtered_len=106,596 no_space=6,259 | ~45479.7 kept/s | elapsed=9.7s
# [SENTS] kept=490,000 seen=604,651 filtered_len=108,289 no_space=6,362 | ~42899.7 kept/s | elapsed=9.9s
# [SENTS] kept=495,000 seen=611,366 filtered_len=109,747 no_space=6,619 | ~41063.4 kept/s | elapsed=10.0s
# [PAGES] pages=4,700 | kept=495,715 | seen=612,448
# [SENTS] kept=500,000 seen=618,146 filtered_len=111,449 no_space=6,697 | ~41749.5 kept/s | elapsed=10.1s
# [PAGES] pages=4,800 | kept=503,752 | seen=623,225
# [SENTS] kept=505,000 seen=624,703 filtered_len=112,936 no_space=6,767 | ~47150.6 kept/s | elapsed=10.2s
# [PAGES] pages=4,900 | kept=509,067 | seen=629,852
# [SENTS] kept=510,000 seen=631,046 filtered_len=114,156 no_space=6,890 | ~41569.4 kept/s | elapsed=10.3s
# [SENTS] kept=515,000 seen=638,784 filtered_len=116,817 no_space=6,967 | ~39788.0 kept/s | elapsed=10.5s
# [PAGES] pages=5,000 | kept=517,496 | seen=642,007
# [SENTS] kept=520,000 seen=645,282 filtered_len=118,227 no_space=7,055 | ~43524.7 kept/s | elapsed=10.6s
# [PAGES] pages=5,100 | kept=523,985 | seen=650,326
# [SENTS] kept=525,000 seen=651,656 filtered_len=119,517 no_space=7,139 | ~42016.1 kept/s | elapsed=10.7s
# [SENTS] kept=530,000 seen=658,171 filtered_len=120,864 no_space=7,307 | ~42242.6 kept/s | elapsed=10.8s
# [PAGES] pages=5,200 | kept=530,999 | seen=659,374
# [SENTS] kept=535,000 seen=664,341 filtered_len=121,892 no_space=7,449 | ~39945.6 kept/s | elapsed=10.9s
# [SENTS] kept=540,000 seen=670,945 filtered_len=123,363 no_space=7,582 | ~40888.1 kept/s | elapsed=11.1s
# [PAGES] pages=5,300 | kept=540,221 | seen=671,204
# [SENTS] kept=545,000 seen=677,033 filtered_len=124,369 no_space=7,664 | ~40553.4 kept/s | elapsed=11.2s
# [PAGES] pages=5,400 | kept=546,229 | seen=678,403
# [SENTS] kept=550,000 seen=682,748 filtered_len=125,050 no_space=7,698 | ~47006.7 kept/s | elapsed=11.3s
# [PAGES] pages=5,500 | kept=553,689 | seen=687,214
# [SENTS] kept=555,000 seen=688,796 filtered_len=126,030 no_space=7,766 | ~45779.1 kept/s | elapsed=11.4s
# [SENTS] kept=560,000 seen=695,045 filtered_len=127,204 no_space=7,841 | ~44660.7 kept/s | elapsed=11.5s
# [PAGES] pages=5,600 | kept=564,813 | seen=701,105
# [SENTS] kept=565,000 seen=701,334 filtered_len=128,428 no_space=7,906 | ~42517.8 kept/s | elapsed=11.6s
# [SENTS] kept=570,000 seen=707,526 filtered_len=129,518 no_space=8,008 | ~42307.6 kept/s | elapsed=11.7s
# [PAGES] pages=5,700 | kept=574,296 | seen=712,581
# [SENTS] kept=575,000 seen=713,458 filtered_len=130,393 no_space=8,065 | ~42865.4 kept/s | elapsed=11.9s
# [SENTS] kept=580,000 seen=719,334 filtered_len=131,217 no_space=8,117 | ~45802.6 kept/s | elapsed=12.0s
# [PAGES] pages=5,800 | kept=584,785 | seen=725,691
# [SENTS] kept=585,000 seen=725,962 filtered_len=132,715 no_space=8,247 | ~52915.2 kept/s | elapsed=12.1s
# [SENTS] kept=590,000 seen=732,082 filtered_len=133,767 no_space=8,315 | ~41339.3 kept/s | elapsed=12.2s
# [PAGES] pages=5,900 | kept=591,808 | seen=734,158
# [SENTS] kept=595,000 seen=738,167 filtered_len=134,788 no_space=8,379 | ~42050.8 kept/s | elapsed=12.3s
# [SENTS] kept=600,000 seen=744,645 filtered_len=136,180 no_space=8,465 | ~46156.1 kept/s | elapsed=12.4s
# [PAGES] pages=6,000 | kept=602,776 | seen=748,665
# [SENTS] kept=605,000 seen=751,379 filtered_len=137,769 no_space=8,610 | ~47892.2 kept/s | elapsed=12.5s
# [SENTS] kept=610,000 seen=757,553 filtered_len=138,848 no_space=8,705 | ~44087.5 kept/s | elapsed=12.6s
# [PAGES] pages=6,100 | kept=611,210 | seen=759,177
# [SENTS] kept=615,000 seen=763,894 filtered_len=140,093 no_space=8,801 | ~42600.6 kept/s | elapsed=12.7s
# [PAGES] pages=6,200 | kept=619,999 | seen=770,319
# [SENTS] kept=620,000 seen=770,320 filtered_len=141,429 no_space=8,891 | ~44995.2 kept/s | elapsed=12.9s
# [SENTS] kept=625,000 seen=776,889 filtered_len=142,898 no_space=8,991 | ~48933.1 kept/s | elapsed=13.0s
# [SENTS] kept=630,000 seen=783,185 filtered_len=144,101 no_space=9,084 | ~42446.4 kept/s | elapsed=13.1s
# [PAGES] pages=6,300 | kept=630,917 | seen=784,298
# [SENTS] kept=635,000 seen=789,466 filtered_len=145,316 no_space=9,150 | ~41222.8 kept/s | elapsed=13.2s
# [PAGES] pages=6,400 | kept=638,040 | seen=793,310
# [SENTS] kept=640,000 seen=795,619 filtered_len=146,405 no_space=9,214 | ~39469.5 kept/s | elapsed=13.3s
# [SENTS] kept=645,000 seen=801,924 filtered_len=147,665 no_space=9,259 | ~40016.3 kept/s | elapsed=13.5s
# [PAGES] pages=6,500 | kept=648,491 | seen=806,638
# [SENTS] kept=650,000 seen=808,571 filtered_len=149,224 no_space=9,347 | ~40072.2 kept/s | elapsed=13.6s
# [SENTS] kept=655,000 seen=814,565 filtered_len=150,138 no_space=9,427 | ~43414.4 kept/s | elapsed=13.7s
# [PAGES] pages=6,600 | kept=656,752 | seen=816,893
# [SENTS] kept=660,000 seen=821,039 filtered_len=151,495 no_space=9,544 | ~39795.4 kept/s | elapsed=13.8s
# [SENTS] kept=665,000 seen=827,307 filtered_len=152,635 no_space=9,672 | ~43333.5 kept/s | elapsed=13.9s
# [PAGES] pages=6,700 | kept=666,778 | seen=829,661
# [SENTS] kept=670,000 seen=833,609 filtered_len=153,809 no_space=9,800 | ~41851.5 kept/s | elapsed=14.1s
# [SENTS] kept=675,000 seen=839,959 filtered_len=155,079 no_space=9,880 | ~45099.5 kept/s | elapsed=14.2s
# [PAGES] pages=6,800 | kept=675,943 | seen=841,054
# [SENTS] kept=680,000 seen=846,104 filtered_len=156,166 no_space=9,938 | ~39053.4 kept/s | elapsed=14.3s
# [SENTS] kept=685,000 seen=852,476 filtered_len=157,447 no_space=10,029 | ~50876.1 kept/s | elapsed=14.4s
# [PAGES] pages=6,900 | kept=685,421 | seen=853,026
# [SENTS] kept=690,000 seen=859,098 filtered_len=159,003 no_space=10,095 | ~39491.3 kept/s | elapsed=14.5s
# [PAGES] pages=7,000 | kept=694,869 | seen=865,180
# [SENTS] kept=695,000 seen=865,350 filtered_len=160,177 no_space=10,173 | ~45417.0 kept/s | elapsed=14.6s
# [SENTS] kept=700,000 seen=871,520 filtered_len=161,252 no_space=10,268 | ~42849.3 kept/s | elapsed=14.7s
# [PAGES] pages=7,100 | kept=701,365 | seen=873,341
# [SENTS] kept=705,000 seen=877,874 filtered_len=162,504 no_space=10,370 | ~45945.3 kept/s | elapsed=14.8s
# [SENTS] kept=710,000 seen=884,739 filtered_len=164,278 no_space=10,461 | ~45405.0 kept/s | elapsed=15.0s
# [PAGES] pages=7,200 | kept=710,286 | seen=885,079
# [SENTS] kept=715,000 seen=891,010 filtered_len=165,444 no_space=10,566 | ~41540.7 kept/s | elapsed=15.1s
# [SENTS] kept=720,000 seen=897,305 filtered_len=166,629 no_space=10,676 | ~47610.4 kept/s | elapsed=15.2s
# [PAGES] pages=7,300 | kept=720,408 | seen=898,217
# [SENTS] kept=725,000 seen=904,259 filtered_len=168,409 no_space=10,850 | ~45959.3 kept/s | elapsed=15.3s
# [SENTS] kept=730,000 seen=910,673 filtered_len=169,739 no_space=10,934 | ~48210.8 kept/s | elapsed=15.4s
# [PAGES] pages=7,400 | kept=730,650 | seen=911,443
# [SENTS] kept=735,000 seen=916,555 filtered_len=170,576 no_space=10,979 | ~42602.1 kept/s | elapsed=15.5s
# [SENTS] kept=740,000 seen=923,119 filtered_len=172,020 no_space=11,099 | ~47529.5 kept/s | elapsed=15.6s
# [PAGES] pages=7,500 | kept=741,096 | seen=924,493
# [SENTS] kept=745,000 seen=929,161 filtered_len=173,009 no_space=11,152 | ~42371.5 kept/s | elapsed=15.7s
# [PAGES] pages=7,600 | kept=747,314 | seen=932,065
# [SENTS] kept=750,000 seen=935,476 filtered_len=174,233 no_space=11,243 | ~43502.1 kept/s | elapsed=15.9s
# [SENTS] kept=755,000 seen=942,043 filtered_len=175,694 no_space=11,349 | ~46555.0 kept/s | elapsed=16.0s
# [PAGES] pages=7,700 | kept=756,033 | seen=943,729
# [SENTS] kept=760,000 seen=948,666 filtered_len=177,219 no_space=11,447 | ~44749.9 kept/s | elapsed=16.1s
# [PAGES] pages=7,800 | kept=763,526 | seen=953,830
# [SENTS] kept=765,000 seen=955,815 filtered_len=179,148 no_space=11,667 | ~50625.8 kept/s | elapsed=16.2s
# [PAGES] pages=7,900 | kept=769,173 | seen=961,050
# [SENTS] kept=770,000 seen=962,090 filtered_len=180,353 no_space=11,737 | ~45390.1 kept/s | elapsed=16.3s
# [SENTS] kept=775,000 seen=968,310 filtered_len=181,477 no_space=11,833 | ~49280.1 kept/s | elapsed=16.4s
# [PAGES] pages=8,000 | kept=776,230 | seen=969,762
# [SENTS] kept=780,000 seen=974,460 filtered_len=182,551 no_space=11,909 | ~46391.6 kept/s | elapsed=16.5s
# [SENTS] kept=785,000 seen=980,870 filtered_len=183,882 no_space=11,988 | ~47723.5 kept/s | elapsed=16.6s
# [SENTS] kept=790,000 seen=993,628 filtered_len=190,247 no_space=13,381 | ~45827.1 kept/s | elapsed=16.7s
# [PAGES] pages=8,100 | kept=793,899 | seen=1,003,775
# [SENTS] kept=795,000 seen=1,005,111 filtered_len=195,646 no_space=14,465 | ~48615.9 kept/s | elapsed=16.8s
# [SENTS] kept=800,000 seen=1,011,299 filtered_len=196,785 no_space=14,514 | ~37412.5 kept/s | elapsed=16.9s
# [PAGES] pages=8,200 | kept=803,389 | seen=1,015,057
# [SENTS] kept=805,000 seen=1,016,756 filtered_len=197,201 no_space=14,555 | ~67202.6 kept/s | elapsed=17.0s
# [PAGES] pages=8,300 | kept=806,163 | seen=1,017,988
# [SENTS] kept=810,000 seen=1,022,575 filtered_len=197,969 no_space=14,606 | ~47965.8 kept/s | elapsed=17.1s
# [PAGES] pages=8,400 | kept=811,979 | seen=1,025,040
# [SENTS] kept=815,000 seen=1,028,714 filtered_len=198,987 no_space=14,727 | ~50777.8 kept/s | elapsed=17.2s
# [SENTS] kept=820,000 seen=1,035,208 filtered_len=200,393 no_space=14,815 | ~48388.7 kept/s | elapsed=17.3s
# [SENTS] kept=825,000 seen=1,041,541 filtered_len=201,663 no_space=14,878 | ~45318.3 kept/s | elapsed=17.4s
# [PAGES] pages=8,500 | kept=825,555 | seen=1,042,321
# [SENTS] kept=830,000 seen=1,047,488 filtered_len=202,511 no_space=14,977 | ~43531.6 kept/s | elapsed=17.5s
# [SENTS] kept=835,000 seen=1,054,220 filtered_len=204,124 no_space=15,096 | ~52157.7 kept/s | elapsed=17.6s
# [PAGES] pages=8,600 | kept=835,697 | seen=1,055,174
# [SENTS] kept=840,000 seen=1,060,245 filtered_len=205,030 no_space=15,215 | ~45713.5 kept/s | elapsed=17.8s
# [PAGES] pages=8,700 | kept=843,292 | seen=1,064,415
# [SENTS] kept=845,000 seen=1,066,840 filtered_len=206,548 no_space=15,292 | ~44428.3 kept/s | elapsed=17.9s
# [SENTS] kept=850,000 seen=1,073,162 filtered_len=207,804 no_space=15,358 | ~44713.9 kept/s | elapsed=18.0s
# [PAGES] pages=8,800 | kept=850,400 | seen=1,073,848
# [SENTS] kept=855,000 seen=1,079,558 filtered_len=209,102 no_space=15,456 | ~47828.2 kept/s | elapsed=18.1s
# [PAGES] pages=8,900 | kept=856,371 | seen=1,081,212
# [SENTS] kept=860,000 seen=1,086,130 filtered_len=210,559 no_space=15,571 | ~43399.7 kept/s | elapsed=18.2s
# [PAGES] pages=9,000 | kept=863,850 | seen=1,090,994
# [SENTS] kept=865,000 seen=1,092,482 filtered_len=211,846 no_space=15,636 | ~46151.1 kept/s | elapsed=18.3s
# [SENTS] kept=870,000 seen=1,098,750 filtered_len=213,003 no_space=15,747 | ~47834.0 kept/s | elapsed=18.4s
# [PAGES] pages=9,100 | kept=873,936 | seen=1,103,694
# [SENTS] kept=875,000 seen=1,104,978 filtered_len=214,178 no_space=15,800 | ~41791.7 kept/s | elapsed=18.5s
# [SENTS] kept=880,000 seen=1,111,456 filtered_len=215,533 no_space=15,923 | ~47660.4 kept/s | elapsed=18.6s
# [PAGES] pages=9,200 | kept=883,635 | seen=1,116,014
# [SENTS] kept=885,000 seen=1,117,693 filtered_len=216,701 no_space=15,992 | ~40671.6 kept/s | elapsed=18.8s
# [PAGES] pages=9,300 | kept=887,260 | seen=1,120,450
# [SENTS] kept=890,000 seen=1,123,747 filtered_len=217,718 no_space=16,029 | ~38987.9 kept/s | elapsed=18.9s
# [PAGES] pages=9,400 | kept=890,154 | seen=1,123,938
# [PAGES] pages=9,500 | kept=893,184 | seen=1,127,650
# [SENTS] kept=895,000 seen=1,129,871 filtered_len=218,750 no_space=16,121 | ~43629.7 kept/s | elapsed=19.0s
# [SENTS] kept=900,000 seen=1,136,269 filtered_len=219,973 no_space=16,296 | ~46114.4 kept/s | elapsed=19.1s
# [PAGES] pages=9,600 | kept=900,226 | seen=1,136,541
# [SENTS] kept=905,000 seen=1,142,567 filtered_len=221,157 no_space=16,410 | ~45312.8 kept/s | elapsed=19.2s
# [PAGES] pages=9,700 | kept=907,470 | seen=1,145,568
# [SENTS] kept=910,000 seen=1,148,690 filtered_len=222,198 no_space=16,492 | ~49925.7 kept/s | elapsed=19.3s
# [SENTS] kept=915,000 seen=1,155,514 filtered_len=223,953 no_space=16,561 | ~47225.5 kept/s | elapsed=19.4s
# [PAGES] pages=9,800 | kept=917,850 | seen=1,159,323
# [SENTS] kept=920,000 seen=1,161,846 filtered_len=225,202 no_space=16,644 | ~45400.1 kept/s | elapsed=19.5s
# [SENTS] kept=925,000 seen=1,168,215 filtered_len=226,490 no_space=16,725 | ~45810.1 kept/s | elapsed=19.6s
# [PAGES] pages=9,900 | kept=925,194 | seen=1,168,449
# [SENTS] kept=930,000 seen=1,174,685 filtered_len=227,843 no_space=16,842 | ~41438.7 kept/s | elapsed=19.8s
# [PAGES] pages=10,000 | kept=930,465 | seen=1,175,357
# [SENTS] kept=935,000 seen=1,181,106 filtered_len=229,188 no_space=16,918 | ~42792.1 kept/s | elapsed=19.9s
# [PAGES] pages=10,100 | kept=937,045 | seen=1,183,819
# [SENTS] kept=940,000 seen=1,187,380 filtered_len=230,372 no_space=17,008 | ~44228.7 kept/s | elapsed=20.0s
# [PAGES] pages=10,200 | kept=943,927 | seen=1,192,519
# [SENTS] kept=945,000 seen=1,193,804 filtered_len=231,746 no_space=17,058 | ~44755.9 kept/s | elapsed=20.1s
# [PAGES] pages=10,300 | kept=947,741 | seen=1,197,168
# [SENTS] kept=950,000 seen=1,200,059 filtered_len=232,965 no_space=17,094 | ~50880.3 kept/s | elapsed=20.2s
# [PAGES] pages=10,400 | kept=952,613 | seen=1,203,367
# [SENTS] kept=955,000 seen=1,206,201 filtered_len=234,028 no_space=17,173 | ~42399.9 kept/s | elapsed=20.3s
# [PAGES] pages=10,500 | kept=959,926 | seen=1,212,379
# [SENTS] kept=960,000 seen=1,212,461 filtered_len=235,223 no_space=17,238 | ~41888.3 kept/s | elapsed=20.4s
# [SENTS] kept=965,000 seen=1,219,106 filtered_len=236,761 no_space=17,345 | ~45971.8 kept/s | elapsed=20.5s
# [PAGES] pages=10,600 | kept=966,875 | seen=1,221,482
# [SENTS] kept=970,000 seen=1,225,244 filtered_len=237,765 no_space=17,479 | ~42079.5 kept/s | elapsed=20.7s
# [PAGES] pages=10,700 | kept=973,742 | seen=1,230,052
# [SENTS] kept=975,000 seen=1,231,653 filtered_len=239,004 no_space=17,649 | ~49686.9 kept/s | elapsed=20.8s
# [SENTS] kept=980,000 seen=1,237,771 filtered_len=240,037 no_space=17,734 | ~52070.3 kept/s | elapsed=20.9s
# [PAGES] pages=10,800 | kept=982,841 | seen=1,241,229
# [SENTS] kept=985,000 seen=1,244,069 filtered_len=241,262 no_space=17,807 | ~45753.6 kept/s | elapsed=21.0s
# [SENTS] kept=990,000 seen=1,251,038 filtered_len=243,121 no_space=17,917 | ~41797.3 kept/s | elapsed=21.1s
# [PAGES] pages=10,900 | kept=991,609 | seen=1,253,165
# [SENTS] kept=995,000 seen=1,257,213 filtered_len=244,220 no_space=17,993 | ~44043.9 kept/s | elapsed=21.2s
# [PAGES] pages=11,000 | kept=998,778 | seen=1,261,905
# [SENTS] kept=1,000,000 seen=1,263,350 filtered_len=245,292 no_space=18,058 | ~40335.9 kept/s | elapsed=21.3s
# [SENTS] kept=1,005,000 seen=1,269,391 filtered_len=246,277 no_space=18,114 | ~43907.0 kept/s | elapsed=21.4s
# [PAGES] pages=11,100 | kept=1,006,970 | seen=1,271,841
# [SENTS] kept=1,010,000 seen=1,275,808 filtered_len=247,619 no_space=18,189 | ~47207.3 kept/s | elapsed=21.6s
# [SENTS] kept=1,015,000 seen=1,282,388 filtered_len=249,110 no_space=18,278 | ~42872.1 kept/s | elapsed=21.7s
# [PAGES] pages=11,200 | kept=1,017,047 | seen=1,285,003
# [SENTS] kept=1,020,000 seen=1,290,549 filtered_len=251,823 no_space=18,726 | ~56540.6 kept/s | elapsed=21.8s
# [SENTS] kept=1,025,000 seen=1,299,831 filtered_len=255,496 no_space=19,335 | ~35409.5 kept/s | elapsed=21.9s
# [PAGES] pages=11,300 | kept=1,028,562 | seen=1,304,687
# [SENTS] kept=1,030,000 seen=1,306,399 filtered_len=256,918 no_space=19,481 | ~46468.8 kept/s | elapsed=22.0s
# [SENTS] kept=1,035,000 seen=1,312,751 filtered_len=258,185 no_space=19,566 | ~45078.0 kept/s | elapsed=22.1s
# [PAGES] pages=11,400 | kept=1,038,284 | seen=1,316,630
# [SENTS] kept=1,040,000 seen=1,318,614 filtered_len=258,974 no_space=19,640 | ~51225.8 kept/s | elapsed=22.2s
# [SENTS] kept=1,045,000 seen=1,325,180 filtered_len=260,429 no_space=19,751 | ~43405.8 kept/s | elapsed=22.3s
# [PAGES] pages=11,500 | kept=1,047,916 | seen=1,328,968
# [SENTS] kept=1,050,000 seen=1,331,479 filtered_len=261,649 no_space=19,830 | ~44035.8 kept/s | elapsed=22.4s
# [SENTS] kept=1,055,000 seen=1,337,663 filtered_len=262,704 no_space=19,959 | ~46197.9 kept/s | elapsed=22.6s
# [PAGES] pages=11,600 | kept=1,055,462 | seen=1,338,218
# [SENTS] kept=1,060,000 seen=1,343,791 filtered_len=263,715 no_space=20,076 | ~45642.6 kept/s | elapsed=22.7s
# [PAGES] pages=11,700 | kept=1,062,602 | seen=1,347,007
# [SENTS] kept=1,065,000 seen=1,349,830 filtered_len=264,663 no_space=20,167 | ~43943.2 kept/s | elapsed=22.8s
# [SENTS] kept=1,070,000 seen=1,356,360 filtered_len=265,979 no_space=20,381 | ~46733.8 kept/s | elapsed=22.9s
# [PAGES] pages=11,800 | kept=1,073,928 | seen=1,361,147
# [SENTS] kept=1,075,000 seen=1,362,488 filtered_len=267,012 no_space=20,476 | ~47347.1 kept/s | elapsed=23.0s
# [SENTS] kept=1,080,000 seen=1,368,883 filtered_len=268,355 no_space=20,528 | ~49006.1 kept/s | elapsed=23.1s
# [PAGES] pages=11,900 | kept=1,082,648 | seen=1,372,248
# [SENTS] kept=1,085,000 seen=1,375,150 filtered_len=269,530 no_space=20,620 | ~35986.0 kept/s | elapsed=23.2s
# [SENTS] kept=1,090,000 seen=1,381,617 filtered_len=270,912 no_space=20,705 | ~45647.1 kept/s | elapsed=23.3s
# [PAGES] pages=12,000 | kept=1,090,449 | seen=1,382,189
# [SENTS] kept=1,095,000 seen=1,387,949 filtered_len=272,154 no_space=20,795 | ~44522.8 kept/s | elapsed=23.4s
# [PAGES] pages=12,100 | kept=1,099,482 | seen=1,393,543
# [SENTS] kept=1,100,000 seen=1,394,180 filtered_len=273,331 no_space=20,849 | ~44791.3 kept/s | elapsed=23.6s
# [SENTS] kept=1,105,000 seen=1,400,932 filtered_len=274,991 no_space=20,941 | ~38482.5 kept/s | elapsed=23.7s
# [PAGES] pages=12,200 | kept=1,106,790 | seen=1,403,128
# [SENTS] kept=1,110,000 seen=1,407,156 filtered_len=276,138 no_space=21,018 | ~46880.2 kept/s | elapsed=23.8s
# [SENTS] kept=1,115,000 seen=1,413,592 filtered_len=277,469 no_space=21,123 | ~44880.6 kept/s | elapsed=23.9s
# [PAGES] pages=12,300 | kept=1,115,438 | seen=1,414,169
# [SENTS] kept=1,120,000 seen=1,420,261 filtered_len=279,056 no_space=21,205 | ~42705.1 kept/s | elapsed=24.0s
# [PAGES] pages=12,400 | kept=1,121,126 | seen=1,421,777
# [SENTS] kept=1,125,000 seen=1,426,650 filtered_len=280,346 no_space=21,304 | ~45167.1 kept/s | elapsed=24.1s
# [PAGES] pages=12,500 | kept=1,129,863 | seen=1,432,903
# [SENTS] kept=1,130,000 seen=1,433,066 filtered_len=281,659 no_space=21,407 | ~45614.7 kept/s | elapsed=24.2s
# [SENTS] kept=1,135,000 seen=1,439,484 filtered_len=282,992 no_space=21,492 | ~43494.1 kept/s | elapsed=24.4s
# [PAGES] pages=12,600 | kept=1,137,875 | seen=1,443,104
# [SENTS] kept=1,140,000 seen=1,445,782 filtered_len=284,136 no_space=21,646 | ~44888.9 kept/s | elapsed=24.5s
# [SENTS] kept=1,145,000 seen=1,452,093 filtered_len=285,382 no_space=21,711 | ~42279.8 kept/s | elapsed=24.6s
# [PAGES] pages=12,700 | kept=1,146,124 | seen=1,453,458
# [SENTS] kept=1,150,000 seen=1,458,282 filtered_len=286,478 no_space=21,804 | ~43812.0 kept/s | elapsed=24.7s
# [PAGES] pages=12,800 | kept=1,154,556 | seen=1,464,120
# [SENTS] kept=1,155,000 seen=1,464,703 filtered_len=287,816 no_space=21,887 | ~41953.7 kept/s | elapsed=24.8s
# [SENTS] kept=1,160,000 seen=1,471,129 filtered_len=289,173 no_space=21,956 | ~38067.7 kept/s | elapsed=25.0s
# [PAGES] pages=12,900 | kept=1,163,096 | seen=1,475,026
# [SENTS] kept=1,165,000 seen=1,477,449 filtered_len=290,429 no_space=22,020 | ~39775.1 kept/s | elapsed=25.1s
# [SENTS] kept=1,170,000 seen=1,483,863 filtered_len=291,761 no_space=22,102 | ~44491.1 kept/s | elapsed=25.2s
# [PAGES] pages=13,000 | kept=1,171,726 | seen=1,486,059
# [SENTS] kept=1,175,000 seen=1,489,868 filtered_len=292,675 no_space=22,193 | ~46477.4 kept/s | elapsed=25.3s
# [SENTS] kept=1,180,000 seen=1,495,601 filtered_len=293,343 no_space=22,258 | ~45494.3 kept/s | elapsed=25.4s
# [SENTS] kept=1,185,000 seen=1,501,875 filtered_len=294,552 no_space=22,323 | ~41629.2 kept/s | elapsed=25.5s
# [PAGES] pages=13,100 | kept=1,185,336 | seen=1,502,364
# [SENTS] kept=1,190,000 seen=1,508,400 filtered_len=295,998 no_space=22,402 | ~42628.9 kept/s | elapsed=25.6s
# [PAGES] pages=13,200 | kept=1,194,561 | seen=1,514,749
# [SENTS] kept=1,195,000 seen=1,515,343 filtered_len=297,864 no_space=22,479 | ~46597.1 kept/s | elapsed=25.8s
# [SENTS] kept=1,200,000 seen=1,521,641 filtered_len=299,045 no_space=22,596 | ~40978.9 kept/s | elapsed=25.9s
# [PAGES] pages=13,300 | kept=1,200,945 | seen=1,522,763
# [SENTS] kept=1,205,000 seen=1,527,767 filtered_len=300,083 no_space=22,684 | ~46381.4 kept/s | elapsed=26.0s
# [PAGES] pages=13,400 | kept=1,208,887 | seen=1,533,036
# [SENTS] kept=1,210,000 seen=1,534,527 filtered_len=301,768 no_space=22,759 | ~41447.7 kept/s | elapsed=26.1s
# [SENTS] kept=1,215,000 seen=1,540,541 filtered_len=302,703 no_space=22,838 | ~44276.8 kept/s | elapsed=26.2s
# [PAGES] pages=13,500 | kept=1,216,585 | seen=1,542,440
# [SENTS] kept=1,220,000 seen=1,546,734 filtered_len=303,832 no_space=22,902 | ~45397.6 kept/s | elapsed=26.3s
# [PAGES] pages=13,600 | kept=1,224,408 | seen=1,552,342
# [SENTS] kept=1,225,000 seen=1,553,125 filtered_len=305,137 no_space=22,988 | ~44230.5 kept/s | elapsed=26.4s
# [SENTS] kept=1,230,000 seen=1,559,723 filtered_len=306,575 no_space=23,148 | ~47217.1 kept/s | elapsed=26.5s
# [PAGES] pages=13,700 | kept=1,230,997 | seen=1,560,878
# [SENTS] kept=1,235,000 seen=1,565,899 filtered_len=307,697 no_space=23,202 | ~37952.1 kept/s | elapsed=26.7s
# [PAGES] pages=13,800 | kept=1,238,188 | seen=1,569,878
# [SENTS] kept=1,240,000 seen=1,572,032 filtered_len=308,758 no_space=23,274 | ~45917.9 kept/s | elapsed=26.8s
# [PAGES] pages=13,900 | kept=1,244,037 | seen=1,577,069
# [SENTS] kept=1,245,000 seen=1,578,313 filtered_len=309,978 no_space=23,335 | ~42869.2 kept/s | elapsed=26.9s
# [SENTS] kept=1,250,000 seen=1,584,576 filtered_len=311,160 no_space=23,416 | ~51044.8 kept/s | elapsed=27.0s
# [PAGES] pages=14,000 | kept=1,251,439 | seen=1,586,467
# [SENTS] kept=1,255,000 seen=1,590,949 filtered_len=312,460 no_space=23,489 | ~38023.1 kept/s | elapsed=27.1s
# [PAGES] pages=14,100 | kept=1,258,941 | seen=1,595,800
# [SENTS] kept=1,260,000 seen=1,597,166 filtered_len=313,589 no_space=23,577 | ~42853.4 kept/s | elapsed=27.3s
# [SENTS] kept=1,265,000 seen=1,603,178 filtered_len=314,513 no_space=23,665 | ~49081.6 kept/s | elapsed=27.4s
# [PAGES] pages=14,200 | kept=1,266,496 | seen=1,605,011
# [SENTS] kept=1,270,000 seen=1,609,728 filtered_len=315,986 no_space=23,742 | ~44947.5 kept/s | elapsed=27.5s
# [PAGES] pages=14,300 | kept=1,272,269 | seen=1,612,829
# [SENTS] kept=1,275,000 seen=1,616,353 filtered_len=317,523 no_space=23,830 | ~45454.1 kept/s | elapsed=27.6s
# [PAGES] pages=14,400 | kept=1,277,445 | seen=1,619,881
# [SENTS] kept=1,280,000 seen=1,623,368 filtered_len=319,437 no_space=23,931 | ~48617.3 kept/s | elapsed=27.7s
# [PAGES] pages=14,500 | kept=1,283,069 | seen=1,627,151
# [SENTS] kept=1,285,000 seen=1,629,543 filtered_len=320,543 no_space=24,000 | ~43761.0 kept/s | elapsed=27.8s
# [SENTS] kept=1,290,000 seen=1,635,906 filtered_len=321,807 no_space=24,099 | ~46618.3 kept/s | elapsed=27.9s
# [PAGES] pages=14,600 | kept=1,292,024 | seen=1,638,364
# [SENTS] kept=1,295,000 seen=1,642,162 filtered_len=322,950 no_space=24,212 | ~49138.0 kept/s | elapsed=28.0s
# [SENTS] kept=1,300,000 seen=1,648,589 filtered_len=324,260 no_space=24,329 | ~45625.5 kept/s | elapsed=28.1s
# [PAGES] pages=14,700 | kept=1,300,923 | seen=1,649,773
# [SENTS] kept=1,305,000 seen=1,654,826 filtered_len=325,414 no_space=24,412 | ~45635.9 kept/s | elapsed=28.2s
# [PAGES] pages=14,800 | kept=1,308,571 | seen=1,659,640
# [SENTS] kept=1,310,000 seen=1,661,553 filtered_len=327,038 no_space=24,515 | ~47028.7 kept/s | elapsed=28.3s
# [SENTS] kept=1,315,000 seen=1,668,879 filtered_len=329,241 no_space=24,638 | ~48028.0 kept/s | elapsed=28.4s
# [PAGES] pages=14,900 | kept=1,316,198 | seen=1,670,388
# [SENTS] kept=1,320,000 seen=1,675,468 filtered_len=330,752 no_space=24,716 | ~44578.7 kept/s | elapsed=28.5s
# [PAGES] pages=15,000 | kept=1,323,871 | seen=1,680,684
# [SENTS] kept=1,325,000 seen=1,682,134 filtered_len=332,297 no_space=24,837 | ~44117.0 kept/s | elapsed=28.7s
# [SENTS] kept=1,330,000 seen=1,688,733 filtered_len=333,757 no_space=24,976 | ~47502.3 kept/s | elapsed=28.8s
# [PAGES] pages=15,100 | kept=1,332,040 | seen=1,691,380
# [SENTS] kept=1,335,000 seen=1,695,302 filtered_len=335,227 no_space=25,075 | ~45328.3 kept/s | elapsed=28.9s
# [PAGES] pages=15,200 | kept=1,337,460 | seen=1,698,685
# [SENTS] kept=1,340,000 seen=1,702,452 filtered_len=337,207 no_space=25,245 | ~47512.3 kept/s | elapsed=29.0s
# [SENTS] kept=1,345,000 seen=1,708,575 filtered_len=338,257 no_space=25,318 | ~51459.9 kept/s | elapsed=29.1s
# [PAGES] pages=15,300 | kept=1,347,271 | seen=1,711,498
# [SENTS] kept=1,350,000 seen=1,714,916 filtered_len=339,500 no_space=25,416 | ~42655.9 kept/s | elapsed=29.2s
# [PAGES] pages=15,400 | kept=1,353,243 | seen=1,719,354
# [SENTS] kept=1,355,000 seen=1,721,628 filtered_len=341,094 no_space=25,534 | ~47381.2 kept/s | elapsed=29.3s
# [SENTS] kept=1,360,000 seen=1,728,132 filtered_len=342,523 no_space=25,609 | ~48353.7 kept/s | elapsed=29.4s
# [PAGES] pages=15,500 | kept=1,361,927 | seen=1,730,728
# [SENTS] kept=1,365,000 seen=1,734,904 filtered_len=344,205 no_space=25,699 | ~43057.4 kept/s | elapsed=29.5s
# [PAGES] pages=15,600 | kept=1,369,376 | seen=1,740,865
# [SENTS] kept=1,370,000 seen=1,741,580 filtered_len=345,810 no_space=25,770 | ~43694.0 kept/s | elapsed=29.6s
# [PAGES] pages=15,700 | kept=1,374,576 | seen=1,747,416
# [SENTS] kept=1,375,000 seen=1,747,980 filtered_len=347,124 no_space=25,856 | ~43670.1 kept/s | elapsed=29.7s
# [SENTS] kept=1,380,000 seen=1,754,590 filtered_len=348,563 no_space=26,027 | ~48460.9 kept/s | elapsed=29.8s
# [PAGES] pages=15,800 | kept=1,380,584 | seen=1,755,312
# [SENTS] kept=1,385,000 seen=1,760,658 filtered_len=349,575 no_space=26,083 | ~42502.2 kept/s | elapsed=30.0s
# [SENTS] kept=1,390,000 seen=1,766,753 filtered_len=350,594 no_space=26,159 | ~47731.6 kept/s | elapsed=30.1s
# [PAGES] pages=15,900 | kept=1,390,123 | seen=1,766,899
# [SENTS] kept=1,395,000 seen=1,773,158 filtered_len=351,827 no_space=26,331 | ~45675.6 kept/s | elapsed=30.2s
# [PAGES] pages=16,000 | kept=1,396,072 | seen=1,774,491
# [SENTS] kept=1,400,000 seen=1,779,503 filtered_len=353,064 no_space=26,439 | ~44619.3 kept/s | elapsed=30.3s
# [PAGES] pages=16,100 | kept=1,401,773 | seen=1,781,704
# [PAGES] pages=16,200 | kept=1,404,461 | seen=1,785,034
# [SENTS] kept=1,405,000 seen=1,785,689 filtered_len=354,163 no_space=26,526 | ~43490.4 kept/s | elapsed=30.4s
# [SENTS] kept=1,410,000 seen=1,792,302 filtered_len=355,653 no_space=26,649 | ~50096.6 kept/s | elapsed=30.5s
# [PAGES] pages=16,300 | kept=1,411,018 | seen=1,793,512
# [SENTS] kept=1,415,000 seen=1,798,641 filtered_len=356,932 no_space=26,709 | ~42046.6 kept/s | elapsed=30.6s
# [SENTS] kept=1,420,000 seen=1,805,556 filtered_len=358,770 no_space=26,786 | ~42331.2 kept/s | elapsed=30.7s
# [PAGES] pages=16,400 | kept=1,420,193 | seen=1,805,880
# [SENTS] kept=1,425,000 seen=1,811,856 filtered_len=359,997 no_space=26,859 | ~45459.1 kept/s | elapsed=30.9s
# [PAGES] pages=16,500 | kept=1,426,043 | seen=1,813,263
# [SENTS] kept=1,430,000 seen=1,818,449 filtered_len=361,490 no_space=26,959 | ~42944.2 kept/s | elapsed=31.0s
# [PAGES] pages=16,600 | kept=1,433,217 | seen=1,822,335
# [SENTS] kept=1,435,000 seen=1,824,591 filtered_len=362,552 no_space=27,039 | ~45190.8 kept/s | elapsed=31.1s
# [PAGES] pages=16,700 | kept=1,438,754 | seen=1,829,275
# [SENTS] kept=1,440,000 seen=1,830,870 filtered_len=363,736 no_space=27,134 | ~46006.2 kept/s | elapsed=31.2s
# [PAGES] pages=16,800 | kept=1,444,218 | seen=1,836,000
# [SENTS] kept=1,445,000 seen=1,836,985 filtered_len=364,790 no_space=27,195 | ~45913.3 kept/s | elapsed=31.3s
# [SENTS] kept=1,450,000 seen=1,843,279 filtered_len=365,989 no_space=27,290 | ~45028.8 kept/s | elapsed=31.4s
# [PAGES] pages=16,900 | kept=1,452,030 | seen=1,845,705
# [SENTS] kept=1,455,000 seen=1,849,543 filtered_len=367,170 no_space=27,373 | ~46967.7 kept/s | elapsed=31.5s
# [SENTS] kept=1,460,000 seen=1,855,713 filtered_len=368,263 no_space=27,450 | ~51144.6 kept/s | elapsed=31.6s
# [PAGES] pages=17,000 | kept=1,462,121 | seen=1,858,349
# [SENTS] kept=1,465,000 seen=1,861,845 filtered_len=369,329 no_space=27,516 | ~37700.3 kept/s | elapsed=31.7s
# [SENTS] kept=1,470,000 seen=1,868,203 filtered_len=370,579 no_space=27,624 | ~45123.0 kept/s | elapsed=31.9s
# [PAGES] pages=17,100 | kept=1,471,142 | seen=1,869,674
# [SENTS] kept=1,475,000 seen=1,874,774 filtered_len=372,084 no_space=27,690 | ~42899.7 kept/s | elapsed=32.0s
# [PAGES] pages=17,200 | kept=1,477,257 | seen=1,878,079
# [SENTS] kept=1,480,000 seen=1,881,724 filtered_len=373,889 no_space=27,835 | ~46258.6 kept/s | elapsed=32.1s
# [SENTS] kept=1,485,000 seen=1,888,166 filtered_len=375,265 no_space=27,901 | ~45191.7 kept/s | elapsed=32.2s
# [PAGES] pages=17,300 | kept=1,485,315 | seen=1,888,535
# [PAGES] pages=17,400 | kept=1,487,654 | seen=1,891,492
# [PAGES] pages=17,500 | kept=1,489,631 | seen=1,893,701
# [SENTS] kept=1,490,000 seen=1,894,096 filtered_len=376,165 no_space=27,931 | ~60337.5 kept/s | elapsed=32.3s
# [PAGES] pages=17,600 | kept=1,493,189 | seen=1,897,849
# [PAGES] pages=17,700 | kept=1,494,814 | seen=1,899,682
# [SENTS] kept=1,495,000 seen=1,899,888 filtered_len=376,914 no_space=27,974 | ~55341.7 kept/s | elapsed=32.4s
# [PAGES] pages=17,800 | kept=1,497,186 | seen=1,902,251
# [PAGES] pages=17,900 | kept=1,499,157 | seen=1,904,333
# [SENTS] kept=1,500,000 seen=1,905,217 filtered_len=377,235 no_space=27,982 | ~55469.8 kept/s | elapsed=32.5s
# [PAGES] pages=18,000 | kept=1,500,237 | seen=1,905,509
# [PAGES] pages=18,100 | kept=1,504,745 | seen=1,911,260
# [SENTS] kept=1,505,000 seen=1,911,584 filtered_len=378,491 no_space=28,093 | ~41370.6 kept/s | elapsed=32.6s
# [SENTS] kept=1,510,000 seen=1,918,236 filtered_len=380,041 no_space=28,195 | ~48226.1 kept/s | elapsed=32.7s
# [PAGES] pages=18,200 | kept=1,513,217 | seen=1,922,327
# [SENTS] kept=1,515,000 seen=1,924,491 filtered_len=381,218 no_space=28,273 | ~40451.4 kept/s | elapsed=32.8s
# [PAGES] pages=18,300 | kept=1,519,294 | seen=1,930,064
# [SENTS] kept=1,520,000 seen=1,930,973 filtered_len=382,595 no_space=28,378 | ~41857.5 kept/s | elapsed=32.9s
# [PAGES] pages=18,400 | kept=1,523,639 | seen=1,935,594
# [SENTS] kept=1,525,000 seen=1,937,155 filtered_len=383,677 no_space=28,478 | ~43241.0 kept/s | elapsed=33.0s
# [PAGES] pages=18,500 | kept=1,529,263 | seen=1,942,665
# [SENTS] kept=1,530,000 seen=1,943,575 filtered_len=384,980 no_space=28,595 | ~48325.5 kept/s | elapsed=33.1s
# [SENTS] kept=1,535,000 seen=1,949,473 filtered_len=385,793 no_space=28,680 | ~50995.9 kept/s | elapsed=33.2s
# [PAGES] pages=18,600 | kept=1,536,120 | seen=1,950,956
# [PAGES] pages=18,700 | kept=1,539,918 | seen=1,955,710
# [SENTS] kept=1,540,000 seen=1,955,802 filtered_len=387,059 no_space=28,743 | ~43760.2 kept/s | elapsed=33.4s
# [SENTS] kept=1,545,000 seen=1,961,928 filtered_len=388,123 no_space=28,805 | ~45597.1 kept/s | elapsed=33.5s
# [PAGES] pages=18,800 | kept=1,546,316 | seen=1,963,529
# [SENTS] kept=1,550,000 seen=1,968,042 filtered_len=389,179 no_space=28,863 | ~43127.2 kept/s | elapsed=33.6s
# [PAGES] pages=18,900 | kept=1,551,967 | seen=1,970,556
# [SENTS] kept=1,555,000 seen=1,974,551 filtered_len=390,595 no_space=28,956 | ~43457.5 kept/s | elapsed=33.7s
# [PAGES] pages=19,000 | kept=1,557,200 | seen=1,977,206
# [SENTS] kept=1,560,000 seen=1,980,909 filtered_len=391,838 no_space=29,071 | ~46990.7 kept/s | elapsed=33.8s
# [SENTS] kept=1,565,000 seen=1,987,163 filtered_len=392,967 no_space=29,196 | ~50125.4 kept/s | elapsed=33.9s
# [PAGES] pages=19,100 | kept=1,566,790 | seen=1,989,533
# [SENTS] kept=1,570,000 seen=1,993,647 filtered_len=394,363 no_space=29,284 | ~45781.2 kept/s | elapsed=34.0s
# [PAGES] pages=19,200 | kept=1,573,553 | seen=1,998,141
# [SENTS] kept=1,575,000 seen=1,999,920 filtered_len=395,548 no_space=29,372 | ~44660.7 kept/s | elapsed=34.1s
# [SENTS] kept=1,580,000 seen=2,006,062 filtered_len=396,612 no_space=29,450 | ~49134.3 kept/s | elapsed=34.2s
# [PAGES] pages=19,300 | kept=1,581,605 | seen=2,008,123
# [PAGES] pages=19,400 | kept=1,584,881 | seen=2,012,382
# [SENTS] kept=1,585,000 seen=2,012,536 filtered_len=397,998 no_space=29,538 | ~44298.3 kept/s | elapsed=34.3s
# [PAGES] pages=19,500 | kept=1,589,313 | seen=2,017,871
# [SENTS] kept=1,590,000 seen=2,018,708 filtered_len=399,094 no_space=29,614 | ~43404.3 kept/s | elapsed=34.5s
# [PAGES] pages=19,600 | kept=1,594,218 | seen=2,023,751
# [SENTS] kept=1,595,000 seen=2,024,731 filtered_len=400,044 no_space=29,687 | ~47287.3 kept/s | elapsed=34.6s
# [PAGES] pages=19,700 | kept=1,597,601 | seen=2,028,231
# [SENTS] kept=1,600,000 seen=2,031,122 filtered_len=401,337 no_space=29,785 | ~42593.4 kept/s | elapsed=34.7s
# [PAGES] pages=19,800 | kept=1,602,078 | seen=2,033,515
# [SENTS] kept=1,605,000 seen=2,037,233 filtered_len=402,376 no_space=29,857 | ~48926.6 kept/s | elapsed=34.8s
# [PAGES] pages=19,900 | kept=1,606,638 | seen=2,039,490
# [SENTS] kept=1,610,000 seen=2,043,826 filtered_len=403,872 no_space=29,954 | ~47945.0 kept/s | elapsed=34.9s
# [PAGES] pages=20,000 | kept=1,612,031 | seen=2,046,383
# [SENTS] kept=1,615,000 seen=2,050,121 filtered_len=405,082 no_space=30,039 | ~47385.3 kept/s | elapsed=35.0s
# [PAGES] pages=20,100 | kept=1,616,062 | seen=2,051,516
# [PAGES] pages=20,200 | kept=1,617,662 | seen=2,053,599
# [SENTS] kept=1,620,000 seen=2,056,802 filtered_len=406,666 no_space=30,136 | ~45314.8 kept/s | elapsed=35.1s
# [PAGES] pages=20,300 | kept=1,623,216 | seen=2,060,738
# [SENTS] kept=1,625,000 seen=2,063,076 filtered_len=407,839 no_space=30,237 | ~44763.6 kept/s | elapsed=35.2s
# [PAGES] pages=20,400 | kept=1,629,787 | seen=2,068,663
# [SENTS] kept=1,630,000 seen=2,068,913 filtered_len=408,603 no_space=30,310 | ~47938.2 kept/s | elapsed=35.3s
# [PAGES] pages=20,500 | kept=1,631,649 | seen=2,070,874
# [SENTS] kept=1,635,000 seen=2,075,044 filtered_len=409,677 no_space=30,367 | ~42895.9 kept/s | elapsed=35.4s
# [PAGES] pages=20,600 | kept=1,636,840 | seen=2,077,440
# [SENTS] kept=1,640,000 seen=2,081,492 filtered_len=411,018 no_space=30,474 | ~47022.6 kept/s | elapsed=35.5s
# [PAGES] pages=20,700 | kept=1,641,285 | seen=2,083,198
# [SENTS] kept=1,645,000 seen=2,087,826 filtered_len=412,274 no_space=30,552 | ~46060.9 kept/s | elapsed=35.6s
# [PAGES] pages=20,800 | kept=1,645,580 | seen=2,088,523
# [SENTS] kept=1,650,000 seen=2,093,860 filtered_len=413,232 no_space=30,628 | ~48988.3 kept/s | elapsed=35.7s
# [PAGES] pages=20,900 | kept=1,650,014 | seen=2,093,882
# [PAGES] pages=21,000 | kept=1,653,192 | seen=2,097,883
# [SENTS] kept=1,655,000 seen=2,100,115 filtered_len=414,416 no_space=30,699 | ~43142.9 kept/s | elapsed=35.9s
# [PAGES] pages=21,100 | kept=1,659,819 | seen=2,106,916
# [SENTS] kept=1,660,000 seen=2,107,136 filtered_len=416,293 no_space=30,843 | ~43649.0 kept/s | elapsed=36.0s
# [SENTS] kept=1,665,000 seen=2,114,412 filtered_len=418,482 no_space=30,930 | ~49888.2 kept/s | elapsed=36.1s
# [PAGES] pages=21,200 | kept=1,667,044 | seen=2,118,006
# [SENTS] kept=1,670,000 seen=2,121,942 filtered_len=420,768 no_space=31,174 | ~49208.1 kept/s | elapsed=36.2s
# [PAGES] pages=21,300 | kept=1,672,348 | seen=2,124,822
# [SENTS] kept=1,675,000 seen=2,128,524 filtered_len=422,264 no_space=31,260 | ~44639.7 kept/s | elapsed=36.3s
# [PAGES] pages=21,400 | kept=1,675,362 | seen=2,129,074
# [SENTS] kept=1,680,000 seen=2,135,458 filtered_len=424,033 no_space=31,425 | ~53842.8 kept/s | elapsed=36.4s
# [PAGES] pages=21,500 | kept=1,681,559 | seen=2,137,558
# [SENTS] kept=1,685,000 seen=2,142,209 filtered_len=425,687 no_space=31,522 | ~47439.2 kept/s | elapsed=36.5s
# [PAGES] pages=21,600 | kept=1,687,362 | seen=2,145,292
# [SENTS] kept=1,690,000 seen=2,149,493 filtered_len=427,841 no_space=31,652 | ~49717.6 kept/s | elapsed=36.6s
# [SENTS] kept=1,695,000 seen=2,156,396 filtered_len=429,589 no_space=31,807 | ~53246.5 kept/s | elapsed=36.7s
# [PAGES] pages=21,700 | kept=1,696,712 | seen=2,158,602
# [SENTS] kept=1,700,000 seen=2,162,667 filtered_len=430,730 no_space=31,937 | ~51938.4 kept/s | elapsed=36.8s
# [PAGES] pages=21,800 | kept=1,700,717 | seen=2,163,653
# [SENTS] kept=1,705,000 seen=2,168,654 filtered_len=431,642 no_space=32,012 | ~47245.9 kept/s | elapsed=36.9s
# [PAGES] pages=21,900 | kept=1,707,077 | seen=2,171,502
# [SENTS] kept=1,710,000 seen=2,175,596 filtered_len=433,476 no_space=32,120 | ~46759.7 kept/s | elapsed=37.0s
# [PAGES] pages=22,000 | kept=1,710,527 | seen=2,176,221
# [PAGES] pages=22,100 | kept=1,712,961 | seen=2,179,278
# [SENTS] kept=1,715,000 seen=2,181,977 filtered_len=434,779 no_space=32,198 | ~44594.3 kept/s | elapsed=37.1s
# [PAGES] pages=22,200 | kept=1,715,572 | seen=2,182,669
# ...
# [PAGES] pages=90,600 | kept=4,582,929 | seen=5,776,891
# [SENTS] kept=4,585,000 seen=5,779,537 filtered_len=1,109,961 no_space=84,576 | ~41019.6 kept/s | elapsed=101.8s
# [PAGES] pages=90,700 | kept=4,587,610 | seen=5,782,808
# [SENTS] kept=4,590,000 seen=5,785,665 filtered_len=1,111,000 no_space=84,665 | ~42770.0 kept/s | elapsed=101.9s
# [PAGES] pages=90,800 | kept=4,591,168 | seen=5,787,190
# [PAGES] pages=90,900 | kept=4,594,822 | seen=5,791,867
# [SENTS] kept=4,595,000 seen=5,792,086 filtered_len=1,112,339 no_space=84,747 | ~40482.2 kept/s | elapsed=102.1s
# [PAGES] pages=91,000 | kept=4,598,586 | seen=5,796,547
# [SENTS] kept=4,600,000 seen=5,798,393 filtered_len=1,113,572 no_space=84,821 | ~42905.7 kept/s | elapsed=102.2s
# [PAGES] pages=91,100 | kept=4,602,003 | seen=5,801,062
# [SENTS] kept=4,605,000 seen=5,804,859 filtered_len=1,114,928 no_space=84,931 | ~43994.7 kept/s | elapsed=102.3s
# [PAGES] pages=91,200 | kept=4,605,652 | seen=5,805,700
# [PAGES] pages=91,300 | kept=4,609,517 | seen=5,810,521
# [SENTS] kept=4,610,000 seen=5,811,094 filtered_len=1,116,029 no_space=85,065 | ~39058.8 kept/s | elapsed=102.4s
# [SENTS] kept=4,615,000 seen=5,817,470 filtered_len=1,117,256 no_space=85,214 | ~45278.0 kept/s | elapsed=102.5s
# [PAGES] pages=91,400 | kept=4,615,000 | seen=5,817,470
# [PAGES] pages=91,500 | kept=4,618,921 | seen=5,822,451
# [SENTS] kept=4,620,000 seen=5,823,773 filtered_len=1,118,463 no_space=85,310 | ~44264.3 kept/s | elapsed=102.6s
# [PAGES] pages=91,600 | kept=4,621,709 | seen=5,825,854
# [SENTS] kept=4,625,000 seen=5,829,929 filtered_len=1,119,529 no_space=85,400 | ~43251.5 kept/s | elapsed=102.8s
# [PAGES] pages=91,700 | kept=4,626,313 | seen=5,831,387
# [SENTS] kept=4,630,000 seen=5,835,706 filtered_len=1,120,240 no_space=85,466 | ~47253.6 kept/s | elapsed=102.9s
# [PAGES] pages=91,800 | kept=4,631,201 | seen=5,837,108
# [PAGES] pages=91,900 | kept=4,633,794 | seen=5,840,259
# [SENTS] kept=4,635,000 seen=5,841,755 filtered_len=1,121,222 no_space=85,533 | ~41634.7 kept/s | elapsed=103.0s
# [PAGES] pages=92,000 | kept=4,639,138 | seen=5,846,747
# [SENTS] kept=4,640,000 seen=5,847,808 filtered_len=1,122,173 no_space=85,635 | ~41510.7 kept/s | elapsed=103.1s
# [PAGES] pages=92,100 | kept=4,641,201 | seen=5,849,444
# [SENTS] kept=4,645,000 seen=5,854,424 filtered_len=1,123,681 no_space=85,743 | ~40908.1 kept/s | elapsed=103.2s
# [PAGES] pages=92,200 | kept=4,645,197 | seen=5,854,673
# [PAGES] pages=92,300 | kept=4,647,776 | seen=5,857,841
# [SENTS] kept=4,650,000 seen=5,860,589 filtered_len=1,124,761 no_space=85,828 | ~50491.9 kept/s | elapsed=103.3s
# [PAGES] pages=92,400 | kept=4,651,138 | seen=5,862,000
# [SENTS] kept=4,655,000 seen=5,866,862 filtered_len=1,125,938 no_space=85,924 | ~41655.2 kept/s | elapsed=103.4s
# [PAGES] pages=92,500 | kept=4,655,432 | seen=5,867,356
# [PAGES] pages=92,600 | kept=4,658,681 | seen=5,871,490
# [SENTS] kept=4,660,000 seen=5,873,237 filtered_len=1,127,218 no_space=86,019 | ~44395.2 kept/s | elapsed=103.6s
# [PAGES] pages=92,700 | kept=4,660,817 | seen=5,874,238
# [PAGES] pages=92,800 | kept=4,662,498 | seen=5,876,303
# [SENTS] kept=4,665,000 seen=5,879,380 filtered_len=1,128,268 no_space=86,112 | ~46607.8 kept/s | elapsed=103.7s
# [PAGES] pages=92,900 | kept=4,666,587 | seen=5,881,373
# [PAGES] pages=93,000 | kept=4,669,958 | seen=5,885,524
# [SENTS] kept=4,670,000 seen=5,885,601 filtered_len=1,129,385 no_space=86,216 | ~43591.6 kept/s | elapsed=103.8s
# [PAGES] pages=93,100 | kept=4,673,840 | seen=5,890,618
# [SENTS] kept=4,675,000 seen=5,892,429 filtered_len=1,130,988 no_space=86,441 | ~47629.5 kept/s | elapsed=103.9s
# [PAGES] pages=93,200 | kept=4,678,461 | seen=5,896,695
# [SENTS] kept=4,680,000 seen=5,898,549 filtered_len=1,132,051 no_space=86,498 | ~42820.3 kept/s | elapsed=104.0s
# [PAGES] pages=93,300 | kept=4,683,229 | seen=5,902,554
# [SENTS] kept=4,685,000 seen=5,904,827 filtered_len=1,133,219 no_space=86,608 | ~42675.3 kept/s | elapsed=104.1s
# [PAGES] pages=93,400 | kept=4,686,823 | seen=5,907,010
# [PAGES] pages=93,500 | kept=4,689,754 | seen=5,910,533
# [SENTS] kept=4,690,000 seen=5,910,858 filtered_len=1,134,157 no_space=86,701 | ~40629.6 kept/s | elapsed=104.2s
# [PAGES] pages=93,600 | kept=4,693,779 | seen=5,915,478
# [SENTS] kept=4,695,000 seen=5,917,018 filtered_len=1,135,241 no_space=86,777 | ~41936.2 kept/s | elapsed=104.4s
# [PAGES] pages=93,700 | kept=4,696,244 | seen=5,918,485
# [PAGES] pages=93,800 | kept=4,699,416 | seen=5,922,606
# [SENTS] kept=4,700,000 seen=5,923,333 filtered_len=1,136,473 no_space=86,860 | ~43360.6 kept/s | elapsed=104.5s
# [PAGES] pages=93,900 | kept=4,703,487 | seen=5,927,440
# [SENTS] kept=4,705,000 seen=5,929,347 filtered_len=1,137,428 no_space=86,919 | ~50213.9 kept/s | elapsed=104.6s
# [PAGES] pages=94,000 | kept=4,708,071 | seen=5,933,420
# [SENTS] kept=4,710,000 seen=5,935,919 filtered_len=1,138,880 no_space=87,039 | ~45000.9 kept/s | elapsed=104.7s
# [PAGES] pages=94,100 | kept=4,711,640 | seen=5,937,835
# [SENTS] kept=4,715,000 seen=5,942,124 filtered_len=1,139,904 no_space=87,220 | ~48117.9 kept/s | elapsed=104.8s
# [PAGES] pages=94,200 | kept=4,715,625 | seen=5,942,905
# [PAGES] pages=94,300 | kept=4,719,089 | seen=5,947,137
# [SENTS] kept=4,720,000 seen=5,948,264 filtered_len=1,140,962 no_space=87,302 | ~42839.8 kept/s | elapsed=104.9s
# [PAGES] pages=94,400 | kept=4,721,880 | seen=5,950,724
# [SENTS] kept=4,725,000 seen=5,954,773 filtered_len=1,142,364 no_space=87,409 | ~43580.9 kept/s | elapsed=105.0s
# [PAGES] pages=94,500 | kept=4,726,212 | seen=5,956,261
# [PAGES] pages=94,600 | kept=4,729,426 | seen=5,960,236
# [SENTS] kept=4,730,000 seen=5,960,918 filtered_len=1,143,409 no_space=87,509 | ~43635.0 kept/s | elapsed=105.1s
# [SENTS] kept=4,735,000 seen=5,966,898 filtered_len=1,144,219 no_space=87,679 | ~50681.6 kept/s | elapsed=105.2s
# [PAGES] pages=94,700 | kept=4,735,277 | seen=5,967,248
# [PAGES] pages=94,800 | kept=4,738,872 | seen=5,971,835
# [SENTS] kept=4,740,000 seen=5,973,235 filtered_len=1,145,459 no_space=87,776 | ~46299.9 kept/s | elapsed=105.3s
# [PAGES] pages=94,900 | kept=4,743,710 | seen=5,977,673
# [SENTS] kept=4,745,000 seen=5,979,243 filtered_len=1,146,414 no_space=87,829 | ~42553.9 kept/s | elapsed=105.5s
# [PAGES] pages=95,000 | kept=4,747,651 | seen=5,982,525
# [SENTS] kept=4,750,000 seen=5,985,277 filtered_len=1,147,369 no_space=87,908 | ~48916.0 kept/s | elapsed=105.6s
# [PAGES] pages=95,100 | kept=4,753,055 | seen=5,989,037
# [SENTS] kept=4,755,000 seen=5,991,392 filtered_len=1,148,418 no_space=87,974 | ~40140.7 kept/s | elapsed=105.7s
# [PAGES] pages=95,200 | kept=4,756,564 | seen=5,993,157
# [SENTS] kept=4,760,000 seen=5,997,406 filtered_len=1,149,353 no_space=88,053 | ~40011.1 kept/s | elapsed=105.8s
# [PAGES] pages=95,300 | kept=4,760,291 | seen=5,997,736
# [PAGES] pages=95,400 | kept=4,762,496 | seen=6,000,431
# [SENTS] kept=4,765,000 seen=6,003,399 filtered_len=1,150,288 no_space=88,111 | ~48156.6 kept/s | elapsed=105.9s
# [PAGES] pages=95,500 | kept=4,766,208 | seen=6,004,821
# [SENTS] kept=4,770,000 seen=6,009,433 filtered_len=1,151,226 no_space=88,207 | ~44558.1 kept/s | elapsed=106.0s
# [PAGES] pages=95,600 | kept=4,770,427 | seen=6,009,947
# [PAGES] pages=95,700 | kept=4,773,812 | seen=6,014,495
# [SENTS] kept=4,775,000 seen=6,015,936 filtered_len=1,152,612 no_space=88,324 | ~40981.3 kept/s | elapsed=106.1s
# [PAGES] pages=95,800 | kept=4,777,026 | seen=6,018,444
# [SENTS] kept=4,780,000 seen=6,022,033 filtered_len=1,153,631 no_space=88,402 | ~42473.3 kept/s | elapsed=106.3s
# [PAGES] pages=95,900 | kept=4,780,101 | seen=6,022,137
# [PAGES] pages=96,000 | kept=4,784,718 | seen=6,027,890
# [SENTS] kept=4,785,000 seen=6,028,200 filtered_len=1,154,723 no_space=88,477 | ~40911.2 kept/s | elapsed=106.4s
# [PAGES] pages=96,100 | kept=4,786,768 | seen=6,030,230
# [PAGES] pages=96,200 | kept=4,789,129 | seen=6,033,137
# [SENTS] kept=4,790,000 seen=6,034,148 filtered_len=1,155,609 no_space=88,539 | ~48391.9 kept/s | elapsed=106.5s
# [PAGES] pages=96,300 | kept=4,793,270 | seen=6,038,210
# [SENTS] kept=4,795,000 seen=6,040,417 filtered_len=1,156,769 no_space=88,648 | ~47702.7 kept/s | elapsed=106.6s
# [PAGES] pages=96,400 | kept=4,797,300 | seen=6,043,439
# [SENTS] kept=4,800,000 seen=6,046,660 filtered_len=1,157,889 no_space=88,771 | ~44982.2 kept/s | elapsed=106.7s
# [PAGES] pages=96,500 | kept=4,800,300 | seen=6,047,045
# [PAGES] pages=96,600 | kept=4,804,827 | seen=6,052,563
# [SENTS] kept=4,805,000 seen=6,052,744 filtered_len=1,158,898 no_space=88,846 | ~39487.3 kept/s | elapsed=106.8s
# [PAGES] pages=96,700 | kept=4,807,628 | seen=6,056,149
# [SENTS] kept=4,810,000 seen=6,059,046 filtered_len=1,160,067 no_space=88,979 | ~45041.8 kept/s | elapsed=106.9s
# [PAGES] pages=96,800 | kept=4,810,817 | seen=6,060,030
# [SENTS] kept=4,815,000 seen=6,065,554 filtered_len=1,161,472 no_space=89,082 | ~52419.1 kept/s | elapsed=107.0s
# [PAGES] pages=96,900 | kept=4,815,138 | seen=6,065,707
# [PAGES] pages=97,000 | kept=4,818,695 | seen=6,070,316
# [SENTS] kept=4,820,000 seen=6,071,865 filtered_len=1,162,683 no_space=89,182 | ~42892.0 kept/s | elapsed=107.2s
# [PAGES] pages=97,100 | kept=4,823,191 | seen=6,075,721
# [SENTS] kept=4,825,000 seen=6,077,988 filtered_len=1,163,761 no_space=89,227 | ~44243.9 kept/s | elapsed=107.3s
# [PAGES] pages=97,200 | kept=4,826,699 | seen=6,080,131
# [SENTS] kept=4,830,000 seen=6,084,163 filtered_len=1,164,864 no_space=89,299 | ~38247.6 kept/s | elapsed=107.4s
# [PAGES] pages=97,300 | kept=4,832,434 | seen=6,087,043
# [SENTS] kept=4,835,000 seen=6,090,234 filtered_len=1,165,872 no_space=89,362 | ~42044.0 kept/s | elapsed=107.5s
# [PAGES] pages=97,400 | kept=4,836,928 | seen=6,092,685
# [PAGES] pages=97,500 | kept=4,839,897 | seen=6,096,553
# [SENTS] kept=4,840,000 seen=6,096,683 filtered_len=1,167,224 no_space=89,459 | ~53126.5 kept/s | elapsed=107.6s
# [PAGES] pages=97,600 | kept=4,843,789 | seen=6,101,630
# [SENTS] kept=4,845,000 seen=6,103,047 filtered_len=1,168,477 no_space=89,570 | ~46681.9 kept/s | elapsed=107.7s
# [PAGES] pages=97,700 | kept=4,847,107 | seen=6,105,912
# [PAGES] pages=97,800 | kept=4,849,965 | seen=6,110,012
# [SENTS] kept=4,850,000 seen=6,110,051 filtered_len=1,170,384 no_space=89,667 | ~43946.7 kept/s | elapsed=107.8s
# [PAGES] pages=97,900 | kept=4,854,468 | seen=6,115,570
# [SENTS] kept=4,855,000 seen=6,116,126 filtered_len=1,171,408 no_space=89,718 | ~43761.4 kept/s | elapsed=107.9s
# [PAGES] pages=98,000 | kept=4,857,477 | seen=6,119,160
# [SENTS] kept=4,860,000 seen=6,122,048 filtered_len=1,172,242 no_space=89,806 | ~43479.0 kept/s | elapsed=108.1s
# [PAGES] pages=98,100 | kept=4,861,718 | seen=6,124,045
# [SENTS] kept=4,865,000 seen=6,128,610 filtered_len=1,173,717 no_space=89,893 | ~43654.4 kept/s | elapsed=108.2s
# [PAGES] pages=98,200 | kept=4,865,170 | seen=6,128,847
# [PAGES] pages=98,300 | kept=4,869,313 | seen=6,133,700
# [SENTS] kept=4,870,000 seen=6,134,479 filtered_len=1,174,527 no_space=89,952 | ~45421.1 kept/s | elapsed=108.3s
# [PAGES] pages=98,400 | kept=4,873,517 | seen=6,138,885
# [SENTS] kept=4,875,000 seen=6,140,801 filtered_len=1,175,756 no_space=90,045 | ~44968.5 kept/s | elapsed=108.4s
# [PAGES] pages=98,500 | kept=4,878,929 | seen=6,145,716
# [SENTS] kept=4,880,000 seen=6,147,051 filtered_len=1,176,917 no_space=90,134 | ~42457.4 kept/s | elapsed=108.5s
# [PAGES] pages=98,600 | kept=4,880,913 | seen=6,148,132
# [SENTS] kept=4,885,000 seen=6,153,174 filtered_len=1,177,960 no_space=90,214 | ~40115.8 kept/s | elapsed=108.6s
# [PAGES] pages=98,700 | kept=4,885,562 | seen=6,153,899
# [PAGES] pages=98,800 | kept=4,889,349 | seen=6,158,551
# [SENTS] kept=4,890,000 seen=6,159,348 filtered_len=1,179,037 no_space=90,311 | ~45872.1 kept/s | elapsed=108.7s
# [PAGES] pages=98,900 | kept=4,892,346 | seen=6,162,121
# [SENTS] kept=4,895,000 seen=6,165,515 filtered_len=1,180,104 no_space=90,411 | ~47432.4 kept/s | elapsed=108.9s
# [PAGES] pages=99,000 | kept=4,895,149 | seen=6,165,681
# [PAGES] pages=99,100 | kept=4,897,912 | seen=6,169,178
# [SENTS] kept=4,900,000 seen=6,171,883 filtered_len=1,181,375 no_space=90,508 | ~42942.0 kept/s | elapsed=109.0s
# [PAGES] pages=99,200 | kept=4,903,121 | seen=6,176,009
# [SENTS] kept=4,905,000 seen=6,178,287 filtered_len=1,182,704 no_space=90,583 | ~39489.2 kept/s | elapsed=109.1s
# [PAGES] pages=99,300 | kept=4,907,090 | seen=6,180,854
# [PAGES] pages=99,400 | kept=4,909,913 | seen=6,184,518
# [SENTS] kept=4,910,000 seen=6,184,622 filtered_len=1,183,938 no_space=90,684 | ~45661.7 kept/s | elapsed=109.2s
# [PAGES] pages=99,500 | kept=4,914,052 | seen=6,189,646
# [PAGES] pages=99,600 | kept=4,914,978 | seen=6,190,682
# [SENTS] kept=4,915,000 seen=6,190,709 filtered_len=1,184,949 no_space=90,760 | ~44060.6 kept/s | elapsed=109.3s
# [PAGES] pages=99,700 | kept=4,918,215 | seen=6,194,697
# [SENTS] kept=4,920,000 seen=6,198,038 filtered_len=1,187,029 no_space=91,009 | ~48132.4 kept/s | elapsed=109.4s
# [PAGES] pages=99,800 | kept=4,923,233 | seen=6,202,511
# [SENTS] kept=4,925,000 seen=6,204,453 filtered_len=1,188,349 no_space=91,104 | ~43127.3 kept/s | elapsed=109.5s
# [PAGES] pages=99,900 | kept=4,926,837 | seen=6,206,817
# [PAGES] pages=100,000 | kept=4,929,411 | seen=6,209,813
# [SENTS] kept=4,930,000 seen=6,210,473 filtered_len=1,189,268 no_space=91,205 | ~45750.7 kept/s | elapsed=109.6s
# [PAGES] pages=100,100 | kept=4,932,856 | seen=6,213,722
# [SENTS] kept=4,935,000 seen=6,216,401 filtered_len=1,190,122 no_space=91,279 | ~49776.9 kept/s | elapsed=109.7s
# [PAGES] pages=100,200 | kept=4,935,366 | seen=6,216,830
# [PAGES] pages=100,300 | kept=4,938,055 | seen=6,220,153
# [SENTS] kept=4,940,000 seen=6,222,375 filtered_len=1,190,979 no_space=91,396 | ~50664.2 kept/s | elapsed=109.8s
# [PAGES] pages=100,400 | kept=4,942,531 | seen=6,225,391
# [SENTS] kept=4,945,000 seen=6,228,287 filtered_len=1,191,836 no_space=91,451 | ~42134.8 kept/s | elapsed=110.0s
# [PAGES] pages=100,500 | kept=4,945,179 | seen=6,228,535
# [PAGES] pages=100,600 | kept=4,947,840 | seen=6,231,613
# [SENTS] kept=4,950,000 seen=6,234,164 filtered_len=1,192,637 no_space=91,527 | ~45858.1 kept/s | elapsed=110.1s
# [PAGES] pages=100,700 | kept=4,950,709 | seen=6,234,967
# [SENTS] kept=4,955,000 seen=6,240,156 filtered_len=1,193,485 no_space=91,671 | ~50212.3 kept/s | elapsed=110.2s
# [PAGES] pages=100,800 | kept=4,957,239 | seen=6,243,017
# [SENTS] kept=4,960,000 seen=6,246,559 filtered_len=1,194,745 no_space=91,814 | ~52618.9 kept/s | elapsed=110.3s
# [PAGES] pages=100,900 | kept=4,960,524 | seen=6,247,177
# [SENTS] kept=4,965,000 seen=6,252,770 filtered_len=1,195,889 no_space=91,881 | ~45584.7 kept/s | elapsed=110.4s
# [PAGES] pages=101,000 | kept=4,965,039 | seen=6,252,813
# [PAGES] pages=101,100 | kept=4,968,331 | seen=6,256,756
# [SENTS] kept=4,970,000 seen=6,258,830 filtered_len=1,196,816 no_space=92,014 | ~47521.7 kept/s | elapsed=110.5s
# [PAGES] pages=101,200 | kept=4,972,165 | seen=6,261,548
# [SENTS] kept=4,975,000 seen=6,264,865 filtered_len=1,197,763 no_space=92,102 | ~41254.8 kept/s | elapsed=110.6s
# [PAGES] pages=101,300 | kept=4,976,069 | seen=6,266,161
# [PAGES] pages=101,400 | kept=4,979,904 | seen=6,270,993
# [SENTS] kept=4,980,000 seen=6,271,113 filtered_len=1,198,898 no_space=92,215 | ~43360.7 kept/s | elapsed=110.7s
# [PAGES] pages=101,500 | kept=4,984,504 | seen=6,276,701
# [SENTS] kept=4,985,000 seen=6,277,294 filtered_len=1,199,964 no_space=92,330 | ~49610.9 kept/s | elapsed=110.8s
# [PAGES] pages=101,600 | kept=4,988,612 | seen=6,282,383
# [SENTS] kept=4,990,000 seen=6,284,165 filtered_len=1,201,706 no_space=92,459 | ~44234.1 kept/s | elapsed=110.9s
# [PAGES] pages=101,700 | kept=4,992,622 | seen=6,287,551
# [SENTS] kept=4,995,000 seen=6,290,521 filtered_len=1,202,949 no_space=92,572 | ~46176.6 kept/s | elapsed=111.0s
# [PAGES] pages=101,800 | kept=4,996,551 | seen=6,292,639
# [SENTS] kept=5,000,000 seen=6,297,447 filtered_len=1,204,778 no_space=92,669 | ~45542.7 kept/s | elapsed=111.2s
# === ИТОГО ===
# Страниц обработано: 101,880
# Предложений рассмотрено: 6,297,447
# Сохранено (train+val): 5,000,000
# Отсеяно по длине: 1,204,778
# Без пробелов (нет меток): 92,669
# Train строк: 4,750,264
# Val   строк: 249,736
# Уникальных униграмм: 1,569,913
# Время (факт): 113.2 s

# %%
# === ЭТАП 2. (Опционально) Добавление синтетики с ПЕРВЫМИ версиями списков ===
# Если не хотите синтетику сейчас — ПРОСТО НЕ ЗАПУСКАЙТЕ эту ячейку.

from collections import Counter

UNITS = ["см", "мм", "м", "км", "кг", "г", "л", "мл", "дюйм",
         "дюйма", "дюймов", "gb", "mb", "tb", "гб", "мб", "тб"]
BRANDS = ["iphone", "samsung", "xiaomi", "huawei", "sony",
          "nokia", "poco", "asus", "lenovo", "honor", "pixel", "oneplus"]
MODELS = ["14", "14pro", "14proMax", "13", "s23", "s23ultra", "s24",
          "s24plus", "mi13", "mi14", "12t", "rtx4060", "rtx4070ti", "rx7800xt"]
MISC_LEFT = ["usb", "hdmi", "typec", "usbc", "sd", "microsd",
             "ssd", "hdd", "ddr4", "ddr5", "wifi", "bluetooth"]
MISC_RIGHT = ["кабель", "переходник", "адаптер", "карта",
              "накопитель", "модуль", "память", "зарядка", "чехол", "блокпитания"]

SYNTHETIC_COUNT = 5000  # при необходимости измените


def synth_examples(n=SYNTHETIC_COUNT):
    rng = random.Random(SEED + 7)
    out = []
    # 1) число + единица измерения
    for _ in range(n // 3):
        num = str(rng.choice([1, 2, 3, 4, 5, 10, 12, 14,
                  15, 16, 24, 27, 32, 64, 128, 256, 512, 1024]))
        unit = rng.choice(UNITS)
        tail = rng.choice(
            ["", " кабель", " экран", " дисплей", " память", " вес"])
        text = f"{num} {unit}{tail}"
        out.append(text)
    # 2) бренд+модель (слитно или с хвостом)
    for _ in range(n // 3):
        b = rng.choice(BRANDS)
        m = rng.choice(MODELS)
        tail = rng.choice(["", " телефон", " смартфон", " чехол", " зарядка"])
        text = rng.choice([f"{b}{m}{tail}", f"{b} {m}{tail}"])
        out.append(text)
    # 3) <misc_left> <misc_right> <num><unit>
    for _ in range(n - 2*(n//3)):
        left = rng.choice(MISC_LEFT)
        right = rng.choice(MISC_RIGHT)
        num = str(rng.choice(
            [1, 2, 3, 5, 10, 15, 20, 25, 30, 50, 100, 150, 200]))
        unit = rng.choice(UNITS)
        text = f"{left} {right} {num}{unit}"
        out.append(text)
    rng.shuffle(out)
    return out


def append_synthetic(train_path: Path, unigram_path: Path, examples: list[str]):
    uni_counter = Counter()
    added = 0
    with train_path.open("a", encoding="utf-8") as f_train:
        for s in examples:
            s_norm = normalize_ws(s)
            # ослабим фильтры для коротких синтетических фраз
            if len(s_norm) < 5:
                continue
            text_no_spaces, boundaries = to_compact_and_boundaries(s_norm)
            if len(text_no_spaces) < 3 or len(text_no_spaces) > MAX_COMPACT_LEN:
                continue
            if len(boundaries) == 0:
                continue
            rec = {"text_no_spaces": text_no_spaces, "boundaries": boundaries}
            f_train.write(json.dumps(rec, ensure_ascii=False) + "\n")
            uni_counter.update(tokenize_for_unigrams(s_norm))
            added += 1

    existing = Counter()
    if unigram_path.exists():
        with unigram_path.open("r", encoding="utf-8") as f_uni:
            for line in f_uni:
                w, c = line.rstrip("\n").split("\t")
                existing[w] += int(c)
    existing.update(uni_counter)
    with unigram_path.open("w", encoding="utf-8") as f_uni:
        for w, c in existing.most_common():
            f_uni.write(f"{w}\t{c}\n")

    print(f"Синтетики добавлено в train: {added}")
    print(
        f"Униграммы обновлены: {sum(1 for _ in unigram_path.open('r', encoding='utf-8'))} строк")


# Генерация и добавление (опционально)
synth = synth_examples(SYNTHETIC_COUNT)
append_synthetic(TRAIN_PATH, UNIGRAM_PATH, synth)
# Out:
# Синтетики добавлено в train: 4738
# Униграммы обновлены: 1570271 строк

# %%
# === ЭТАП 2. Санитайзер JSONL и быстрый просмотр примеров ===

def sanitize_jsonl(path_str: str):
    path = Path(path_str)
    if not path.exists():
        print("Нет файла:", path)
        return
    tmp = path.with_suffix(path.suffix + ".fixed")
    bad = 0
    with path.open("r", encoding="utf-8", errors="ignore") as fin, \
            tmp.open("w", encoding="utf-8") as fout:
        for line in fin:
            s = line.rstrip("\n")
            if not s.strip():
                continue
            try:
                json.loads(s)
                fout.write(s + "\n")
            except json.JSONDecodeError:
                bad += 1
    if bad:
        path.rename(path.with_suffix(path.suffix + ".bak"))
        tmp.rename(path)
        print(
            f"[sanitize] Исправлено. Отброшено битых строк: {bad}. Бэкап: {path.with_suffix(path.suffix + '.bak').name}")
    else:
        tmp.unlink(missing_ok=True)
        print("[sanitize] Файл целый.")


def sample_jsonl(path: Path, k=5):
    items = []
    with path.open("r", encoding="utf-8") as f:
        for i, line in enumerate(f):
            if i >= k:
                break
            items.append(json.loads(line))
    for rec in items:
        t = rec["text_no_spaces"]
        b = rec["boundaries"]
        # восстановим для проверки
        chars = list(t)
        for pos in sorted(b, reverse=True):
            if 0 <= pos <= len(chars):
                chars.insert(pos, " ")
        restored = "".join(chars)
        print("no_spaces:", t[:120])
        print("boundaries:", b[:20], ("..." if len(b) > 20 else ""))
        print("restore :", restored[:120])
        print("---")


# Санитайз и сэмпл
sanitize_jsonl(str(TRAIN_PATH))
sanitize_jsonl(str(VAL_PATH))

print("\nПримеры из train.jsonl:")
sample_jsonl(TRAIN_PATH, k=5)
print("\nПримеры из val.jsonl:")
sample_jsonl(VAL_PATH, k=3)

print("\nРазмеры файлов:")
print("train.jsonl :", TRAIN_PATH.stat(
).st_size if TRAIN_PATH.exists() else 0, "байт")
print("val.jsonl   :", VAL_PATH.stat().st_size if VAL_PATH.exists() else 0, "байт")
print("unigram_freq:", UNIGRAM_PATH.stat(
).st_size if UNIGRAM_PATH.exists() else 0, "байт")
# Out:
# [sanitize] Файл целый.
# [sanitize] Файл целый.
#
# Примеры из train.jsonl:
# no_spaces: #REDIRECTЗаглавнаястраница
# boundaries: [9, 18]
# restore : #REDIRECT Заглавная страница
# ---
# no_spaces: Площадь—км2.
# boundaries: [7, 8, 11]
# restore : Площадь — км2 .
# ---
# no_spaces: Населениесоставляетчеловек(октябрь,2024).
# boundaries: [9, 19, 26, 35, 40]
# restore : Население составляет человек (октябрь, 2024) .
# ---
# no_spaces: 6сентября1991годаГосударственныйсоветСССРпризналнезависимостьЛитвы.
# boundaries: [1, 9, 13, 17, 32, 37, 41, 48, 61]
# restore : 6 сентября 1991 года Государственный совет СССР признал независимость Литвы.
# ---
# no_spaces: Литва—членООН(1991),ОБСЕ(1991),СоветаЕвропы(1993),ВТО(2001),Европейскогосоюза(2004),НАТО(2004)иОЭСР(2018).
# boundaries: [5, 6, 10, 13, 20, 24, 31, 37, 43, 50, 53, 60, 72, 77, 84, 88, 94, 95, 99]
# restore : Литва — член ООН (1991), ОБСЕ (1991), Совета Европы (1993), ВТО (2001), Европейского союза (2004), НАТО (2004) и ОЭСР (2
# ---
#
# Примеры из val.jsonl:
# no_spaces: Литва́(),официальноеназвание—Лито́вскаяРеспу́блика()—государство,расположенноевСевернойЕвропе.
# boundaries: [6, 7, 9, 20, 28, 29, 39, 50, 51, 52, 53, 65, 78, 79, 87, 93]
# restore : Литва́ ( ), официальное название — Лито́вская Респу́блика ( ) — государство, расположенное в Северной Европе .
# ---
# no_spaces: Так,например,существуютсозвучныетопонимынатерриторииСловакии(Lytva)иРумынии(Litua),известныесXI—XIIвеков.
# boundaries: [4, 13, 23, 32, 40, 42, 52, 60, 67, 68, 75, 83, 92, 93, 99, 104]
# restore : Так, например, существуют созвучные топонимы на территории Словакии (Lytva) и Румынии (Litua), известные с XI—XII веков
# ---
# no_spaces: Феодальноекняжество,поземлямкоторогопротекалаэтарека,современемзаняловедущееположениеиназваниебылораспространенонавсёгос
# boundaries: [10, 20, 22, 28, 36, 45, 48, 53, 55, 63, 69, 76, 85, 86, 94, 98, 112, 114, 117]
# restore : Феодальное княжество, по землям которого протекала эта река, со временем заняло ведущее положение и название было распро
# ---
#
# Размеры файлов:
# train.jsonl : 974262669 байт
# val.jsonl   : 51278546 байт
# unigram_freq: 32843119 байт

# %% [markdown]
# ## Признаки + Обучение классификатора

# %%
# === ЭТАП 3. ОБУЧЕНИЕ КЛАССИФИКАТОРА ГРАНИЦ ПРОБЕЛОВ ===
from pathlib import Path
import json
import math
import random
import re
from collections import Counter
import numpy as np
from scipy import sparse

from sklearn.feature_extraction import FeatureHasher
from sklearn.linear_model import SGDClassifier
from sklearn.utils import murmurhash3_32
import joblib

# Пути к артефактам Этапа 2
DATA_DIR = Path("prepared_corpus")
TRAIN_PATH = DATA_DIR / "train.jsonl"
VAL_PATH = DATA_DIR / "val.jsonl"
# можно отсутствовать — тогда лексикон не используется
UNIGRAM_PATH = DATA_DIR / "unigram_freq.tsv"

# Куда сохраняем модель
ART_DIR = Path("artifacts_boundary")
ART_DIR.mkdir(parents=True, exist_ok=True)
MODEL_PATH = ART_DIR / "boundary_sgd.joblib"
CFG_PATH = ART_DIR / "config_boundary.json"
THR_PATH = ART_DIR / "best_threshold.txt"

# Гиперпараметры признаков/модели
SEED = 42
random.seed(SEED)
np.random.seed(SEED)

WINDOW = 5                  # контекст по 5 символов слева и справа
# размер хеш-пространства для FeatureHasher (262144)
N_FEATURES = 2**18
# доля оставляемых "0"-примеров (оставим все "1" и 30% "0")
NEGATIVE_DOWNSAMPLE = 0.3
BATCH_LINES = 5000          # сколько строк train.jsonl обрабатываем на один partial_fit
ALPHA = 1e-5                # L2-регуляризация у SGDClassifier
MAX_EPOCHS = 2              # проходов по train.jsonl (стримингово)
USE_UNIGRAM = True          # использовать ли униграммный лексикон как флаги

# Порог для «словарного» слова (если используем лексикон)
UNIGRAM_MIN_COUNT = 5

# Тюнинг порога
THRESH_GRID = np.linspace(0.1, 0.9, 33)  # сетка из 33 точек

print("train.jsonl exists:", TRAIN_PATH.exists())
print("val.jsonl   exists:", VAL_PATH.exists())
print("unigram_freq exists:", UNIGRAM_PATH.exists())
# Out:
# train.jsonl exists: True
# val.jsonl   exists: True
# unigram_freq exists: True

# %%
# Подгружаем униграммный словарь: word -> bool(частотен)
LEXICON = None
if USE_UNIGRAM and UNIGRAM_PATH.exists():
    LEXICON = set()
    with UNIGRAM_PATH.open("r", encoding="utf-8") as f:
        for line in f:
            w, c = line.rstrip("\n").split("\t")
            if int(c) >= UNIGRAM_MIN_COUNT:
                LEXICON.add(w)
    print(
        f"[LEXICON] загружено слов: {len(LEXICON)} (min_count={UNIGRAM_MIN_COUNT})")
else:
    print("[LEXICON] не используется или файл отсутствует.")
# Out:
# [LEXICON] загружено слов: 385143 (min_count=5)

# %%
# Чтение jsonl построчно (стриминг)
def iter_jsonl(path: Path):
    with path.open("r", encoding="utf-8") as f:
        for line in f:
            if not line.strip():
                continue
            yield json.loads(line)

# Категории символов (Юникод)


def is_cyr(ch: str) -> bool:
    return 'А' <= ch <= 'я' or ch in "Ёё"


def is_lat(ch: str) -> bool:
    oc = ord(ch)
    return (65 <= oc <= 90) or (97 <= oc <= 122)


def is_digit(ch: str) -> bool:
    return ch.isdigit()


def is_punct(ch: str) -> bool:
    return ch in r""".,;:!?-—()[]{}«»"'/\|+*=_~%^<>…"""


def cat(ch: str) -> str:
    if is_cyr(ch):
        return "cyr"
    if is_lat(ch):
        return "lat"
    if is_digit(ch):
        return "dig"
    if is_punct(ch):
        return "pnc"
    return "oth"

# Служебные флаги на переходах


def trans(a: str, b: str) -> str:
    return f"{a}->{b}"

# Правило «словоподобного» символа (для предполагаемых токенов)


def is_word_char(ch: str) -> bool:
    return is_cyr(ch) or is_lat(ch) or is_digit(ch) or ch in "-_"

# Быстрый поиск «локальных токенов» слева/справа от позиции


def local_tokens(text: str, pos: int) -> tuple[str, str, str]:
    """
    pos — позиция вставки пробела (между pos-1 и pos), 1..len(text)-1.
    Возвращает (left_token, right_token, merged_token) в нижнем регистре.
    """
    n = len(text)
    i = pos - 1
    j = pos
    # идём влево
    L = i
    while L >= 0 and is_word_char(text[L]):
        L -= 1
    left_tok = text[L+1:i+1]
    # вправо
    R = j
    while R < n and is_word_char(text[R]):
        R += 1
    right_tok = text[j:R]
    merged = (left_tok + right_tok) if (left_tok and right_tok) else ""
    return left_tok.lower(), right_tok.lower(), merged.lower()

# Признаки одной позиции


def boundary_features(text: str, pos: int, window: int, lexicon=None) -> dict:
    """
    text: компактная строка без пробелов
    pos:  позиция 1..len(text)-1 (между символами)
    """
    feats = {}
    n = len(text)
    Lch = text[pos-1]
    Rch = text[pos]
    Lc = cat(Lch)
    Rc = cat(Rch)

    # Базовые свойства
    feats[f"LC:{Lch}"] = 1
    feats[f"RC:{Rch}"] = 1
    feats[f"LCAT:{Lc}"] = 1
    feats[f"RCAT:{Rc}"] = 1
    feats[f"TRAN:{trans(Lc,Rc)}"] = 1

    # Регистры
    feats["L_isupper"] = 1 if Lch.isalpha() and Lch.isupper() else 0
    feats["R_isupper"] = 1 if Rch.isalpha() and Rch.isupper() else 0

    # Символьное окно
    for k in range(1, window+1):
        if pos-1-k >= 0:
            ch = text[pos-1-k]
            feats[f"L{k}:{ch}"] = 1
            feats[f"L{k}C:{cat(ch)}"] = 1
        if pos+k < n:
            ch = text[pos+k]
            feats[f"R{k}:{ch}"] = 1
            feats[f"R{k}C:{cat(ch)}"] = 1

    # Переходы цифра↔буква/кирилл↔латиница
    feats["dig_to_alpha"] = 1 if (
        is_digit(Lch) and (is_cyr(Rch) or is_lat(Rch))) else 0
    feats["alpha_to_dig"] = 1 if (
        (is_cyr(Lch) or is_lat(Lch)) and is_digit(Rch)) else 0
    feats["cyr_to_lat"] = 1 if (is_cyr(Lch) and is_lat(Rch)) else 0
    feats["lat_to_cyr"] = 1 if (is_lat(Lch) and is_cyr(Rch)) else 0
    feats["punct_left"] = 1 if is_punct(Lch) else 0
    feats["punct_right"] = 1 if is_punct(Rch) else 0

    # Лексические флаги по локальным токенам
    if lexicon is not None:
        lt, rt, merged = local_tokens(text, pos)
        feats["lex_left"] = 1 if lt and lt in lexicon else 0
        feats["lex_right"] = 1 if rt and rt in lexicon else 0
        feats["lex_merged"] = 1 if merged and merged in lexicon else 0
        # длины «слов» — полезны как численные
        feats["len_lt"] = len(lt)
        feats["len_rt"] = len(rt)
        feats["len_merged"] = len(merged)
    else:
        feats["len_lt"] = 0
        feats["len_rt"] = 0
        feats["len_merged"] = 0

    # Позиционные фичи
    feats["rel_pos"] = pos / n
    feats["is_start_near"] = 1 if pos <= 2 else 0
    feats["is_end_near"] = 1 if (n - pos) <= 2 else 0
    return feats

# %%
# Преобразование партии строк в матрицу признаков и вектор меток
HASher = FeatureHasher(n_features=N_FEATURES,
                       input_type="dict", alternate_sign=False)


def build_batch_Xy(records, window=WINDOW, lexicon=LEXICON, neg_downsample=NEGATIVE_DOWNSAMPLE, seed=SEED):
    rng = random.Random(seed)
    feat_dicts = []
    labels = []
    for rec in records:
        text = rec["text_no_spaces"]
        gold = set(rec["boundaries"])  # 0-based позиции «вставить пробел»
        n = len(text)
        if n <= 1:
            continue
        # все потенциальные позиции: 1..n-1
        for pos in range(1, n):
            y = 1 if pos in gold else 0
            if y == 0:
                # даунсэмпл негатива
                if rng.random() > neg_downsample:
                    continue
            feat_dicts.append(boundary_features(text, pos, window, lexicon))
            labels.append(y)
    if not feat_dicts:
        # пустой батч
        return sparse.csr_matrix((0, N_FEATURES)), np.zeros((0,), dtype=np.int8)
    X = HASher.transform(feat_dicts)
    y = np.array(labels, dtype=np.int8)
    return X, y

# %%
# SGD "логистическая регрессия" с partial_fit — обучается стримингом, не кладёт всё в память

clf = SGDClassifier(
    loss="log_loss",      # логистическая регрессия
    penalty="l2",
    alpha=ALPHA,
    random_state=SEED,
    max_iter=1,           # один проход внутри partial_fit; внешние эпохи задаём сами
    warm_start=False,
    n_jobs=-1,
)

classes = np.array([0, 1], dtype=np.int64)


def train_streaming(train_path: Path, epochs=MAX_EPOCHS, batch_lines=BATCH_LINES):
    total_seen = 0
    for ep in range(1, epochs+1):
        print(f"\n=== Эпоха {ep}/{epochs} ===")
        batch = []
        for i, rec in enumerate(iter_jsonl(train_path), 1):
            batch.append(rec)
            if len(batch) >= batch_lines:
                X, y = build_batch_Xy(batch)
                if X.shape[0] > 0:
                    clf.partial_fit(X, y, classes=classes)
                    total_seen += X.shape[0]
                print(
                    f"[train] эп={ep} | обработано строк: {i} | позиций в батче: {X.shape[0]} | всего позиций: {total_seen}")
                batch.clear()
        # хвост
        if batch:
            X, y = build_batch_Xy(batch)
            if X.shape[0] > 0:
                clf.partial_fit(X, y, classes=classes)
                total_seen += X.shape[0]
            print(
                f"[train] эп={ep} | хвост | позиций в батче: {X.shape[0]} | всего позиций: {total_seen}")
    print("\n[train] готово. Всего позиций обучено:", total_seen)


train_streaming(TRAIN_PATH, epochs=MAX_EPOCHS, batch_lines=BATCH_LINES)
# Out:
# === Эпоха 1/2 ===
# [train] эп=1 | обработано строк: 5000 | позиций в батче: 149892 | всего позиций: 149892
# [train] эп=1 | обработано строк: 10000 | позиций в батче: 159488 | всего позиций: 309380
# [train] эп=1 | обработано строк: 15000 | позиций в батче: 149266 | всего позиций: 458646
# [train] эп=1 | обработано строк: 20000 | позиций в батче: 149257 | всего позиций: 607903
# [train] эп=1 | обработано строк: 25000 | позиций в батче: 156821 | всего позиций: 764724
# [train] эп=1 | обработано строк: 30000 | позиций в батче: 154820 | всего позиций: 919544
# [train] эп=1 | обработано строк: 35000 | позиций в батче: 160389 | всего позиций: 1079933
# [train] эп=1 | обработано строк: 40000 | позиций в батче: 146303 | всего позиций: 1226236
# [train] эп=1 | обработано строк: 45000 | позиций в батче: 149910 | всего позиций: 1376146
# [train] эп=1 | обработано строк: 50000 | позиций в батче: 120744 | всего позиций: 1496890
# [train] эп=1 | обработано строк: 55000 | позиций в батче: 137285 | всего позиций: 1634175
# [train] эп=1 | обработано строк: 60000 | позиций в батче: 133631 | всего позиций: 1767806
# [train] эп=1 | обработано строк: 65000 | позиций в батче: 139978 | всего позиций: 1907784
# [train] эп=1 | обработано строк: 70000 | позиций в батче: 138025 | всего позиций: 2045809
# [train] эп=1 | обработано строк: 75000 | позиций в батче: 142685 | всего позиций: 2188494
# [train] эп=1 | обработано строк: 80000 | позиций в батче: 142686 | всего позиций: 2331180
# [train] эп=1 | обработано строк: 85000 | позиций в батче: 134091 | всего позиций: 2465271
# [train] эп=1 | обработано строк: 90000 | позиций в батче: 126617 | всего позиций: 2591888
# [train] эп=1 | обработано строк: 95000 | позиций в батче: 149115 | всего позиций: 2741003
# [train] эп=1 | обработано строк: 100000 | позиций в батче: 126847 | всего позиций: 2867850
# [train] эп=1 | обработано строк: 105000 | позиций в батче: 125051 | всего позиций: 2992901
# [train] эп=1 | обработано строк: 110000 | позиций в батче: 130080 | всего позиций: 3122981
# [train] эп=1 | обработано строк: 115000 | позиций в батче: 127134 | всего позиций: 3250115
# [train] эп=1 | обработано строк: 120000 | позиций в батче: 124954 | всего позиций: 3375069
# [train] эп=1 | обработано строк: 125000 | позиций в батче: 108389 | всего позиций: 3483458
# [train] эп=1 | обработано строк: 130000 | позиций в батче: 109313 | всего позиций: 3592771
# [train] эп=1 | обработано строк: 135000 | позиций в батче: 158196 | всего позиций: 3750967
# [train] эп=1 | обработано строк: 140000 | позиций в батче: 126636 | всего позиций: 3877603
# [train] эп=1 | обработано строк: 145000 | позиций в батче: 138466 | всего позиций: 4016069
# [train] эп=1 | обработано строк: 150000 | позиций в батче: 157376 | всего позиций: 4173445
# [train] эп=1 | обработано строк: 155000 | позиций в батче: 137097 | всего позиций: 4310542
# [train] эп=1 | обработано строк: 160000 | позиций в батче: 146021 | всего позиций: 4456563
# [train] эп=1 | обработано строк: 165000 | позиций в батче: 140911 | всего позиций: 4597474
# [train] эп=1 | обработано строк: 170000 | позиций в батче: 141236 | всего позиций: 4738710
# [train] эп=1 | обработано строк: 175000 | позиций в батче: 135262 | всего позиций: 4873972
# [train] эп=1 | обработано строк: 180000 | позиций в батче: 133021 | всего позиций: 5006993
# [train] эп=1 | обработано строк: 185000 | позиций в батче: 128545 | всего позиций: 5135538
# [train] эп=1 | обработано строк: 190000 | позиций в батче: 135555 | всего позиций: 5271093
# [train] эп=1 | обработано строк: 195000 | позиций в батче: 140519 | всего позиций: 5411612
# [train] эп=1 | обработано строк: 200000 | позиций в батче: 147087 | всего позиций: 5558699
# [train] эп=1 | обработано строк: 205000 | позиций в батче: 155286 | всего позиций: 5713985
# [train] эп=1 | обработано строк: 210000 | позиций в батче: 147540 | всего позиций: 5861525
# [train] эп=1 | обработано строк: 215000 | позиций в батче: 153491 | всего позиций: 6015016
# [train] эп=1 | обработано строк: 220000 | позиций в батче: 150651 | всего позиций: 6165667
# [train] эп=1 | обработано строк: 225000 | позиций в батче: 146434 | всего позиций: 6312101
# [train] эп=1 | обработано строк: 230000 | позиций в батче: 147537 | всего позиций: 6459638
# [train] эп=1 | обработано строк: 235000 | позиций в батче: 129375 | всего позиций: 6589013
# [train] эп=1 | обработано строк: 240000 | позиций в батче: 129815 | всего позиций: 6718828
# [train] эп=1 | обработано строк: 245000 | позиций в батче: 138606 | всего позиций: 6857434
# [train] эп=1 | обработано строк: 250000 | позиций в батче: 127748 | всего позиций: 6985182
# [train] эп=1 | обработано строк: 255000 | позиций в батче: 117949 | всего позиций: 7103131
# [train] эп=1 | обработано строк: 260000 | позиций в батче: 137556 | всего позиций: 7240687
# [train] эп=1 | обработано строк: 265000 | позиций в батче: 130082 | всего позиций: 7370769
# [train] эп=1 | обработано строк: 270000 | позиций в батче: 137455 | всего позиций: 7508224
# [train] эп=1 | обработано строк: 275000 | позиций в батче: 137098 | всего позиций: 7645322
# [train] эп=1 | обработано строк: 280000 | позиций в батче: 129324 | всего позиций: 7774646
# [train] эп=1 | обработано строк: 285000 | позиций в батче: 139728 | всего позиций: 7914374
# [train] эп=1 | обработано строк: 290000 | позиций в батче: 130317 | всего позиций: 8044691
# [train] эп=1 | обработано строк: 295000 | позиций в батче: 126623 | всего позиций: 8171314
# [train] эп=1 | обработано строк: 300000 | позиций в батче: 135877 | всего позиций: 8307191
# [train] эп=1 | обработано строк: 305000 | позиций в батче: 127785 | всего позиций: 8434976
# [train] эп=1 | обработано строк: 310000 | позиций в батче: 141192 | всего позиций: 8576168
# [train] эп=1 | обработано строк: 315000 | позиций в батче: 130640 | всего позиций: 8706808
# [train] эп=1 | обработано строк: 320000 | позиций в батче: 114828 | всего позиций: 8821636
# [train] эп=1 | обработано строк: 325000 | позиций в батче: 90615 | всего позиций: 8912251
# [train] эп=1 | обработано строк: 330000 | позиций в батче: 99705 | всего позиций: 9011956
# [train] эп=1 | обработано строк: 335000 | позиций в батче: 93937 | всего позиций: 9105893
# [train] эп=1 | обработано строк: 340000 | позиций в батче: 91963 | всего позиций: 9197856
# [train] эп=1 | обработано строк: 345000 | позиций в батче: 93552 | всего позиций: 9291408
# [train] эп=1 | обработано строк: 350000 | позиций в батче: 104988 | всего позиций: 9396396
# [train] эп=1 | обработано строк: 355000 | позиций в батче: 96028 | всего позиций: 9492424
# [train] эп=1 | обработано строк: 360000 | позиций в батче: 97295 | всего позиций: 9589719
# [train] эп=1 | обработано строк: 365000 | позиций в батче: 92984 | всего позиций: 9682703
# [train] эп=1 | обработано строк: 370000 | позиций в батче: 92976 | всего позиций: 9775679
# [train] эп=1 | обработано строк: 375000 | позиций в батче: 96941 | всего позиций: 9872620
# [train] эп=1 | обработано строк: 380000 | позиций в батче: 94801 | всего позиций: 9967421
# [train] эп=1 | обработано строк: 385000 | позиций в батче: 95906 | всего позиций: 10063327
# [train] эп=1 | обработано строк: 390000 | позиций в батче: 94334 | всего позиций: 10157661
# [train] эп=1 | обработано строк: 395000 | позиций в батче: 91502 | всего позиций: 10249163
# [train] эп=1 | обработано строк: 400000 | позиций в батче: 90820 | всего позиций: 10339983
# [train] эп=1 | обработано строк: 405000 | позиций в батче: 140451 | всего позиций: 10480434
# [train] эп=1 | обработано строк: 410000 | позиций в батче: 130165 | всего позиций: 10610599
# [train] эп=1 | обработано строк: 415000 | позиций в батче: 128658 | всего позиций: 10739257
# [train] эп=1 | обработано строк: 420000 | позиций в батче: 129524 | всего позиций: 10868781
# [train] эп=1 | обработано строк: 425000 | позиций в батче: 118488 | всего позиций: 10987269
# [train] эп=1 | обработано строк: 430000 | позиций в батче: 116738 | всего позиций: 11104007
# [train] эп=1 | обработано строк: 435000 | позиций в батче: 133099 | всего позиций: 11237106
# [train] эп=1 | обработано строк: 440000 | позиций в батче: 108428 | всего позиций: 11345534
# [train] эп=1 | обработано строк: 445000 | позиций в батче: 92485 | всего позиций: 11438019
# [train] эп=1 | обработано строк: 450000 | позиций в батче: 97295 | всего позиций: 11535314
# [train] эп=1 | обработано строк: 455000 | позиций в батче: 123396 | всего позиций: 11658710
# [train] эп=1 | обработано строк: 460000 | позиций в батче: 130115 | всего позиций: 11788825
# [train] эп=1 | обработано строк: 465000 | позиций в батче: 140566 | всего позиций: 11929391
# [train] эп=1 | обработано строк: 470000 | позиций в батче: 139455 | всего позиций: 12068846
# [train] эп=1 | обработано строк: 475000 | позиций в батче: 147319 | всего позиций: 12216165
# [train] эп=1 | обработано строк: 480000 | позиций в батче: 133504 | всего позиций: 12349669
# [train] эп=1 | обработано строк: 485000 | позиций в батче: 146099 | всего позиций: 12495768
# [train] эп=1 | обработано строк: 490000 | позиций в батче: 147989 | всего позиций: 12643757
# [train] эп=1 | обработано строк: 495000 | позиций в батче: 144634 | всего позиций: 12788391
# [train] эп=1 | обработано строк: 500000 | позиций в батче: 146948 | всего позиций: 12935339
# [train] эп=1 | обработано строк: 505000 | позиций в батче: 143976 | всего позиций: 13079315
# [train] эп=1 | обработано строк: 510000 | позиций в батче: 152563 | всего позиций: 13231878
# [train] эп=1 | обработано строк: 515000 | позиций в батче: 149722 | всего позиций: 13381600
# [train] эп=1 | обработано строк: 520000 | позиций в батче: 136160 | всего позиций: 13517760
# [train] эп=1 | обработано строк: 525000 | позиций в батче: 147105 | всего позиций: 13664865
# [train] эп=1 | обработано строк: 530000 | позиций в батче: 141108 | всего позиций: 13805973
# [train] эп=1 | обработано строк: 535000 | позиций в батче: 144939 | всего позиций: 13950912
# [train] эп=1 | обработано строк: 540000 | позиций в батче: 149581 | всего позиций: 14100493
# [train] эп=1 | обработано строк: 545000 | позиций в батче: 142574 | всего позиций: 14243067
# [train] эп=1 | обработано строк: 550000 | позиций в батче: 143548 | всего позиций: 14386615
# [train] эп=1 | обработано строк: 555000 | позиций в батче: 118375 | всего позиций: 14504990
# [train] эп=1 | обработано строк: 560000 | позиций в батче: 145820 | всего позиций: 14650810
# [train] эп=1 | обработано строк: 565000 | позиций в батче: 146428 | всего позиций: 14797238
# [train] эп=1 | обработано строк: 570000 | позиций в батче: 142807 | всего позиций: 14940045
# [train] эп=1 | обработано строк: 575000 | позиций в батче: 137257 | всего позиций: 15077302
# [train] эп=1 | обработано строк: 580000 | позиций в батче: 144617 | всего позиций: 15221919
# [train] эп=1 | обработано строк: 585000 | позиций в батче: 139296 | всего позиций: 15361215
# [train] эп=1 | обработано строк: 590000 | позиций в батче: 143493 | всего позиций: 15504708
# [train] эп=1 | обработано строк: 595000 | позиций в батче: 132070 | всего позиций: 15636778
# [train] эп=1 | обработано строк: 600000 | позиций в батче: 144787 | всего позиций: 15781565
# [train] эп=1 | обработано строк: 605000 | позиций в батче: 152247 | всего позиций: 15933812
# [train] эп=1 | обработано строк: 610000 | позиций в батче: 158375 | всего позиций: 16092187
# [train] эп=1 | обработано строк: 615000 | позиций в батче: 166632 | всего позиций: 16258819
# [train] эп=1 | обработано строк: 620000 | позиций в батче: 142458 | всего позиций: 16401277
# [train] эп=1 | обработано строк: 625000 | позиций в батче: 146079 | всего позиций: 16547356
# [train] эп=1 | обработано строк: 630000 | позиций в батче: 149948 | всего позиций: 16697304
# [train] эп=1 | обработано строк: 635000 | позиций в батче: 146356 | всего позиций: 16843660
# [train] эп=1 | обработано строк: 640000 | позиций в батче: 144745 | всего позиций: 16988405
# [train] эп=1 | обработано строк: 645000 | позиций в батче: 148102 | всего позиций: 17136507
# [train] эп=1 | обработано строк: 650000 | позиций в батче: 128340 | всего позиций: 17264847
# [train] эп=1 | обработано строк: 655000 | позиций в батче: 147672 | всего позиций: 17412519
# [train] эп=1 | обработано строк: 660000 | позиций в батче: 144866 | всего позиций: 17557385
# [train] эп=1 | обработано строк: 665000 | позиций в батче: 141999 | всего позиций: 17699384
# [train] эп=1 | обработано строк: 670000 | позиций в батче: 136877 | всего позиций: 17836261
# [train] эп=1 | обработано строк: 675000 | позиций в батче: 135578 | всего позиций: 17971839
# [train] эп=1 | обработано строк: 680000 | позиций в батче: 144641 | всего позиций: 18116480
# [train] эп=1 | обработано строк: 685000 | позиций в батче: 136931 | всего позиций: 18253411
# [train] эп=1 | обработано строк: 690000 | позиций в батче: 131239 | всего позиций: 18384650
# [train] эп=1 | обработано строк: 695000 | позиций в батче: 134925 | всего позиций: 18519575
# [train] эп=1 | обработано строк: 700000 | позиций в батче: 144936 | всего позиций: 18664511
# [train] эп=1 | обработано строк: 705000 | позиций в батче: 145958 | всего позиций: 18810469
# [train] эп=1 | обработано строк: 710000 | позиций в батче: 130895 | всего позиций: 18941364
# [train] эп=1 | обработано строк: 715000 | позиций в батче: 132481 | всего позиций: 19073845
# [train] эп=1 | обработано строк: 720000 | позиций в батче: 128926 | всего позиций: 19202771
# [train] эп=1 | обработано строк: 725000 | позиций в батче: 127929 | всего позиций: 19330700
# [train] эп=1 | обработано строк: 730000 | позиций в батче: 144876 | всего позиций: 19475576
# [train] эп=1 | обработано строк: 735000 | позиций в батче: 126060 | всего позиций: 19601636
# [train] эп=1 | обработано строк: 740000 | позиций в батче: 118443 | всего позиций: 19720079
# [train] эп=1 | обработано строк: 745000 | позиций в батче: 132834 | всего позиций: 19852913
# [train] эп=1 | обработано строк: 750000 | позиций в батче: 114779 | всего позиций: 19967692
# [train] эп=1 | обработано строк: 755000 | позиций в батче: 106454 | всего позиций: 20074146
# [train] эп=1 | обработано строк: 760000 | позиций в батче: 130242 | всего позиций: 20204388
# [train] эп=1 | обработано строк: 765000 | позиций в батче: 101962 | всего позиций: 20306350
# [train] эп=1 | обработано строк: 770000 | позиций в батче: 123127 | всего позиций: 20429477
# [train] эп=1 | обработано строк: 775000 | позиций в батче: 123370 | всего позиций: 20552847
# [train] эп=1 | обработано строк: 780000 | позиций в батче: 129250 | всего позиций: 20682097
# [train] эп=1 | обработано строк: 785000 | позиций в батче: 139088 | всего позиций: 20821185
# [train] эп=1 | обработано строк: 790000 | позиций в батче: 128967 | всего позиций: 20950152
# [train] эп=1 | обработано строк: 795000 | позиций в батче: 129423 | всего позиций: 21079575
# [train] эп=1 | обработано строк: 800000 | позиций в батче: 141545 | всего позиций: 21221120
# [train] эп=1 | обработано строк: 805000 | позиций в батче: 136126 | всего позиций: 21357246
# [train] эп=1 | обработано строк: 810000 | позиций в батче: 127911 | всего позиций: 21485157
# [train] эп=1 | обработано строк: 815000 | позиций в батче: 145392 | всего позиций: 21630549
# [train] эп=1 | обработано строк: 820000 | позиций в батче: 130493 | всего позиций: 21761042
# [train] эп=1 | обработано строк: 825000 | позиций в батче: 136786 | всего позиций: 21897828
# [train] эп=1 | обработано строк: 830000 | позиций в батче: 140719 | всего позиций: 22038547
# [train] эп=1 | обработано строк: 835000 | позиций в батче: 135976 | всего позиций: 22174523
# [train] эп=1 | обработано строк: 840000 | позиций в батче: 149792 | всего позиций: 22324315
# [train] эп=1 | обработано строк: 845000 | позиций в батче: 151330 | всего позиций: 22475645
# [train] эп=1 | обработано строк: 850000 | позиций в батче: 155124 | всего позиций: 22630769
# [train] эп=1 | обработано строк: 855000 | позиций в батче: 133773 | всего позиций: 22764542
# [train] эп=1 | обработано строк: 860000 | позиций в батче: 134159 | всего позиций: 22898701
# [train] эп=1 | обработано строк: 865000 | позиций в батче: 126374 | всего позиций: 23025075
# [train] эп=1 | обработано строк: 870000 | позиций в батче: 136170 | всего позиций: 23161245
# [train] эп=1 | обработано строк: 875000 | позиций в батче: 131044 | всего позиций: 23292289
# [train] эп=1 | обработано строк: 880000 | позиций в батче: 138664 | всего позиций: 23430953
# [train] эп=1 | обработано строк: 885000 | позиций в батче: 140941 | всего позиций: 23571894
# [train] эп=1 | обработано строк: 890000 | позиций в батче: 145905 | всего позиций: 23717799
# [train] эп=1 | обработано строк: 895000 | позиций в батче: 147639 | всего позиций: 23865438
# [train] эп=1 | обработано строк: 900000 | позиций в батче: 127172 | всего позиций: 23992610
# [train] эп=1 | обработано строк: 905000 | позиций в батче: 128781 | всего позиций: 24121391
# [train] эп=1 | обработано строк: 910000 | позиций в батче: 137861 | всего позиций: 24259252
# [train] эп=1 | обработано строк: 915000 | позиций в батче: 139347 | всего позиций: 24398599
# [train] эп=1 | обработано строк: 920000 | позиций в батче: 142938 | всего позиций: 24541537
# [train] эп=1 | обработано строк: 925000 | позиций в батче: 125895 | всего позиций: 24667432
# [train] эп=1 | обработано строк: 930000 | позиций в батче: 117250 | всего позиций: 24784682
# [train] эп=1 | обработано строк: 935000 | позиций в батче: 132149 | всего позиций: 24916831
# [train] эп=1 | обработано строк: 940000 | позиций в батче: 145234 | всего позиций: 25062065
# [train] эп=1 | обработано строк: 945000 | позиций в батче: 150513 | всего позиций: 25212578
# [train] эп=1 | обработано строк: 950000 | позиций в батче: 146852 | всего позиций: 25359430
# [train] эп=1 | обработано строк: 955000 | позиций в батче: 151084 | всего позиций: 25510514
# [train] эп=1 | обработано строк: 960000 | позиций в батче: 128025 | всего позиций: 25638539
# [train] эп=1 | обработано строк: 965000 | позиций в батче: 137782 | всего позиций: 25776321
# [train] эп=1 | обработано строк: 970000 | позиций в батче: 103006 | всего позиций: 25879327
# [train] эп=1 | обработано строк: 975000 | позиций в батче: 137032 | всего позиций: 26016359
# [train] эп=1 | обработано строк: 980000 | позиций в батче: 131983 | всего позиций: 26148342
# [train] эп=1 | обработано строк: 985000 | позиций в батче: 115120 | всего позиций: 26263462
# [train] эп=1 | обработано строк: 990000 | позиций в батче: 116077 | всего позиций: 26379539
# [train] эп=1 | обработано строк: 995000 | позиций в батче: 132492 | всего позиций: 26512031
# [train] эп=1 | обработано строк: 1000000 | позиций в батче: 148635 | всего позиций: 26660666
# [train] эп=1 | обработано строк: 1005000 | позиций в батче: 127642 | всего позиций: 26788308
# [train] эп=1 | обработано строк: 1010000 | позиций в батче: 143703 | всего позиций: 26932011
# [train] эп=1 | обработано строк: 1015000 | позиций в батче: 133052 | всего позиций: 27065063
# [train] эп=1 | обработано строк: 1020000 | позиций в батче: 131799 | всего позиций: 27196862
# [train] эп=1 | обработано строк: 1025000 | позиций в батче: 127156 | всего позиций: 27324018
# [train] эп=1 | обработано строк: 1030000 | позиций в батче: 155133 | всего позиций: 27479151
# [train] эп=1 | обработано строк: 1035000 | позиций в батче: 144595 | всего позиций: 27623746
# [train] эп=1 | обработано строк: 1040000 | позиций в батче: 145437 | всего позиций: 27769183
# [train] эп=1 | обработано строк: 1045000 | позиций в батче: 138155 | всего позиций: 27907338
# [train] эп=1 | обработано строк: 1050000 | позиций в батче: 149006 | всего позиций: 28056344
# [train] эп=1 | обработано строк: 1055000 | позиций в батче: 134858 | всего позиций: 28191202
# [train] эп=1 | обработано строк: 1060000 | позиций в батче: 137085 | всего позиций: 28328287
# [train] эп=1 | обработано строк: 1065000 | позиций в батче: 131667 | всего позиций: 28459954
# [train] эп=1 | обработано строк: 1070000 | позиций в батче: 133680 | всего позиций: 28593634
# [train] эп=1 | обработано строк: 1075000 | позиций в батче: 139061 | всего позиций: 28732695
# [train] эп=1 | обработано строк: 1080000 | позиций в батче: 136958 | всего позиций: 28869653
# [train] эп=1 | обработано строк: 1085000 | позиций в батче: 147377 | всего позиций: 29017030
# [train] эп=1 | обработано строк: 1090000 | позиций в батче: 139390 | всего позиций: 29156420
# [train] эп=1 | обработано строк: 1095000 | позиций в батче: 145750 | всего позиций: 29302170
# [train] эп=1 | обработано строк: 1100000 | позиций в батче: 151617 | всего позиций: 29453787
# [train] эп=1 | обработано строк: 1105000 | позиций в батче: 153291 | всего позиций: 29607078
# [train] эп=1 | обработано строк: 1110000 | позиций в батче: 146838 | всего позиций: 29753916
# [train] эп=1 | обработано строк: 1115000 | позиций в батче: 133788 | всего позиций: 29887704
# [train] эп=1 | обработано строк: 1120000 | позиций в батче: 126312 | всего позиций: 30014016
# [train] эп=1 | обработано строк: 1125000 | позиций в батче: 160569 | всего позиций: 30174585
# [train] эп=1 | обработано строк: 1130000 | позиций в батче: 139326 | всего позиций: 30313911
# [train] эп=1 | обработано строк: 1135000 | позиций в батче: 126007 | всего позиций: 30439918
# [train] эп=1 | обработано строк: 1140000 | позиций в батче: 146971 | всего позиций: 30586889
# [train] эп=1 | обработано строк: 1145000 | позиций в батче: 138296 | всего позиций: 30725185
# [train] эп=1 | обработано строк: 1150000 | позиций в батче: 138096 | всего позиций: 30863281
# [train] эп=1 | обработано строк: 1155000 | позиций в батче: 145211 | всего позиций: 31008492
# [train] эп=1 | обработано строк: 1160000 | позиций в батче: 130133 | всего позиций: 31138625
# [train] эп=1 | обработано строк: 1165000 | позиций в батче: 130279 | всего позиций: 31268904
# [train] эп=1 | обработано строк: 1170000 | позиций в батче: 140326 | всего позиций: 31409230
# [train] эп=1 | обработано строк: 1175000 | позиций в батче: 149446 | всего позиций: 31558676
# [train] эп=1 | обработано строк: 1180000 | позиций в батче: 131969 | всего позиций: 31690645
# [train] эп=1 | обработано строк: 1185000 | позиций в батче: 121134 | всего позиций: 31811779
# [train] эп=1 | обработано строк: 1190000 | позиций в батче: 148086 | всего позиций: 31959865
# [train] эп=1 | обработано строк: 1195000 | позиций в батче: 137611 | всего позиций: 32097476
# [train] эп=1 | обработано строк: 1200000 | позиций в батче: 136013 | всего позиций: 32233489
# [train] эп=1 | обработано строк: 1205000 | позиций в батче: 139303 | всего позиций: 32372792
# [train] эп=1 | обработано строк: 1210000 | позиций в батче: 132437 | всего позиций: 32505229
# [train] эп=1 | обработано строк: 1215000 | позиций в батче: 117598 | всего позиций: 32622827
# [train] эп=1 | обработано строк: 1220000 | позиций в батче: 145929 | всего позиций: 32768756
# [train] эп=1 | обработано строк: 1225000 | позиций в батче: 123355 | всего позиций: 32892111
# [train] эп=1 | обработано строк: 1230000 | позиций в батче: 130756 | всего позиций: 33022867
# [train] эп=1 | обработано строк: 1235000 | позиций в батче: 123477 | всего позиций: 33146344
# [train] эп=1 | обработано строк: 1240000 | позиций в батче: 135641 | всего позиций: 33281985
# [train] эп=1 | обработано строк: 1245000 | позиций в батче: 127137 | всего позиций: 33409122
# [train] эп=1 | обработано строк: 1250000 | позиций в батче: 121625 | всего позиций: 33530747
# [train] эп=1 | обработано строк: 1255000 | позиций в батче: 135240 | всего позиций: 33665987
# [train] эп=1 | обработано строк: 1260000 | позиций в батче: 129841 | всего позиций: 33795828
# [train] эп=1 | обработано строк: 1265000 | позиций в батче: 127521 | всего позиций: 33923349
# [train] эп=1 | обработано строк: 1270000 | позиций в батче: 124750 | всего позиций: 34048099
# [train] эп=1 | обработано строк: 1275000 | позиций в батче: 130870 | всего позиций: 34178969
# [train] эп=1 | обработано строк: 1280000 | позиций в батче: 128466 | всего позиций: 34307435
# [train] эп=1 | обработано строк: 1285000 | позиций в батче: 126487 | всего позиций: 34433922
# [train] эп=1 | обработано строк: 1290000 | позиций в батче: 123558 | всего позиций: 34557480
# [train] эп=1 | обработано строк: 1295000 | позиций в батче: 140928 | всего позиций: 34698408
# [train] эп=1 | обработано строк: 1300000 | позиций в батче: 136930 | всего позиций: 34835338
# [train] эп=1 | обработано строк: 1305000 | позиций в батче: 136232 | всего позиций: 34971570
# [train] эп=1 | обработано строк: 1310000 | позиций в батче: 119961 | всего позиций: 35091531
# [train] эп=1 | обработано строк: 1315000 | позиций в батче: 146118 | всего позиций: 35237649
# [train] эп=1 | обработано строк: 1320000 | позиций в батче: 132365 | всего позиций: 35370014
# [train] эп=1 | обработано строк: 1325000 | позиций в батче: 140057 | всего позиций: 35510071
# [train] эп=1 | обработано строк: 1330000 | позиций в батче: 131019 | всего позиций: 35641090
# [train] эп=1 | обработано строк: 1335000 | позиций в батче: 133854 | всего позиций: 35774944
# [train] эп=1 | обработано строк: 1340000 | позиций в батче: 125743 | всего позиций: 35900687
# [train] эп=1 | обработано строк: 1345000 | позиций в батче: 148475 | всего позиций: 36049162
# [train] эп=1 | обработано строк: 1350000 | позиций в батче: 140106 | всего позиций: 36189268
# [train] эп=1 | обработано строк: 1355000 | позиций в батче: 137522 | всего позиций: 36326790
# [train] эп=1 | обработано строк: 1360000 | позиций в батче: 144872 | всего позиций: 36471662
# [train] эп=1 | обработано строк: 1365000 | позиций в батче: 140018 | всего позиций: 36611680
# [train] эп=1 | обработано строк: 1370000 | позиций в батче: 123746 | всего позиций: 36735426
# [train] эп=1 | обработано строк: 1375000 | позиций в батче: 136750 | всего позиций: 36872176
# [train] эп=1 | обработано строк: 1380000 | позиций в батче: 130017 | всего позиций: 37002193
# [train] эп=1 | обработано строк: 1385000 | позиций в батче: 136747 | всего позиций: 37138940
# [train] эп=1 | обработано строк: 1390000 | позиций в батче: 131569 | всего позиций: 37270509
# [train] эп=1 | обработано строк: 1395000 | позиций в батче: 145437 | всего позиций: 37415946
# [train] эп=1 | обработано строк: 1400000 | позиций в батче: 131893 | всего позиций: 37547839
# [train] эп=1 | обработано строк: 1405000 | позиций в батче: 140409 | всего позиций: 37688248
# [train] эп=1 | обработано строк: 1410000 | позиций в батче: 133674 | всего позиций: 37821922
# [train] эп=1 | обработано строк: 1415000 | позиций в батче: 109138 | всего позиций: 37931060
# [train] эп=1 | обработано строк: 1420000 | позиций в батче: 112456 | всего позиций: 38043516
# [train] эп=1 | обработано строк: 1425000 | позиций в батче: 123991 | всего позиций: 38167507
# [train] эп=1 | обработано строк: 1430000 | позиций в батче: 139522 | всего позиций: 38307029
# [train] эп=1 | обработано строк: 1435000 | позиций в батче: 136490 | всего позиций: 38443519
# [train] эп=1 | обработано строк: 1440000 | позиций в батче: 157150 | всего позиций: 38600669
# [train] эп=1 | обработано строк: 1445000 | позиций в батче: 140965 | всего позиций: 38741634
# [train] эп=1 | обработано строк: 1450000 | позиций в батче: 131082 | всего позиций: 38872716
# [train] эп=1 | обработано строк: 1455000 | позиций в батче: 121008 | всего позиций: 38993724
# [train] эп=1 | обработано строк: 1460000 | позиций в батче: 128861 | всего позиций: 39122585
# [train] эп=1 | обработано строк: 1465000 | позиций в батче: 141177 | всего позиций: 39263762
# [train] эп=1 | обработано строк: 1470000 | позиций в батче: 133876 | всего позиций: 39397638
# [train] эп=1 | обработано строк: 1475000 | позиций в батче: 142161 | всего позиций: 39539799
# [train] эп=1 | обработано строк: 1480000 | позиций в батче: 136643 | всего позиций: 39676442
# [train] эп=1 | обработано строк: 1485000 | позиций в батче: 121853 | всего позиций: 39798295
# [train] эп=1 | обработано строк: 1490000 | позиций в батче: 122637 | всего позиций: 39920932
# [train] эп=1 | обработано строк: 1495000 | позиций в батче: 136339 | всего позиций: 40057271
# [train] эп=1 | обработано строк: 1500000 | позиций в батче: 127924 | всего позиций: 40185195
# [train] эп=1 | обработано строк: 1505000 | позиций в батче: 134325 | всего позиций: 40319520
# [train] эп=1 | обработано строк: 1510000 | позиций в батче: 136994 | всего позиций: 40456514
# [train] эп=1 | обработано строк: 1515000 | позиций в батче: 129824 | всего позиций: 40586338
# [train] эп=1 | обработано строк: 1520000 | позиций в батче: 138278 | всего позиций: 40724616
# [train] эп=1 | обработано строк: 1525000 | позиций в батче: 125152 | всего позиций: 40849768
# [train] эп=1 | обработано строк: 1530000 | позиций в батче: 133882 | всего позиций: 40983650
# [train] эп=1 | обработано строк: 1535000 | позиций в батче: 124173 | всего позиций: 41107823
# [train] эп=1 | обработано строк: 1540000 | позиций в батче: 125392 | всего позиций: 41233215
# [train] эп=1 | обработано строк: 1545000 | позиций в батче: 136821 | всего позиций: 41370036
# [train] эп=1 | обработано строк: 1550000 | позиций в батче: 132030 | всего позиций: 41502066
# [train] эп=1 | обработано строк: 1555000 | позиций в батче: 145112 | всего позиций: 41647178
# [train] эп=1 | обработано строк: 1560000 | позиций в батче: 128535 | всего позиций: 41775713
# [train] эп=1 | обработано строк: 1565000 | позиций в батче: 131251 | всего позиций: 41906964
# [train] эп=1 | обработано строк: 1570000 | позиций в батче: 129445 | всего позиций: 42036409
# [train] эп=1 | обработано строк: 1575000 | позиций в батче: 134049 | всего позиций: 42170458
# [train] эп=1 | обработано строк: 1580000 | позиций в батче: 122485 | всего позиций: 42292943
# [train] эп=1 | обработано строк: 1585000 | позиций в батче: 127936 | всего позиций: 42420879
# [train] эп=1 | обработано строк: 1590000 | позиций в батче: 138239 | всего позиций: 42559118
# [train] эп=1 | обработано строк: 1595000 | позиций в батче: 114108 | всего позиций: 42673226
# [train] эп=1 | обработано строк: 1600000 | позиций в батче: 118800 | всего позиций: 42792026
# [train] эп=1 | обработано строк: 1605000 | позиций в батче: 126100 | всего позиций: 42918126
# [train] эп=1 | обработано строк: 1610000 | позиций в батче: 102956 | всего позиций: 43021082
# [train] эп=1 | обработано строк: 1615000 | позиций в батче: 112529 | всего позиций: 43133611
# [train] эп=1 | обработано строк: 1620000 | позиций в батче: 136377 | всего позиций: 43269988
# [train] эп=1 | обработано строк: 1625000 | позиций в батче: 126112 | всего позиций: 43396100
# [train] эп=1 | обработано строк: 1630000 | позиций в батче: 133455 | всего позиций: 43529555
# [train] эп=1 | обработано строк: 1635000 | позиций в батче: 139995 | всего позиций: 43669550
# [train] эп=1 | обработано строк: 1640000 | позиций в батче: 151112 | всего позиций: 43820662
# [train] эп=1 | обработано строк: 1645000 | позиций в батче: 116639 | всего позиций: 43937301
# [train] эп=1 | обработано строк: 1650000 | позиций в батче: 120593 | всего позиций: 44057894
# [train] эп=1 | обработано строк: 1655000 | позиций в батче: 126750 | всего позиций: 44184644
# [train] эп=1 | обработано строк: 1660000 | позиций в батче: 138906 | всего позиций: 44323550
# [train] эп=1 | обработано строк: 1665000 | позиций в батче: 129839 | всего позиций: 44453389
# [train] эп=1 | обработано строк: 1670000 | позиций в батче: 121358 | всего позиций: 44574747
# [train] эп=1 | обработано строк: 1675000 | позиций в батче: 126707 | всего позиций: 44701454
# [train] эп=1 | обработано строк: 1680000 | позиций в батче: 133624 | всего позиций: 44835078
# [train] эп=1 | обработано строк: 1685000 | позиций в батче: 119307 | всего позиций: 44954385
# [train] эп=1 | обработано строк: 1690000 | позиций в батче: 145498 | всего позиций: 45099883
# [train] эп=1 | обработано строк: 1695000 | позиций в батче: 139935 | всего позиций: 45239818
# [train] эп=1 | обработано строк: 1700000 | позиций в батче: 122778 | всего позиций: 45362596
# [train] эп=1 | обработано строк: 1705000 | позиций в батче: 136221 | всего позиций: 45498817
# [train] эп=1 | обработано строк: 1710000 | позиций в батче: 138055 | всего позиций: 45636872
# [train] эп=1 | обработано строк: 1715000 | позиций в батче: 134742 | всего позиций: 45771614
# [train] эп=1 | обработано строк: 1720000 | позиций в батче: 121685 | всего позиций: 45893299
# [train] эп=1 | обработано строк: 1725000 | позиций в батче: 135618 | всего позиций: 46028917
# [train] эп=1 | обработано строк: 1730000 | позиций в батче: 148041 | всего позиций: 46176958
# [train] эп=1 | обработано строк: 1735000 | позиций в батче: 130826 | всего позиций: 46307784
# [train] эп=1 | обработано строк: 1740000 | позиций в батче: 132726 | всего позиций: 46440510
# [train] эп=1 | обработано строк: 1745000 | позиций в батче: 144206 | всего позиций: 46584716
# [train] эп=1 | обработано строк: 1750000 | позиций в батче: 145225 | всего позиций: 46729941
# [train] эп=1 | обработано строк: 1755000 | позиций в батче: 136204 | всего позиций: 46866145
# [train] эп=1 | обработано строк: 1760000 | позиций в батче: 135775 | всего позиций: 47001920
# [train] эп=1 | обработано строк: 1765000 | позиций в батче: 139044 | всего позиций: 47140964
# [train] эп=1 | обработано строк: 1770000 | позиций в батче: 115714 | всего позиций: 47256678
# [train] эп=1 | обработано строк: 1775000 | позиций в батче: 150662 | всего позиций: 47407340
# [train] эп=1 | обработано строк: 1780000 | позиций в батче: 150633 | всего позиций: 47557973
# [train] эп=1 | обработано строк: 1785000 | позиций в батче: 138698 | всего позиций: 47696671
# [train] эп=1 | обработано строк: 1790000 | позиций в батче: 146047 | всего позиций: 47842718
# [train] эп=1 | обработано строк: 1795000 | позиций в батче: 140760 | всего позиций: 47983478
# [train] эп=1 | обработано строк: 1800000 | позиций в батче: 133990 | всего позиций: 48117468
# [train] эп=1 | обработано строк: 1805000 | позиций в батче: 135854 | всего позиций: 48253322
# [train] эп=1 | обработано строк: 1810000 | позиций в батче: 125333 | всего позиций: 48378655
# [train] эп=1 | обработано строк: 1815000 | позиций в батче: 142010 | всего позиций: 48520665
# [train] эп=1 | обработано строк: 1820000 | позиций в батче: 140203 | всего позиций: 48660868
# [train] эп=1 | обработано строк: 1825000 | позиций в батче: 135767 | всего позиций: 48796635
# [train] эп=1 | обработано строк: 1830000 | позиций в батче: 141527 | всего позиций: 48938162
# [train] эп=1 | обработано строк: 1835000 | позиций в батче: 92485 | всего позиций: 49030647
# [train] эп=1 | обработано строк: 1840000 | позиций в батче: 128675 | всего позиций: 49159322
# [train] эп=1 | обработано строк: 1845000 | позиций в батче: 147783 | всего позиций: 49307105
# [train] эп=1 | обработано строк: 1850000 | позиций в батче: 136600 | всего позиций: 49443705
# [train] эп=1 | обработано строк: 1855000 | позиций в батче: 142876 | всего позиций: 49586581
# [train] эп=1 | обработано строк: 1860000 | позиций в батче: 139350 | всего позиций: 49725931
# [train] эп=1 | обработано строк: 1865000 | позиций в батче: 132907 | всего позиций: 49858838
# [train] эп=1 | обработано строк: 1870000 | позиций в батче: 131998 | всего позиций: 49990836
# [train] эп=1 | обработано строк: 1875000 | позиций в батче: 131778 | всего позиций: 50122614
# [train] эп=1 | обработано строк: 1880000 | позиций в батче: 134344 | всего позиций: 50256958
# [train] эп=1 | обработано строк: 1885000 | позиций в батче: 153978 | всего позиций: 50410936
# [train] эп=1 | обработано строк: 1890000 | позиций в батче: 130862 | всего позиций: 50541798
# [train] эп=1 | обработано строк: 1895000 | позиций в батче: 125939 | всего позиций: 50667737
# [train] эп=1 | обработано строк: 1900000 | позиций в батче: 135251 | всего позиций: 50802988
# [train] эп=1 | обработано строк: 1905000 | позиций в батче: 132837 | всего позиций: 50935825
# [train] эп=1 | обработано строк: 1910000 | позиций в батче: 138751 | всего позиций: 51074576
# [train] эп=1 | обработано строк: 1915000 | позиций в батче: 132414 | всего позиций: 51206990
# [train] эп=1 | обработано строк: 1920000 | позиций в батче: 118557 | всего позиций: 51325547
# [train] эп=1 | обработано строк: 1925000 | позиций в батче: 135953 | всего позиций: 51461500
# [train] эп=1 | обработано строк: 1930000 | позиций в батче: 135631 | всего позиций: 51597131
# [train] эп=1 | обработано строк: 1935000 | позиций в батче: 128699 | всего позиций: 51725830
# [train] эп=1 | обработано строк: 1940000 | позиций в батче: 154116 | всего позиций: 51879946
# [train] эп=1 | обработано строк: 1945000 | позиций в батче: 141497 | всего позиций: 52021443
# [train] эп=1 | обработано строк: 1950000 | позиций в батче: 134810 | всего позиций: 52156253
# [train] эп=1 | обработано строк: 1955000 | позиций в батче: 126822 | всего позиций: 52283075
# [train] эп=1 | обработано строк: 1960000 | позиций в батче: 139225 | всего позиций: 52422300
# [train] эп=1 | обработано строк: 1965000 | позиций в батче: 133986 | всего позиций: 52556286
# [train] эп=1 | обработано строк: 1970000 | позиций в батче: 132350 | всего позиций: 52688636
# [train] эп=1 | обработано строк: 1975000 | позиций в батче: 135814 | всего позиций: 52824450
# [train] эп=1 | обработано строк: 1980000 | позиций в батче: 135433 | всего позиций: 52959883
# [train] эп=1 | обработано строк: 1985000 | позиций в батче: 140814 | всего позиций: 53100697
# [train] эп=1 | обработано строк: 1990000 | позиций в батче: 141121 | всего позиций: 53241818
# [train] эп=1 | обработано строк: 1995000 | позиций в батче: 143938 | всего позиций: 53385756
# [train] эп=1 | обработано строк: 2000000 | позиций в батче: 148599 | всего позиций: 53534355
# [train] эп=1 | обработано строк: 2005000 | позиций в батче: 125859 | всего позиций: 53660214
# [train] эп=1 | обработано строк: 2010000 | позиций в батче: 137800 | всего позиций: 53798014
# [train] эп=1 | обработано строк: 2015000 | позиций в батче: 137296 | всего позиций: 53935310
# [train] эп=1 | обработано строк: 2020000 | позиций в батче: 125876 | всего позиций: 54061186
# [train] эп=1 | обработано строк: 2025000 | позиций в батче: 144318 | всего позиций: 54205504
# [train] эп=1 | обработано строк: 2030000 | позиций в батче: 135274 | всего позиций: 54340778
# [train] эп=1 | обработано строк: 2035000 | позиций в батче: 121942 | всего позиций: 54462720
# [train] эп=1 | обработано строк: 2040000 | позиций в батче: 138456 | всего позиций: 54601176
# [train] эп=1 | обработано строк: 2045000 | позиций в батче: 145488 | всего позиций: 54746664
# [train] эп=1 | обработано строк: 2050000 | позиций в батче: 142230 | всего позиций: 54888894
# [train] эп=1 | обработано строк: 2055000 | позиций в батче: 124635 | всего позиций: 55013529
# [train] эп=1 | обработано строк: 2060000 | позиций в батче: 132194 | всего позиций: 55145723
# [train] эп=1 | обработано строк: 2065000 | позиций в батче: 130861 | всего позиций: 55276584
# [train] эп=1 | обработано строк: 2070000 | позиций в батче: 133738 | всего позиций: 55410322
# [train] эп=1 | обработано строк: 2075000 | позиций в батче: 125111 | всего позиций: 55535433
# [train] эп=1 | обработано строк: 2080000 | позиций в батче: 131958 | всего позиций: 55667391
# [train] эп=1 | обработано строк: 2085000 | позиций в батче: 137721 | всего позиций: 55805112
# [train] эп=1 | обработано строк: 2090000 | позиций в батче: 131378 | всего позиций: 55936490
# [train] эп=1 | обработано строк: 2095000 | позиций в батче: 131598 | всего позиций: 56068088
# [train] эп=1 | обработано строк: 2100000 | позиций в батче: 124201 | всего позиций: 56192289
# [train] эп=1 | обработано строк: 2105000 | позиций в батче: 126257 | всего позиций: 56318546
# [train] эп=1 | обработано строк: 2110000 | позиций в батче: 126997 | всего позиций: 56445543
# [train] эп=1 | обработано строк: 2115000 | позиций в батче: 134329 | всего позиций: 56579872
# [train] эп=1 | обработано строк: 2120000 | позиций в батче: 133664 | всего позиций: 56713536
# [train] эп=1 | обработано строк: 2125000 | позиций в батче: 134035 | всего позиций: 56847571
# [train] эп=1 | обработано строк: 2130000 | позиций в батче: 118559 | всего позиций: 56966130
# [train] эп=1 | обработано строк: 2135000 | позиций в батче: 113550 | всего позиций: 57079680
# [train] эп=1 | обработано строк: 2140000 | позиций в батче: 142723 | всего позиций: 57222403
# [train] эп=1 | обработано строк: 2145000 | позиций в батче: 134392 | всего позиций: 57356795
# [train] эп=1 | обработано строк: 2150000 | позиций в батче: 137720 | всего позиций: 57494515
# [train] эп=1 | обработано строк: 2155000 | позиций в батче: 138523 | всего позиций: 57633038
# [train] эп=1 | обработано строк: 2160000 | позиций в батче: 128413 | всего позиций: 57761451
# [train] эп=1 | обработано строк: 2165000 | позиций в батче: 123783 | всего позиций: 57885234
# [train] эп=1 | обработано строк: 2170000 | позиций в батче: 128127 | всего позиций: 58013361
# [train] эп=1 | обработано строк: 2175000 | позиций в батче: 137559 | всего позиций: 58150920
# [train] эп=1 | обработано строк: 2180000 | позиций в батче: 126319 | всего позиций: 58277239
# [train] эп=1 | обработано строк: 2185000 | позиций в батче: 140511 | всего позиций: 58417750
# [train] эп=1 | обработано строк: 2190000 | позиций в батче: 135747 | всего позиций: 58553497
# [train] эп=1 | обработано строк: 2195000 | позиций в батче: 141143 | всего позиций: 58694640
# [train] эп=1 | обработано строк: 2200000 | позиций в батче: 127344 | всего позиций: 58821984
# [train] эп=1 | обработано строк: 2205000 | позиций в батче: 135293 | всего позиций: 58957277
# [train] эп=1 | обработано строк: 2210000 | позиций в батче: 140809 | всего позиций: 59098086
# [train] эп=1 | обработано строк: 2215000 | позиций в батче: 128367 | всего позиций: 59226453
# [train] эп=1 | обработано строк: 2220000 | позиций в батче: 146567 | всего позиций: 59373020
# [train] эп=1 | обработано строк: 2225000 | позиций в батче: 142065 | всего позиций: 59515085
# [train] эп=1 | обработано строк: 2230000 | позиций в батче: 124356 | всего позиций: 59639441
# [train] эп=1 | обработано строк: 2235000 | позиций в батче: 115235 | всего позиций: 59754676
# [train] эп=1 | обработано строк: 2240000 | позиций в батче: 148741 | всего позиций: 59903417
# [train] эп=1 | обработано строк: 2245000 | позиций в батче: 132686 | всего позиций: 60036103
# [train] эп=1 | обработано строк: 2250000 | позиций в батче: 122565 | всего позиций: 60158668
# [train] эп=1 | обработано строк: 2255000 | позиций в батче: 130390 | всего позиций: 60289058
# [train] эп=1 | обработано строк: 2260000 | позиций в батче: 133124 | всего позиций: 60422182
# [train] эп=1 | обработано строк: 2265000 | позиций в батче: 143007 | всего позиций: 60565189
# [train] эп=1 | обработано строк: 2270000 | позиций в батче: 142777 | всего позиций: 60707966
# [train] эп=1 | обработано строк: 2275000 | позиций в батче: 131769 | всего позиций: 60839735
# [train] эп=1 | обработано строк: 2280000 | позиций в батче: 134089 | всего позиций: 60973824
# [train] эп=1 | обработано строк: 2285000 | позиций в батче: 148831 | всего позиций: 61122655
# [train] эп=1 | обработано строк: 2290000 | позиций в батче: 135887 | всего позиций: 61258542
# [train] эп=1 | обработано строк: 2295000 | позиций в батче: 145222 | всего позиций: 61403764
# [train] эп=1 | обработано строк: 2300000 | позиций в батче: 133059 | всего позиций: 61536823
# [train] эп=1 | обработано строк: 2305000 | позиций в батче: 130258 | всего позиций: 61667081
# [train] эп=1 | обработано строк: 2310000 | позиций в батче: 131224 | всего позиций: 61798305
# [train] эп=1 | обработано строк: 2315000 | позиций в батче: 140701 | всего позиций: 61939006
# [train] эп=1 | обработано строк: 2320000 | позиций в батче: 137055 | всего позиций: 62076061
# [train] эп=1 | обработано строк: 2325000 | позиций в батче: 129696 | всего позиций: 62205757
# [train] эп=1 | обработано строк: 2330000 | позиций в батче: 132027 | всего позиций: 62337784
# [train] эп=1 | обработано строк: 2335000 | позиций в батче: 135520 | всего позиций: 62473304
# [train] эп=1 | обработано строк: 2340000 | позиций в батче: 130289 | всего позиций: 62603593
# [train] эп=1 | обработано строк: 2345000 | позиций в батче: 131553 | всего позиций: 62735146
# [train] эп=1 | обработано строк: 2350000 | позиций в батче: 127699 | всего позиций: 62862845
# [train] эп=1 | обработано строк: 2355000 | позиций в батче: 137043 | всего позиций: 62999888
# [train] эп=1 | обработано строк: 2360000 | позиций в батче: 126524 | всего позиций: 63126412
# [train] эп=1 | обработано строк: 2365000 | позиций в батче: 132031 | всего позиций: 63258443
# [train] эп=1 | обработано строк: 2370000 | позиций в батче: 135436 | всего позиций: 63393879
# [train] эп=1 | обработано строк: 2375000 | позиций в батче: 126871 | всего позиций: 63520750
# [train] эп=1 | обработано строк: 2380000 | позиций в батче: 137144 | всего позиций: 63657894
# [train] эп=1 | обработано строк: 2385000 | позиций в батче: 129372 | всего позиций: 63787266
# [train] эп=1 | обработано строк: 2390000 | позиций в батче: 123203 | всего позиций: 63910469
# [train] эп=1 | обработано строк: 2395000 | позиций в батче: 133083 | всего позиций: 64043552
# [train] эп=1 | обработано строк: 2400000 | позиций в батче: 142629 | всего позиций: 64186181
# [train] эп=1 | обработано строк: 2405000 | позиций в батче: 135336 | всего позиций: 64321517
# [train] эп=1 | обработано строк: 2410000 | позиций в батче: 123006 | всего позиций: 64444523
# [train] эп=1 | обработано строк: 2415000 | позиций в батче: 124286 | всего позиций: 64568809
# [train] эп=1 | обработано строк: 2420000 | позиций в батче: 138859 | всего позиций: 64707668
# [train] эп=1 | обработано строк: 2425000 | позиций в батче: 123121 | всего позиций: 64830789
# [train] эп=1 | обработано строк: 2430000 | позиций в батче: 140422 | всего позиций: 64971211
# [train] эп=1 | обработано строк: 2435000 | позиций в батче: 135617 | всего позиций: 65106828
# [train] эп=1 | обработано строк: 2440000 | позиций в батче: 132576 | всего позиций: 65239404
# [train] эп=1 | обработано строк: 2445000 | позиций в батче: 93654 | всего позиций: 65333058
# [train] эп=1 | обработано строк: 2450000 | позиций в батче: 124709 | всего позиций: 65457767
# [train] эп=1 | обработано строк: 2455000 | позиций в батче: 136375 | всего позиций: 65594142
# [train] эп=1 | обработано строк: 2460000 | позиций в батче: 130391 | всего позиций: 65724533
# [train] эп=1 | обработано строк: 2465000 | позиций в батче: 123296 | всего позиций: 65847829
# [train] эп=1 | обработано строк: 2470000 | позиций в батче: 142823 | всего позиций: 65990652
# [train] эп=1 | обработано строк: 2475000 | позиций в батче: 132582 | всего позиций: 66123234
# [train] эп=1 | обработано строк: 2480000 | позиций в батче: 129786 | всего позиций: 66253020
# [train] эп=1 | обработано строк: 2485000 | позиций в батче: 126475 | всего позиций: 66379495
# [train] эп=1 | обработано строк: 2490000 | позиций в батче: 136892 | всего позиций: 66516387
# [train] эп=1 | обработано строк: 2495000 | позиций в батче: 124549 | всего позиций: 66640936
# [train] эп=1 | обработано строк: 2500000 | позиций в батче: 145961 | всего позиций: 66786897
# [train] эп=1 | обработано строк: 2505000 | позиций в батче: 146831 | всего позиций: 66933728
# [train] эп=1 | обработано строк: 2510000 | позиций в батче: 131818 | всего позиций: 67065546
# [train] эп=1 | обработано строк: 2515000 | позиций в батче: 123264 | всего позиций: 67188810
# [train] эп=1 | обработано строк: 2520000 | позиций в батче: 98557 | всего позиций: 67287367
# [train] эп=1 | обработано строк: 2525000 | позиций в батче: 123645 | всего позиций: 67411012
# [train] эп=1 | обработано строк: 2530000 | позиций в батче: 136636 | всего позиций: 67547648
# [train] эп=1 | обработано строк: 2535000 | позиций в батче: 140484 | всего позиций: 67688132
# [train] эп=1 | обработано строк: 2540000 | позиций в батче: 119515 | всего позиций: 67807647
# [train] эп=1 | обработано строк: 2545000 | позиций в батче: 130712 | всего позиций: 67938359
# [train] эп=1 | обработано строк: 2550000 | позиций в батче: 134750 | всего позиций: 68073109
# [train] эп=1 | обработано строк: 2555000 | позиций в батче: 135382 | всего позиций: 68208491
# [train] эп=1 | обработано строк: 2560000 | позиций в батче: 135725 | всего позиций: 68344216
# [train] эп=1 | обработано строк: 2565000 | позиций в батче: 124332 | всего позиций: 68468548
# [train] эп=1 | обработано строк: 2570000 | позиций в батче: 142399 | всего позиций: 68610947
# [train] эп=1 | обработано строк: 2575000 | позиций в батче: 119978 | всего позиций: 68730925
# [train] эп=1 | обработано строк: 2580000 | позиций в батче: 142252 | всего позиций: 68873177
# [train] эп=1 | обработано строк: 2585000 | позиций в батче: 130724 | всего позиций: 69003901
# [train] эп=1 | обработано строк: 2590000 | позиций в батче: 128711 | всего позиций: 69132612
# [train] эп=1 | обработано строк: 2595000 | позиций в батче: 140358 | всего позиций: 69272970
# ...
# [train] эп=2 | обработано строк: 3920000 | позиций в батче: 134761 | всего позиций: 231051795
# [train] эп=2 | обработано строк: 3925000 | позиций в батче: 131649 | всего позиций: 231183444
# [train] эп=2 | обработано строк: 3930000 | позиций в батче: 113553 | всего позиций: 231296997
# [train] эп=2 | обработано строк: 3935000 | позиций в батче: 116639 | всего позиций: 231413636
# [train] эп=2 | обработано строк: 3940000 | позиций в батче: 138992 | всего позиций: 231552628
# [train] эп=2 | обработано строк: 3945000 | позиций в батче: 127064 | всего позиций: 231679692
# [train] эп=2 | обработано строк: 3950000 | позиций в батче: 115673 | всего позиций: 231795365
# [train] эп=2 | обработано строк: 3955000 | позиций в батче: 119399 | всего позиций: 231914764
# [train] эп=2 | обработано строк: 3960000 | позиций в батче: 130760 | всего позиций: 232045524
# [train] эп=2 | обработано строк: 3965000 | позиций в батче: 125340 | всего позиций: 232170864
# [train] эп=2 | обработано строк: 3970000 | позиций в батче: 138052 | всего позиций: 232308916
# [train] эп=2 | обработано строк: 3975000 | позиций в батче: 133500 | всего позиций: 232442416
# [train] эп=2 | обработано строк: 3980000 | позиций в батче: 137677 | всего позиций: 232580093
# [train] эп=2 | обработано строк: 3985000 | позиций в батче: 131909 | всего позиций: 232712002
# [train] эп=2 | обработано строк: 3990000 | позиций в батче: 130257 | всего позиций: 232842259
# [train] эп=2 | обработано строк: 3995000 | позиций в батче: 138093 | всего позиций: 232980352
# [train] эп=2 | обработано строк: 4000000 | позиций в батче: 122844 | всего позиций: 233103196
# [train] эп=2 | обработано строк: 4005000 | позиций в батче: 125632 | всего позиций: 233228828
# [train] эп=2 | обработано строк: 4010000 | позиций в батче: 131736 | всего позиций: 233360564
# [train] эп=2 | обработано строк: 4015000 | позиций в батче: 134531 | всего позиций: 233495095
# [train] эп=2 | обработано строк: 4020000 | позиций в батче: 138605 | всего позиций: 233633700
# [train] эп=2 | обработано строк: 4025000 | позиций в батче: 134816 | всего позиций: 233768516
# [train] эп=2 | обработано строк: 4030000 | позиций в батче: 141128 | всего позиций: 233909644
# [train] эп=2 | обработано строк: 4035000 | позиций в батче: 127763 | всего позиций: 234037407
# [train] эп=2 | обработано строк: 4040000 | позиций в батче: 129046 | всего позиций: 234166453
# [train] эп=2 | обработано строк: 4045000 | позиций в батче: 120834 | всего позиций: 234287287
# [train] эп=2 | обработано строк: 4050000 | позиций в батче: 129104 | всего позиций: 234416391
# [train] эп=2 | обработано строк: 4055000 | позиций в батче: 134866 | всего позиций: 234551257
# [train] эп=2 | обработано строк: 4060000 | позиций в батче: 149371 | всего позиций: 234700628
# [train] эп=2 | обработано строк: 4065000 | позиций в батче: 128136 | всего позиций: 234828764
# [train] эп=2 | обработано строк: 4070000 | позиций в батче: 131696 | всего позиций: 234960460
# [train] эп=2 | обработано строк: 4075000 | позиций в батче: 131575 | всего позиций: 235092035
# [train] эп=2 | обработано строк: 4080000 | позиций в батче: 139710 | всего позиций: 235231745
# [train] эп=2 | обработано строк: 4085000 | позиций в батче: 123772 | всего позиций: 235355517
# [train] эп=2 | обработано строк: 4090000 | позиций в батче: 138509 | всего позиций: 235494026
# [train] эп=2 | обработано строк: 4095000 | позиций в батче: 143043 | всего позиций: 235637069
# [train] эп=2 | обработано строк: 4100000 | позиций в батче: 127088 | всего позиций: 235764157
# [train] эп=2 | обработано строк: 4105000 | позиций в батче: 142144 | всего позиций: 235906301
# [train] эп=2 | обработано строк: 4110000 | позиций в батче: 147932 | всего позиций: 236054233
# [train] эп=2 | обработано строк: 4115000 | позиций в батче: 118130 | всего позиций: 236172363
# [train] эп=2 | обработано строк: 4120000 | позиций в батче: 137244 | всего позиций: 236309607
# [train] эп=2 | обработано строк: 4125000 | позиций в батче: 129891 | всего позиций: 236439498
# [train] эп=2 | обработано строк: 4130000 | позиций в батче: 133450 | всего позиций: 236572948
# [train] эп=2 | обработано строк: 4135000 | позиций в батче: 146748 | всего позиций: 236719696
# [train] эп=2 | обработано строк: 4140000 | позиций в батче: 149053 | всего позиций: 236868749
# [train] эп=2 | обработано строк: 4145000 | позиций в батче: 137296 | всего позиций: 237006045
# [train] эп=2 | обработано строк: 4150000 | позиций в батче: 126241 | всего позиций: 237132286
# [train] эп=2 | обработано строк: 4155000 | позиций в батче: 141606 | всего позиций: 237273892
# [train] эп=2 | обработано строк: 4160000 | позиций в батче: 107814 | всего позиций: 237381706
# [train] эп=2 | обработано строк: 4165000 | позиций в батче: 131298 | всего позиций: 237513004
# [train] эп=2 | обработано строк: 4170000 | позиций в батче: 124572 | всего позиций: 237637576
# [train] эп=2 | обработано строк: 4175000 | позиций в батче: 123740 | всего позиций: 237761316
# [train] эп=2 | обработано строк: 4180000 | позиций в батче: 135413 | всего позиций: 237896729
# [train] эп=2 | обработано строк: 4185000 | позиций в батче: 130077 | всего позиций: 238026806
# [train] эп=2 | обработано строк: 4190000 | позиций в батче: 133674 | всего позиций: 238160480
# [train] эп=2 | обработано строк: 4195000 | позиций в батче: 135305 | всего позиций: 238295785
# [train] эп=2 | обработано строк: 4200000 | позиций в батче: 117472 | всего позиций: 238413257
# [train] эп=2 | обработано строк: 4205000 | позиций в батче: 148304 | всего позиций: 238561561
# [train] эп=2 | обработано строк: 4210000 | позиций в батче: 127746 | всего позиций: 238689307
# [train] эп=2 | обработано строк: 4215000 | позиций в батче: 120893 | всего позиций: 238810200
# [train] эп=2 | обработано строк: 4220000 | позиций в батче: 129048 | всего позиций: 238939248
# [train] эп=2 | обработано строк: 4225000 | позиций в батче: 139586 | всего позиций: 239078834
# [train] эп=2 | обработано строк: 4230000 | позиций в батче: 113875 | всего позиций: 239192709
# [train] эп=2 | обработано строк: 4235000 | позиций в батче: 130569 | всего позиций: 239323278
# [train] эп=2 | обработано строк: 4240000 | позиций в батче: 132535 | всего позиций: 239455813
# [train] эп=2 | обработано строк: 4245000 | позиций в батче: 121601 | всего позиций: 239577414
# [train] эп=2 | обработано строк: 4250000 | позиций в батче: 144261 | всего позиций: 239721675
# [train] эп=2 | обработано строк: 4255000 | позиций в батче: 132965 | всего позиций: 239854640
# [train] эп=2 | обработано строк: 4260000 | позиций в батче: 131495 | всего позиций: 239986135
# [train] эп=2 | обработано строк: 4265000 | позиций в батче: 121970 | всего позиций: 240108105
# [train] эп=2 | обработано строк: 4270000 | позиций в батче: 125238 | всего позиций: 240233343
# [train] эп=2 | обработано строк: 4275000 | позиций в батче: 129360 | всего позиций: 240362703
# [train] эп=2 | обработано строк: 4280000 | позиций в батче: 129863 | всего позиций: 240492566
# [train] эп=2 | обработано строк: 4285000 | позиций в батче: 139694 | всего позиций: 240632260
# [train] эп=2 | обработано строк: 4290000 | позиций в батче: 129473 | всего позиций: 240761733
# [train] эп=2 | обработано строк: 4295000 | позиций в батче: 143070 | всего позиций: 240904803
# [train] эп=2 | обработано строк: 4300000 | позиций в батче: 133476 | всего позиций: 241038279
# [train] эп=2 | обработано строк: 4305000 | позиций в батче: 162980 | всего позиций: 241201259
# [train] эп=2 | обработано строк: 4310000 | позиций в батче: 142921 | всего позиций: 241344180
# [train] эп=2 | обработано строк: 4315000 | позиций в батче: 132862 | всего позиций: 241477042
# [train] эп=2 | обработано строк: 4320000 | позиций в батче: 132722 | всего позиций: 241609764
# [train] эп=2 | обработано строк: 4325000 | позиций в батче: 132385 | всего позиций: 241742149
# [train] эп=2 | обработано строк: 4330000 | позиций в батче: 130929 | всего позиций: 241873078
# [train] эп=2 | обработано строк: 4335000 | позиций в батче: 120307 | всего позиций: 241993385
# [train] эп=2 | обработано строк: 4340000 | позиций в батче: 141524 | всего позиций: 242134909
# [train] эп=2 | обработано строк: 4345000 | позиций в батче: 129272 | всего позиций: 242264181
# [train] эп=2 | обработано строк: 4350000 | позиций в батче: 138153 | всего позиций: 242402334
# [train] эп=2 | обработано строк: 4355000 | позиций в батче: 138749 | всего позиций: 242541083
# [train] эп=2 | обработано строк: 4360000 | позиций в батче: 123952 | всего позиций: 242665035
# [train] эп=2 | обработано строк: 4365000 | позиций в батче: 135522 | всего позиций: 242800557
# [train] эп=2 | обработано строк: 4370000 | позиций в батче: 134430 | всего позиций: 242934987
# [train] эп=2 | обработано строк: 4375000 | позиций в батче: 129495 | всего позиций: 243064482
# [train] эп=2 | обработано строк: 4380000 | позиций в батче: 145345 | всего позиций: 243209827
# [train] эп=2 | обработано строк: 4385000 | позиций в батче: 132500 | всего позиций: 243342327
# [train] эп=2 | обработано строк: 4390000 | позиций в батче: 138264 | всего позиций: 243480591
# [train] эп=2 | обработано строк: 4395000 | позиций в батче: 128705 | всего позиций: 243609296
# [train] эп=2 | обработано строк: 4400000 | позиций в батче: 133252 | всего позиций: 243742548
# [train] эп=2 | обработано строк: 4405000 | позиций в батче: 143910 | всего позиций: 243886458
# [train] эп=2 | обработано строк: 4410000 | позиций в батче: 139174 | всего позиций: 244025632
# [train] эп=2 | обработано строк: 4415000 | позиций в батче: 136923 | всего позиций: 244162555
# [train] эп=2 | обработано строк: 4420000 | позиций в батче: 139749 | всего позиций: 244302304
# [train] эп=2 | обработано строк: 4425000 | позиций в батче: 132706 | всего позиций: 244435010
# [train] эп=2 | обработано строк: 4430000 | позиций в батче: 121324 | всего позиций: 244556334
# [train] эп=2 | обработано строк: 4435000 | позиций в батче: 131073 | всего позиций: 244687407
# [train] эп=2 | обработано строк: 4440000 | позиций в батче: 131125 | всего позиций: 244818532
# [train] эп=2 | обработано строк: 4445000 | позиций в батче: 129221 | всего позиций: 244947753
# [train] эп=2 | обработано строк: 4450000 | позиций в батче: 143904 | всего позиций: 245091657
# [train] эп=2 | обработано строк: 4455000 | позиций в батче: 132593 | всего позиций: 245224250
# [train] эп=2 | обработано строк: 4460000 | позиций в батче: 142263 | всего позиций: 245366513
# [train] эп=2 | обработано строк: 4465000 | позиций в батче: 131604 | всего позиций: 245498117
# [train] эп=2 | обработано строк: 4470000 | позиций в батче: 114921 | всего позиций: 245613038
# [train] эп=2 | обработано строк: 4475000 | позиций в батче: 124269 | всего позиций: 245737307
# [train] эп=2 | обработано строк: 4480000 | позиций в батче: 112158 | всего позиций: 245849465
# [train] эп=2 | обработано строк: 4485000 | позиций в батче: 135955 | всего позиций: 245985420
# [train] эп=2 | обработано строк: 4490000 | позиций в батче: 138514 | всего позиций: 246123934
# [train] эп=2 | обработано строк: 4495000 | позиций в батче: 121562 | всего позиций: 246245496
# [train] эп=2 | обработано строк: 4500000 | позиций в батче: 123413 | всего позиций: 246368909
# [train] эп=2 | обработано строк: 4505000 | позиций в батче: 123335 | всего позиций: 246492244
# [train] эп=2 | обработано строк: 4510000 | позиций в батче: 138819 | всего позиций: 246631063
# [train] эп=2 | обработано строк: 4515000 | позиций в батче: 134107 | всего позиций: 246765170
# [train] эп=2 | обработано строк: 4520000 | позиций в батче: 138245 | всего позиций: 246903415
# [train] эп=2 | обработано строк: 4525000 | позиций в батче: 136893 | всего позиций: 247040308
# [train] эп=2 | обработано строк: 4530000 | позиций в батче: 125836 | всего позиций: 247166144
# [train] эп=2 | обработано строк: 4535000 | позиций в батче: 128886 | всего позиций: 247295030
# [train] эп=2 | обработано строк: 4540000 | позиций в батче: 131870 | всего позиций: 247426900
# [train] эп=2 | обработано строк: 4545000 | позиций в батче: 137670 | всего позиций: 247564570
# [train] эп=2 | обработано строк: 4550000 | позиций в батче: 127143 | всего позиций: 247691713
# [train] эп=2 | обработано строк: 4555000 | позиций в батче: 121216 | всего позиций: 247812929
# [train] эп=2 | обработано строк: 4560000 | позиций в батче: 119444 | всего позиций: 247932373
# [train] эп=2 | обработано строк: 4565000 | позиций в батче: 151338 | всего позиций: 248083711
# [train] эп=2 | обработано строк: 4570000 | позиций в батче: 131550 | всего позиций: 248215261
# [train] эп=2 | обработано строк: 4575000 | позиций в батче: 111190 | всего позиций: 248326451
# [train] эп=2 | обработано строк: 4580000 | позиций в батче: 141271 | всего позиций: 248467722
# [train] эп=2 | обработано строк: 4585000 | позиций в батче: 138509 | всего позиций: 248606231
# [train] эп=2 | обработано строк: 4590000 | позиций в батче: 147953 | всего позиций: 248754184
# [train] эп=2 | обработано строк: 4595000 | позиций в батче: 119166 | всего позиций: 248873350
# [train] эп=2 | обработано строк: 4600000 | позиций в батче: 122020 | всего позиций: 248995370
# [train] эп=2 | обработано строк: 4605000 | позиций в батче: 124643 | всего позиций: 249120013
# [train] эп=2 | обработано строк: 4610000 | позиций в батче: 129244 | всего позиций: 249249257
# [train] эп=2 | обработано строк: 4615000 | позиций в батче: 134886 | всего позиций: 249384143
# [train] эп=2 | обработано строк: 4620000 | позиций в батче: 133822 | всего позиций: 249517965
# [train] эп=2 | обработано строк: 4625000 | позиций в батче: 129051 | всего позиций: 249647016
# [train] эп=2 | обработано строк: 4630000 | позиций в батче: 130871 | всего позиций: 249777887
# [train] эп=2 | обработано строк: 4635000 | позиций в батче: 133924 | всего позиций: 249911811
# [train] эп=2 | обработано строк: 4640000 | позиций в батче: 135920 | всего позиций: 250047731
# [train] эп=2 | обработано строк: 4645000 | позиций в батче: 136809 | всего позиций: 250184540
# [train] эп=2 | обработано строк: 4650000 | позиций в батче: 124113 | всего позиций: 250308653
# [train] эп=2 | обработано строк: 4655000 | позиций в батче: 135305 | всего позиций: 250443958
# [train] эп=2 | обработано строк: 4660000 | позиций в батче: 144666 | всего позиций: 250588624
# [train] эп=2 | обработано строк: 4665000 | позиций в батче: 130522 | всего позиций: 250719146
# [train] эп=2 | обработано строк: 4670000 | позиций в батче: 133688 | всего позиций: 250852834
# [train] эп=2 | обработано строк: 4675000 | позиций в батче: 112474 | всего позиций: 250965308
# [train] эп=2 | обработано строк: 4680000 | позиций в батче: 139467 | всего позиций: 251104775
# [train] эп=2 | обработано строк: 4685000 | позиций в батче: 121035 | всего позиций: 251225810
# [train] эп=2 | обработано строк: 4690000 | позиций в батче: 121713 | всего позиций: 251347523
# [train] эп=2 | обработано строк: 4695000 | позиций в батче: 123157 | всего позиций: 251470680
# [train] эп=2 | обработано строк: 4700000 | позиций в батче: 127988 | всего позиций: 251598668
# [train] эп=2 | обработано строк: 4705000 | позиций в батче: 124037 | всего позиций: 251722705
# [train] эп=2 | обработано строк: 4710000 | позиций в батче: 96833 | всего позиций: 251819538
# [train] эп=2 | обработано строк: 4715000 | позиций в батче: 136355 | всего позиций: 251955893
# [train] эп=2 | обработано строк: 4720000 | позиций в батче: 117273 | всего позиций: 252073166
# [train] эп=2 | обработано строк: 4725000 | позиций в батче: 128967 | всего позиций: 252202133
# [train] эп=2 | обработано строк: 4730000 | позиций в батче: 142855 | всего позиций: 252344988
# [train] эп=2 | обработано строк: 4735000 | позиций в батче: 117032 | всего позиций: 252462020
# [train] эп=2 | обработано строк: 4740000 | позиций в батче: 121864 | всего позиций: 252583884
# [train] эп=2 | обработано строк: 4745000 | позиций в батче: 129242 | всего позиций: 252713126
# [train] эп=2 | обработано строк: 4750000 | позиций в батче: 123911 | всего позиций: 252837037
# [train] эп=2 | обработано строк: 4755000 | позиций в батче: 32594 | всего позиций: 252869631
# [train] эп=2 | хвост | позиций в батче: 13 | всего позиций: 252869644
#
# [train] готово. Всего позиций обучено: 252869644

# %%
from math import isfinite


def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))


def predict_probs_for_text(text: str):
    # Вернём proba для всех позиций 1..n-1
    n = len(text)
    if n <= 1:
        return np.zeros((0,), dtype=np.float32)
    feats = [boundary_features(text, pos, WINDOW, LEXICON)
             for pos in range(1, n)]
    X = HASher.transform(feats)
    # SGDClassifier даёт decision_function; переведём в proba через сигмоиду
    dec = clf.decision_function(X)
    probs = sigmoid(dec).astype(np.float32)
    return probs  # длины n-1, индекс 0 соответствует позиции 1 в строке


def f1_per_string(gold_set, pred_set):
    # gold_set, pred_set — множества позиций (целые индексы)
    if not gold_set and not pred_set:
        return 1.0
    if not gold_set and pred_set:
        return 0.0
    if gold_set and not pred_set:
        return 0.0
    tp = len(gold_set & pred_set)
    fp = len(pred_set - gold_set)
    fn = len(gold_set - pred_set)
    if tp == 0:
        return 0.0
    prec = tp / (tp + fp)
    rec = tp / (tp + fn)
    return 2 * prec * rec / (prec + rec)


def evaluate_on_val(val_path: Path, thresholds=THRESH_GRID):
    # Для подбора порога посчитаем proba для каждой строки один раз
    probs_list = []   # список np.array (длина = n-1)
    golds_list = []   # список set(int)
    lengths = []      # длина строки (n)
    cnt = 0
    for rec in iter_jsonl(val_path):
        text = rec["text_no_spaces"]
        gold = set(rec["boundaries"])
        p = predict_probs_for_text(text)
        probs_list.append(p)
        golds_list.append(gold)
        lengths.append(len(text))
        cnt += 1
        if cnt % 2000 == 0:
            print(f"[val] подготовлено строк: {cnt}")

    # Подбор порога
    best_thr = 0.5
    best_f1 = -1.0
    grid_scores = []
    for thr in thresholds:
        f1s = []
        for p, gold, n in zip(probs_list, golds_list, lengths):
            if n <= 1:
                f1s.append(1.0 if len(gold) == 0 else 0.0)
                continue
            # позиции 1..n-1, а p[0] соответствует позиции 1
            pred_pos = set((np.where(p >= thr)[0] + 1).tolist())
            f1s.append(f1_per_string(gold, pred_pos))
        mean_f1 = float(np.mean(f1s)) if f1s else 0.0
        grid_scores.append((thr, mean_f1))
        if mean_f1 > best_f1:
            best_f1 = mean_f1
            best_thr = thr
    print("\n[val] Порог → F1:")
    for thr, sc in grid_scores[:10]:
        print(f"  thr={thr:.3f}  F1={sc*100:.2f}")
    print("  ...")
    print(f"[val] ЛУЧШИЙ ПОРОГ: {best_thr:.3f} | F1={best_f1*100:.2f}")

    return best_thr, best_f1, grid_scores


best_thr, best_f1, grid = evaluate_on_val(VAL_PATH, thresholds=THRESH_GRID)
# Out:
# [val] подготовлено строк: 2000
# [val] подготовлено строк: 4000
# [val] подготовлено строк: 6000
# [val] подготовлено строк: 8000
# [val] подготовлено строк: 10000
# [val] подготовлено строк: 12000
# [val] подготовлено строк: 14000
# [val] подготовлено строк: 16000
# [val] подготовлено строк: 18000
# [val] подготовлено строк: 20000
# [val] подготовлено строк: 22000
# [val] подготовлено строк: 24000
# [val] подготовлено строк: 26000
# [val] подготовлено строк: 28000
# [val] подготовлено строк: 30000
# [val] подготовлено строк: 32000
# [val] подготовлено строк: 34000
# [val] подготовлено строк: 36000
# [val] подготовлено строк: 38000
# [val] подготовлено строк: 40000
# [val] подготовлено строк: 42000
# [val] подготовлено строк: 44000
# [val] подготовлено строк: 46000
# [val] подготовлено строк: 48000
# [val] подготовлено строк: 50000
# [val] подготовлено строк: 52000
# [val] подготовлено строк: 54000
# [val] подготовлено строк: 56000
# [val] подготовлено строк: 58000
# [val] подготовлено строк: 60000
# [val] подготовлено строк: 62000
# [val] подготовлено строк: 64000
# [val] подготовлено строк: 66000
# [val] подготовлено строк: 68000
# [val] подготовлено строк: 70000
# [val] подготовлено строк: 72000
# [val] подготовлено строк: 74000
# [val] подготовлено строк: 76000
# [val] подготовлено строк: 78000
# [val] подготовлено строк: 80000
# [val] подготовлено строк: 82000
# [val] подготовлено строк: 84000
# [val] подготовлено строк: 86000
# [val] подготовлено строк: 88000
# [val] подготовлено строк: 90000
# [val] подготовлено строк: 92000
# [val] подготовлено строк: 94000
# [val] подготовлено строк: 96000
# [val] подготовлено строк: 98000
# [val] подготовлено строк: 100000
# [val] подготовлено строк: 102000
# [val] подготовлено строк: 104000
# [val] подготовлено строк: 106000
# [val] подготовлено строк: 108000
# [val] подготовлено строк: 110000
# [val] подготовлено строк: 112000
# [val] подготовлено строк: 114000
# [val] подготовлено строк: 116000
# [val] подготовлено строк: 118000
# [val] подготовлено строк: 120000
# [val] подготовлено строк: 122000
# [val] подготовлено строк: 124000
# [val] подготовлено строк: 126000
# [val] подготовлено строк: 128000
# [val] подготовлено строк: 130000
# [val] подготовлено строк: 132000
# [val] подготовлено строк: 134000
# [val] подготовлено строк: 136000
# [val] подготовлено строк: 138000
# [val] подготовлено строк: 140000
# [val] подготовлено строк: 142000
# [val] подготовлено строк: 144000
# [val] подготовлено строк: 146000
# [val] подготовлено строк: 148000
# [val] подготовлено строк: 150000
# [val] подготовлено строк: 152000
# [val] подготовлено строк: 154000
# [val] подготовлено строк: 156000
# [val] подготовлено строк: 158000
# [val] подготовлено строк: 160000
# [val] подготовлено строк: 162000
# [val] подготовлено строк: 164000
# [val] подготовлено строк: 166000
# [val] подготовлено строк: 168000
# [val] подготовлено строк: 170000
# [val] подготовлено строк: 172000
# [val] подготовлено строк: 174000
# [val] подготовлено строк: 176000
# [val] подготовлено строк: 178000
# [val] подготовлено строк: 180000
# [val] подготовлено строк: 182000
# [val] подготовлено строк: 184000
# [val] подготовлено строк: 186000
# [val] подготовлено строк: 188000
# [val] подготовлено строк: 190000
# [val] подготовлено строк: 192000
# [val] подготовлено строк: 194000
# [val] подготовлено строк: 196000
# [val] подготовлено строк: 198000
# [val] подготовлено строк: 200000
# [val] подготовлено строк: 202000
# [val] подготовлено строк: 204000
# [val] подготовлено строк: 206000
# [val] подготовлено строк: 208000
# [val] подготовлено строк: 210000
# [val] подготовлено строк: 212000
# [val] подготовлено строк: 214000
# [val] подготовлено строк: 216000
# [val] подготовлено строк: 218000
# [val] подготовлено строк: 220000
# [val] подготовлено строк: 222000
# [val] подготовлено строк: 224000
# [val] подготовлено строк: 226000
# [val] подготовлено строк: 228000
# [val] подготовлено строк: 230000
# [val] подготовлено строк: 232000
# [val] подготовлено строк: 234000
# [val] подготовлено строк: 236000
# [val] подготовлено строк: 238000
# [val] подготовлено строк: 240000
# [val] подготовлено строк: 242000
# [val] подготовлено строк: 244000
# [val] подготовлено строк: 246000
# [val] подготовлено строк: 248000
#
# [val] Порог → F1:
#   thr=0.100  F1=62.03
#   thr=0.125  F1=64.40
#   thr=0.150  F1=66.32
#   thr=0.175  F1=67.88
#   thr=0.200  F1=69.23
#   thr=0.225  F1=70.34
#   thr=0.250  F1=71.28
#   thr=0.275  F1=72.11
#   thr=0.300  F1=72.82
#   thr=0.325  F1=73.44
#   ...
# [val] ЛУЧШИЙ ПОРОГ: 0.525 | F1=75.72

# %%
import json

# Сохраняем модель и конфиг
joblib.dump(clf, MODEL_PATH)
with CFG_PATH.open("w", encoding="utf-8") as f:
    json.dump({
        "window": WINDOW,
        "n_features": N_FEATURES,
        "neg_downsample": NEGATIVE_DOWNSAMPLE,
        "alpha": ALPHA,
        "use_unigram": bool(LEXICON is not None),
        "unigram_min_count": UNIGRAM_MIN_COUNT if LEXICON is not None else None,
        "seed": SEED
    }, f, ensure_ascii=False, indent=2)

with THR_PATH.open("w", encoding="utf-8") as f:
    f.write(f"{best_thr:.6f}\n")

print("Сохранено:")
print("  Модель:", MODEL_PATH.resolve())
print("  Конфиг:", CFG_PATH.resolve())
print("  Порог :", THR_PATH.resolve())

# Быстрая sanity-проверка на нескольких строках из вал


def restore_with_positions(text_no_spaces: str, positions: set[int]) -> str:
    chars = list(text_no_spaces)
    for pos in sorted(positions, reverse=True):
        if 0 < pos < len(chars):  # вставляем между символами
            chars.insert(pos, " ")
    return "".join(chars)


samples_shown = 0
for rec in iter_jsonl(VAL_PATH):
    text = rec["text_no_spaces"]
    gold = set(rec["boundaries"])
    probs = predict_probs_for_text(text)
    preds = set((np.where(probs >= best_thr)[0] + 1).tolist())
    s_gold = restore_with_positions(text, gold)
    s_pred = restore_with_positions(text, preds)
    print("no_spaces:", text[:120])
    print("GOLD     :", s_gold[:120])
    print("PRED     :", s_pred[:120])
    print("F1 =", f1_per_string(gold, preds))
    print("---")
    samples_shown += 1
    if samples_shown >= 5:
        break
# Out:
# Сохранено:
#   Модель: /Users/strafe/VSCode-Projects/Avito-Test/artifacts_boundary/boundary_sgd.joblib
#   Конфиг: /Users/strafe/VSCode-Projects/Avito-Test/artifacts_boundary/config_boundary.json
#   Порог : /Users/strafe/VSCode-Projects/Avito-Test/artifacts_boundary/best_threshold.txt
# no_spaces: Литва́(),официальноеназвание—Лито́вскаяРеспу́блика()—государство,расположенноевСевернойЕвропе.
# GOLD     : Литва́ ( ), официальное название — Лито́вская Респу́блика ( ) — государство, расположенное в Северной Европе .
# PRED     : Литва́ (), официальное на звание — Лито́вская Респу́блика () — государство, рас положенное в Северной Европе.
# F1 = 0.8387096774193549
# ---
# no_spaces: Так,например,существуютсозвучныетопонимынатерриторииСловакии(Lytva)иРумынии(Litua),известныесXI—XIIвеков.
# GOLD     : Так, например, существуют созвучные топонимы на территории Словакии (Lytva) и Румынии (Litua), известные с XI—XII веков
# PRED     : Так, на пример, существ ую т созвучные топонимынатерритории Словакии (Lytva) и Румынии (Litua), из вестные с XI— XII век
# F1 = 0.7647058823529411
# ---
# no_spaces: Феодальноекняжество,поземлямкоторогопротекалаэтарека,современемзаняловедущееположениеиназваниебылораспространенонавсёгос
# GOLD     : Феодальное княжество, по землям которого протекала эта река, со временем заняло ведущее положение и название было распро
# PRED     : Феодальное кня жество, поземлямкоторого протекала этарека, со в ременем заняло ведущее положение и название былораспрост
# F1 = 0.7567567567567567
# ---
# no_spaces: озёр(1,5%территории),крупнейшееизкоторых—ДрукшяйнаграницеЛатвии,ЛитвыиБеларуси(площадь—44,8км2),самоеглубокое—Таурагнас(
# GOLD     : озёр (1,5 % территории), крупнейшее из которых — Друкшяй на границе Латвии, Литвы и Беларуси (площадь — 44,8 км2), самое
# PRED     : озёр (1, 5 % территории), крупнейшее из которых — Друкшяй награнице Латвии, Литвы и Беларуси ( площадь — 44,8 км 2), сам
# F1 = 0.8767123287671232
# ---
# no_spaces: ВXIV—началеXVвекахтерриторияВеликогокняжестваЛитовскогостремительноросла,восновномзасчётприсоединенияземельЗападнойРуси.
# GOLD     : В XIV — начале XV веках территория Великого княжества Литовского стремительно росла, в основном за счёт присоединения зе
# PRED     : В XIV— начале XV веках территория Великогокня жества Литовского стремительноросла, воснов ном за счёт присоединения земе
# F1 = 0.8108108108108109
# ---

# %% [markdown]
# ## Декодер

# %%
from pathlib import Path
import json
import math
import numpy as np
from collections import Counter
from scipy import sparse
import joblib

# Пути
PREP_DIR = Path("prepared_corpus")
VAL_PATH = PREP_DIR / "val.jsonl"
UNIGRAM_PATH = PREP_DIR / "unigram_freq.tsv"

ART_DIR = Path("artifacts_boundary")
MODEL_PATH = ART_DIR / "boundary_sgd.joblib"
CFG_PATH = ART_DIR / "config_boundary.json"
THR_PATH = ART_DIR / "best_threshold.txt"  # пригодится для сравнения

# Проверки
assert MODEL_PATH.exists(), f"Нет модели: {MODEL_PATH}"
assert CFG_PATH.exists(),   f"Нет конфига: {CFG_PATH}"
assert VAL_PATH.exists(),   f"Нет валидации: {VAL_PATH}"
assert UNIGRAM_PATH.exists(), f"Нет униграмм: {UNIGRAM_PATH}"

# Загрузка
clf = joblib.load(MODEL_PATH)
cfg = json.loads(Path(CFG_PATH).read_text(encoding="utf-8"))
best_thr = float(Path(THR_PATH).read_text(
    encoding="utf-8").strip()) if THR_PATH.exists() else 0.5

# Важные гиперпараметры из Этапа 3
WINDOW = int(cfg["window"])
N_FEATURES = int(cfg["n_features"])
USE_UNIGRAM = bool(cfg["use_unigram"])
UNIGRAM_MIN_COUNT = int(cfg["unigram_min_count"] or 0)

print("Модель:", MODEL_PATH.name)
print("CFG   :", cfg)
print("best_thr из Этапа 3:", best_thr)
# Out:
# Модель: boundary_sgd.joblib
# CFG   : {'window': 5, 'n_features': 262144, 'neg_downsample': 0.3, 'alpha': 1e-05, 'use_unigram': True, 'unigram_min_count': 5, 'seed': 42}
# best_thr из Этапа 3: 0.525

# %%
from sklearn.feature_extraction import FeatureHasher

# Хешер без обучаемых параметров — достаточно восстановить по N_FEATURES
HASher = FeatureHasher(n_features=N_FEATURES,
                       input_type="dict", alternate_sign=False)

# Если функции признаков уже объявлены в ноутбуке (Этап 3), используем их.
# Если нет — определим здесь «идентичные»:


def is_cyr(ch: str) -> bool:
    return 'А' <= ch <= 'я' or ch in "Ёё"


def is_lat(ch: str) -> bool:
    oc = ord(ch)
    return (65 <= oc <= 90) or (97 <= oc <= 122)


def is_digit(ch: str) -> bool:
    return ch.isdigit()


def is_punct(ch: str) -> bool:
    return ch in r""".,;:!?-—()[]{}«»"'/\|+*=_~%^<>…"""


def cat(ch: str) -> str:
    if is_cyr(ch):
        return "cyr"
    if is_lat(ch):
        return "lat"
    if is_digit(ch):
        return "dig"
    if is_punct(ch):
        return "pnc"
    return "oth"


def trans(a: str, b: str) -> str:
    return f"{a}->{b}"


def is_word_char(ch: str) -> bool:
    return is_cyr(ch) or is_lat(ch) or is_digit(ch) or ch in "-_"


def local_tokens(text: str, pos: int) -> tuple[str, str, str]:
    n = len(text)
    i = pos - 1
    j = pos
    L = i
    while L >= 0 and is_word_char(text[L]):
        L -= 1
    left_tok = text[L+1:i+1]
    R = j
    while R < n and is_word_char(text[R]):
        R += 1
    right_tok = text[j:R]
    merged = (left_tok + right_tok) if (left_tok and right_tok) else ""
    return left_tok.lower(), right_tok.lower(), merged.lower()


# LEXICON соберём на следующем шаге из unigram_freq.tsv
LEXICON = None


def boundary_features(text: str, pos: int, window: int, lexicon=None) -> dict:
    feats = {}
    n = len(text)
    Lch = text[pos-1]
    Rch = text[pos]
    Lc = cat(Lch)
    Rc = cat(Rch)

    feats[f"LC:{Lch}"] = 1
    feats[f"RC:{Rch}"] = 1
    feats[f"LCAT:{Lc}"] = 1
    feats[f"RCAT:{Rc}"] = 1
    feats[f"TRAN:{trans(Lc,Rc)}"] = 1

    feats["L_isupper"] = 1 if Lch.isalpha() and Lch.isupper() else 0
    feats["R_isupper"] = 1 if Rch.isalpha() and Rch.isupper() else 0

    for k in range(1, window+1):
        if pos-1-k >= 0:
            ch = text[pos-1-k]
            feats[f"L{k}:{ch}"] = 1
            feats[f"L{k}C:{cat(ch)}"] = 1
        if pos+k < n:
            ch = text[pos+k]
            feats[f"R{k}:{ch}"] = 1
            feats[f"R{k}C:{cat(ch)}"] = 1

    feats["dig_to_alpha"] = 1 if (
        is_digit(Lch) and (is_cyr(Rch) or is_lat(Rch))) else 0
    feats["alpha_to_dig"] = 1 if (
        (is_cyr(Lch) or is_lat(Lch)) and is_digit(Rch)) else 0
    feats["cyr_to_lat"] = 1 if (is_cyr(Lch) and is_lat(Rch)) else 0
    feats["lat_to_cyr"] = 1 if (is_lat(Lch) and is_cyr(Rch)) else 0
    feats["punct_left"] = 1 if is_punct(Lch) else 0
    feats["punct_right"] = 1 if is_punct(Rch) else 0

    if lexicon is not None:
        lt, rt, merged = local_tokens(text, pos)
        feats["lex_left"] = 1 if lt and lt in lexicon else 0
        feats["lex_right"] = 1 if rt and rt in lexicon else 0
        feats["lex_merged"] = 1 if merged and merged in lexicon else 0
        feats["len_lt"] = len(lt)
        feats["len_rt"] = len(rt)
        feats["len_merged"] = len(merged)
    else:
        feats["len_lt"] = 0
        feats["len_rt"] = 0
        feats["len_merged"] = 0

    feats["rel_pos"] = pos / n
    feats["is_start_near"] = 1 if pos <= 2 else 0
    feats["is_end_near"] = 1 if (n - pos) <= 2 else 0
    return feats

# %%
class UnigramLM:
    def __init__(self, path: Path, min_count: int = 1, k: float = 0.5, lowercase: bool = True):
        """
        path: tsv word \t count
        k: add-k сглаживание (0.5 по умолчанию — хорошая середина)
        """
        self.k = float(k)
        self.lowercase = lowercase
        self.counts = {}
        total = 0
        vocab = 0

        with path.open("r", encoding="utf-8") as f:
            for line in f:
                w, c = line.rstrip("\n").split("\t")
                c = int(c)
                if c < min_count:
                    continue
                if lowercase:
                    w = w.lower()
                self.counts[w] = self.counts.get(w, 0) + c

        self.V = len(self.counts)
        self.N = sum(self.counts.values())

        # Предварительные лог-константы
        self._log_N_kV = math.log(self.N + self.k * max(self.V, 1))
        self._oov_log = math.log(self.k) - self._log_N_kV

    def logp(self, word: str) -> float:
        if not word:
            return self._oov_log
        w = word.lower() if self.lowercase else word
        cnt = self.counts.get(w, 0)
        if cnt == 0:
            return self._oov_log
        return math.log(cnt + self.k) - self._log_N_kV


# Загружаем лексикон: множество «известных слов» (флаги для признаков)
LEXICON = set()
with UNIGRAM_PATH.open("r", encoding="utf-8") as f:
    for line in f:
        w, c = line.rstrip("\n").split("\t")
        if int(c) >= UNIGRAM_MIN_COUNT:
            LEXICON.add(w.lower())

LM = UnigramLM(UNIGRAM_PATH, min_count=1, k=0.5, lowercase=True)

print("UnigramLM: V=", LM.V, "N=", LM.N, "OOV_log≈", round(LM._oov_log, 3))
print("LEXICON size:", len(LEXICON))
# Out:
# UnigramLM: V= 1570271 N= 50360333 OOV_log≈ -18.443
# LEXICON size: 385143

# %%
# === FIX: DP со "средним за символ" языком и бонусом словаря ===
def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))


def boundary_probs(text: str) -> np.ndarray:
    n = len(text)
    if n <= 1:
        return np.zeros((0,), dtype=np.float32)
    feats = [boundary_features(text, pos, WINDOW, LEXICON)
             for pos in range(1, n)]
    X = HASher.transform(feats)
    dec = clf.decision_function(X)
    return sigmoid(dec).astype(np.float32)


def safe_logit(p: float, eps=1e-6) -> float:
    p = min(max(p, eps), 1.0 - eps)
    return math.log(p) - math.log(1.0 - p)


def boundary_logits_from_probs(pvec: np.ndarray, eps=1e-6) -> np.ndarray:
    return np.array([safe_logit(float(p), eps) for p in pvec], dtype=np.float32)


# ТЮНИНГ (стартовые числа, подправь по val):
ALPHA = 3.0    # вес логитов классификатора границ
BETA = 0.20   # вес языкового слагаемого (за символ)
GAMMA = 0.02   # регуляризация длины
TAU = 0.30   # бонус, если слово в лексиконе (LEXICON)
# константный bias за каждую поставленную границу (можно 0.1..0.4 при недосегментации)
DELTA = 0.00
L_MAX = 20     # макс. длина слова


def length_reg(len_word: int) -> float:
    pen = 0.0
    if len_word <= 2:
        pen -= 0.8
    if len_word >= 25:
        pen -= (len_word - 24) * 0.15
    return pen


def dp_segment(text: str,
               alpha: float = ALPHA, beta: float = BETA, gamma: float = GAMMA,
               tau: float = TAU, delta: float = DELTA, L: int = L_MAX):
    n = len(text)
    if n <= 1:
        return set(), 0.0

    p = boundary_probs(text)                  # shape (n-1,)
    logit = boundary_logits_from_probs(p)     # shape (n-1,)

    dp = np.full(n + 1, -1e15, dtype=np.float64)
    bp = np.full(n + 1, -1, dtype=np.int32)
    dp[0] = 0.0

    for i in range(1, n + 1):
        j_min = max(0, i - L)
        best_local, best_j = -1e15, -1
        for j in range(i - 1, j_min - 1, -1):
            w = text[j:i]
            # Язык: средний лог-проб за символ (не копит штраф за число слов)
            lp_per_char = LM.logp(w) / max(1, len(w))
            # Бонус за словарность
            lex_bonus = tau if (w.lower() in LEXICON) else 0.0
            # Регуляризация длины
            reg = length_reg(len(w))
            # Скор границы перед словом (если не начало): логит + bias DELTA
            bscore = (alpha * logit[j - 1] + delta) if j > 0 else 0.0

            cur = dp[j] + beta * lp_per_char + lex_bonus + gamma * reg + bscore
            if cur > best_local:
                best_local, best_j = cur, j
        dp[i], bp[i] = best_local, best_j

    # backtrack → позиции пробелов
    pos = set()
    i = n
    while i > 0:
        j = int(bp[i])
        if j < 0:
            break
        if j > 0:
            pos.add(j)
        i = j
    return pos, float(dp[n])

# %%
def f1_per_string(gold_set, pred_set):
    if not gold_set and not pred_set:
        return 1.0
    if not gold_set or not pred_set:
        return 0.0
    tp = len(gold_set & pred_set)
    fp = len(pred_set - gold_set)
    fn = len(gold_set - pred_set)
    if tp == 0:
        return 0.0
    prec = tp / (tp + fp)
    rec = tp / (tp + fn)
    return 2 * prec * rec / (prec + rec)


# Оценка DP на валидации
f1s = []
cnt = 0
for line in Path(VAL_PATH).open("r", encoding="utf-8"):
    if not line.strip():
        continue
    rec = json.loads(line)
    text = rec["text_no_spaces"]
    gold = set(rec["boundaries"])
    pred, _ = dp_segment(text, alpha=ALPHA, beta=BETA, gamma=GAMMA, L=L_MAX)
    f1s.append(f1_per_string(gold, pred))
    cnt += 1
    if cnt % 2000 == 0:
        print(
            f"[val:DP] обработано {cnt} строк, текущий F1={np.mean(f1s)*100:.2f}")

mean_f1_dp = float(np.mean(f1s)) if f1s else 0.0
print(f"\n[val:DP] Средний F1 по позициям: {mean_f1_dp*100:.2f}")
# Out:
# [val:DP] обработано 2000 строк, текущий F1=76.14
# [val:DP] обработано 4000 строк, текущий F1=76.93
# [val:DP] обработано 6000 строк, текущий F1=77.44
# [val:DP] обработано 8000 строк, текущий F1=77.82
# [val:DP] обработано 10000 строк, текущий F1=78.18
# [val:DP] обработано 12000 строк, текущий F1=77.83
# [val:DP] обработано 14000 строк, текущий F1=77.84
# [val:DP] обработано 16000 строк, текущий F1=77.69
# [val:DP] обработано 18000 строк, текущий F1=78.34
# [val:DP] обработано 20000 строк, текущий F1=79.11
# [val:DP] обработано 22000 строк, текущий F1=79.29
# [val:DP] обработано 24000 строк, текущий F1=79.22
# [val:DP] обработано 26000 строк, текущий F1=78.92
# [val:DP] обработано 28000 строк, текущий F1=78.74
# [val:DP] обработано 30000 строк, текущий F1=78.52
# [val:DP] обработано 32000 строк, текущий F1=78.34
# [val:DP] обработано 34000 строк, текущий F1=78.19
# [val:DP] обработано 36000 строк, текущий F1=78.05
# [val:DP] обработано 38000 строк, текущий F1=78.01
# [val:DP] обработано 40000 строк, текущий F1=77.90
# [val:DP] обработано 42000 строк, текущий F1=77.83
# [val:DP] обработано 44000 строк, текущий F1=77.81
# [val:DP] обработано 46000 строк, текущий F1=77.75
# [val:DP] обработано 48000 строк, текущий F1=77.68
# [val:DP] обработано 50000 строк, текущий F1=77.62
# [val:DP] обработано 52000 строк, текущий F1=77.58
# [val:DP] обработано 54000 строк, текущий F1=77.58
# [val:DP] обработано 56000 строк, текущий F1=77.51
# [val:DP] обработано 58000 строк, текущий F1=77.46
# [val:DP] обработано 60000 строк, текущий F1=77.42
# [val:DP] обработано 62000 строк, текущий F1=77.42
# [val:DP] обработано 64000 строк, текущий F1=77.40
# [val:DP] обработано 66000 строк, текущий F1=77.40
# [val:DP] обработано 68000 строк, текущий F1=77.38
# [val:DP] обработано 70000 строк, текущий F1=77.33
# [val:DP] обработано 72000 строк, текущий F1=77.32
# [val:DP] обработано 74000 строк, текущий F1=77.31
# [val:DP] обработано 76000 строк, текущий F1=77.30
# [val:DP] обработано 78000 строк, текущий F1=77.31
# [val:DP] обработано 80000 строк, текущий F1=77.32
# [val:DP] обработано 82000 строк, текущий F1=77.32
# [val:DP] обработано 84000 строк, текущий F1=77.34
# [val:DP] обработано 86000 строк, текущий F1=77.34
# [val:DP] обработано 88000 строк, текущий F1=77.34
# [val:DP] обработано 90000 строк, текущий F1=77.34
# [val:DP] обработано 92000 строк, текущий F1=77.33
# [val:DP] обработано 94000 строк, текущий F1=77.35
# [val:DP] обработано 96000 строк, текущий F1=77.34
# [val:DP] обработано 98000 строк, текущий F1=77.36
# [val:DP] обработано 100000 строк, текущий F1=77.34
# [val:DP] обработано 102000 строк, текущий F1=77.34
# [val:DP] обработано 104000 строк, текущий F1=77.35
# [val:DP] обработано 106000 строк, текущий F1=77.33
# [val:DP] обработано 108000 строк, текущий F1=77.32
# [val:DP] обработано 110000 строк, текущий F1=77.33
# [val:DP] обработано 112000 строк, текущий F1=77.33
# [val:DP] обработано 114000 строк, текущий F1=77.36
# [val:DP] обработано 116000 строк, текущий F1=77.35
# [val:DP] обработано 118000 строк, текущий F1=77.35
# [val:DP] обработано 120000 строк, текущий F1=77.34
# [val:DP] обработано 122000 строк, текущий F1=77.31
# [val:DP] обработано 124000 строк, текущий F1=77.30
# [val:DP] обработано 126000 строк, текущий F1=77.29
# [val:DP] обработано 128000 строк, текущий F1=77.29
# [val:DP] обработано 130000 строк, текущий F1=77.28
# [val:DP] обработано 132000 строк, текущий F1=77.27
# [val:DP] обработано 134000 строк, текущий F1=77.31
# [val:DP] обработано 136000 строк, текущий F1=77.30
# [val:DP] обработано 138000 строк, текущий F1=77.31
# [val:DP] обработано 140000 строк, текущий F1=77.29
# [val:DP] обработано 142000 строк, текущий F1=77.30
# [val:DP] обработано 144000 строк, текущий F1=77.29
# [val:DP] обработано 146000 строк, текущий F1=77.30
# [val:DP] обработано 148000 строк, текущий F1=77.29
# [val:DP] обработано 150000 строк, текущий F1=77.28
# [val:DP] обработано 152000 строк, текущий F1=77.29
# [val:DP] обработано 154000 строк, текущий F1=77.29
# [val:DP] обработано 156000 строк, текущий F1=77.28
# [val:DP] обработано 158000 строк, текущий F1=77.28
# [val:DP] обработано 160000 строк, текущий F1=77.29
# [val:DP] обработано 162000 строк, текущий F1=77.31
# [val:DP] обработано 164000 строк, текущий F1=77.33
# [val:DP] обработано 166000 строк, текущий F1=77.34
# [val:DP] обработано 168000 строк, текущий F1=77.34
# [val:DP] обработано 170000 строк, текущий F1=77.32
# [val:DP] обработано 172000 строк, текущий F1=77.32
# [val:DP] обработано 174000 строк, текущий F1=77.33
# [val:DP] обработано 176000 строк, текущий F1=77.33
# [val:DP] обработано 178000 строк, текущий F1=77.32
# [val:DP] обработано 180000 строк, текущий F1=77.32
# [val:DP] обработано 182000 строк, текущий F1=77.32
# [val:DP] обработано 184000 строк, текущий F1=77.32
# [val:DP] обработано 186000 строк, текущий F1=77.31
# [val:DP] обработано 188000 строк, текущий F1=77.32
# [val:DP] обработано 190000 строк, текущий F1=77.32
# [val:DP] обработано 192000 строк, текущий F1=77.32
# [val:DP] обработано 194000 строк, текущий F1=77.33
# [val:DP] обработано 196000 строк, текущий F1=77.33
# [val:DP] обработано 198000 строк, текущий F1=77.34
# [val:DP] обработано 200000 строк, текущий F1=77.34
# [val:DP] обработано 202000 строк, текущий F1=77.35
# [val:DP] обработано 204000 строк, текущий F1=77.35
# [val:DP] обработано 206000 строк, текущий F1=77.35
# [val:DP] обработано 208000 строк, текущий F1=77.36
# [val:DP] обработано 210000 строк, текущий F1=77.37
# [val:DP] обработано 212000 строк, текущий F1=77.36
# [val:DP] обработано 214000 строк, текущий F1=77.37
# [val:DP] обработано 216000 строк, текущий F1=77.37
# [val:DP] обработано 218000 строк, текущий F1=77.37
# [val:DP] обработано 220000 строк, текущий F1=77.38
# [val:DP] обработано 222000 строк, текущий F1=77.38
# [val:DP] обработано 224000 строк, текущий F1=77.38
# [val:DP] обработано 226000 строк, текущий F1=77.39
# [val:DP] обработано 228000 строк, текущий F1=77.39
# [val:DP] обработано 230000 строк, текущий F1=77.39
# [val:DP] обработано 232000 строк, текущий F1=77.38
# [val:DP] обработано 234000 строк, текущий F1=77.39
# [val:DP] обработано 236000 строк, текущий F1=77.40
# [val:DP] обработано 238000 строк, текущий F1=77.39
# [val:DP] обработано 240000 строк, текущий F1=77.38
# [val:DP] обработано 242000 строк, текущий F1=77.38
# [val:DP] обработано 244000 строк, текущий F1=77.38
# [val:DP] обработано 246000 строк, текущий F1=77.38
# [val:DP] обработано 248000 строк, текущий F1=77.39
#
# [val:DP] Средний F1 по позициям: 77.39

# %%
# Жадный порог: ставим пробел там, где p >= best_thr (для сравнения)
def greedy_positions(text: str, thr: float) -> set[int]:
    p = boundary_probs(text)
    idx = (np.where(p >= thr)[0] + 1).tolist()  # p[0] -> позиция 1
    return set(idx)


f1s_greedy = []
cnt = 0
for line in Path(VAL_PATH).open("r", encoding="utf-8"):
    if not line.strip():
        continue
    rec = json.loads(line)
    text = rec["text_no_spaces"]
    gold = set(rec["boundaries"])
    pred = greedy_positions(text, best_thr)
    f1s_greedy.append(f1_per_string(gold, pred))
    cnt += 1
    if cnt % 2000 == 0:
        print(
            f"[val:Greedy] обработано {cnt} строк, текущий F1={np.mean(f1s_greedy)*100:.2f}")

mean_f1_greedy = float(np.mean(f1s_greedy)) if f1s_greedy else 0.0
print(f"\n[val:Greedy] Средний F1 по позициям: {mean_f1_greedy*100:.2f}")
print(
    f"[сравнение] DP - Greedy: {(mean_f1_dp-mean_f1_greedy)*100:.2f} пунктов")
# Out:
# [val:Greedy] обработано 2000 строк, текущий F1=74.05
# [val:Greedy] обработано 4000 строк, текущий F1=74.94
# [val:Greedy] обработано 6000 строк, текущий F1=75.44
# [val:Greedy] обработано 8000 строк, текущий F1=75.87
# [val:Greedy] обработано 10000 строк, текущий F1=76.23
# [val:Greedy] обработано 12000 строк, текущий F1=75.91
# [val:Greedy] обработано 14000 строк, текущий F1=75.95
# [val:Greedy] обработано 16000 строк, текущий F1=75.83
# [val:Greedy] обработано 18000 строк, текущий F1=76.52
# [val:Greedy] обработано 20000 строк, текущий F1=77.29
# [val:Greedy] обработано 22000 строк, текущий F1=77.49
# [val:Greedy] обработано 24000 строк, текущий F1=77.46
# [val:Greedy] обработано 26000 строк, текущий F1=77.15
# [val:Greedy] обработано 28000 строк, текущий F1=76.95
# [val:Greedy] обработано 30000 строк, текущий F1=76.75
# [val:Greedy] обработано 32000 строк, текущий F1=76.57
# [val:Greedy] обработано 34000 строк, текущий F1=76.43
# [val:Greedy] обработано 36000 строк, текущий F1=76.29
# [val:Greedy] обработано 38000 строк, текущий F1=76.25
# [val:Greedy] обработано 40000 строк, текущий F1=76.14
# [val:Greedy] обработано 42000 строк, текущий F1=76.09
# [val:Greedy] обработано 44000 строк, текущий F1=76.08
# [val:Greedy] обработано 46000 строк, текущий F1=76.02
# [val:Greedy] обработано 48000 строк, текущий F1=75.94
# [val:Greedy] обработано 50000 строк, текущий F1=75.89
# [val:Greedy] обработано 52000 строк, текущий F1=75.86
# [val:Greedy] обработано 54000 строк, текущий F1=75.86
# [val:Greedy] обработано 56000 строк, текущий F1=75.80
# [val:Greedy] обработано 58000 строк, текущий F1=75.76
# [val:Greedy] обработано 60000 строк, текущий F1=75.72
# [val:Greedy] обработано 62000 строк, текущий F1=75.72
# [val:Greedy] обработано 64000 строк, текущий F1=75.70
# [val:Greedy] обработано 66000 строк, текущий F1=75.71
# [val:Greedy] обработано 68000 строк, текущий F1=75.70
# [val:Greedy] обработано 70000 строк, текущий F1=75.65
# [val:Greedy] обработано 72000 строк, текущий F1=75.64
# [val:Greedy] обработано 74000 строк, текущий F1=75.63
# [val:Greedy] обработано 76000 строк, текущий F1=75.61
# [val:Greedy] обработано 78000 строк, текущий F1=75.62
# [val:Greedy] обработано 80000 строк, текущий F1=75.63
# [val:Greedy] обработано 82000 строк, текущий F1=75.63
# [val:Greedy] обработано 84000 строк, текущий F1=75.65
# [val:Greedy] обработано 86000 строк, текущий F1=75.65
# [val:Greedy] обработано 88000 строк, текущий F1=75.66
# [val:Greedy] обработано 90000 строк, текущий F1=75.67
# [val:Greedy] обработано 92000 строк, текущий F1=75.66
# [val:Greedy] обработано 94000 строк, текущий F1=75.67
# [val:Greedy] обработано 96000 строк, текущий F1=75.67
# [val:Greedy] обработано 98000 строк, текущий F1=75.68
# [val:Greedy] обработано 100000 строк, текущий F1=75.66
# [val:Greedy] обработано 102000 строк, текущий F1=75.65
# [val:Greedy] обработано 104000 строк, текущий F1=75.66
# [val:Greedy] обработано 106000 строк, текущий F1=75.65
# [val:Greedy] обработано 108000 строк, текущий F1=75.64
# [val:Greedy] обработано 110000 строк, текущий F1=75.65
# [val:Greedy] обработано 112000 строк, текущий F1=75.64
# [val:Greedy] обработано 114000 строк, текущий F1=75.67
# [val:Greedy] обработано 116000 строк, текущий F1=75.66
# [val:Greedy] обработано 118000 строк, текущий F1=75.66
# [val:Greedy] обработано 120000 строк, текущий F1=75.64
# [val:Greedy] обработано 122000 строк, текущий F1=75.61
# [val:Greedy] обработано 124000 строк, текущий F1=75.61
# [val:Greedy] обработано 126000 строк, текущий F1=75.60
# [val:Greedy] обработано 128000 строк, текущий F1=75.60
# [val:Greedy] обработано 130000 строк, текущий F1=75.59
# [val:Greedy] обработано 132000 строк, текущий F1=75.58
# [val:Greedy] обработано 134000 строк, текущий F1=75.62
# [val:Greedy] обработано 136000 строк, текущий F1=75.61
# [val:Greedy] обработано 138000 строк, текущий F1=75.62
# [val:Greedy] обработано 140000 строк, текущий F1=75.61
# [val:Greedy] обработано 142000 строк, текущий F1=75.61
# [val:Greedy] обработано 144000 строк, текущий F1=75.61
# [val:Greedy] обработано 146000 строк, текущий F1=75.62
# [val:Greedy] обработано 148000 строк, текущий F1=75.60
# [val:Greedy] обработано 150000 строк, текущий F1=75.59
# [val:Greedy] обработано 152000 строк, текущий F1=75.60
# [val:Greedy] обработано 154000 строк, текущий F1=75.59
# [val:Greedy] обработано 156000 строк, текущий F1=75.59
# [val:Greedy] обработано 158000 строк, текущий F1=75.60
# [val:Greedy] обработано 160000 строк, текущий F1=75.61
# [val:Greedy] обработано 162000 строк, текущий F1=75.64
# [val:Greedy] обработано 164000 строк, текущий F1=75.66
# [val:Greedy] обработано 166000 строк, текущий F1=75.67
# [val:Greedy] обработано 168000 строк, текущий F1=75.67
# [val:Greedy] обработано 170000 строк, текущий F1=75.65
# [val:Greedy] обработано 172000 строк, текущий F1=75.64
# [val:Greedy] обработано 174000 строк, текущий F1=75.65
# [val:Greedy] обработано 176000 строк, текущий F1=75.65
# [val:Greedy] обработано 178000 строк, текущий F1=75.64
# [val:Greedy] обработано 180000 строк, текущий F1=75.64
# [val:Greedy] обработано 182000 строк, текущий F1=75.64
# [val:Greedy] обработано 184000 строк, текущий F1=75.63
# [val:Greedy] обработано 186000 строк, текущий F1=75.63
# [val:Greedy] обработано 188000 строк, текущий F1=75.63
# [val:Greedy] обработано 190000 строк, текущий F1=75.63
# [val:Greedy] обработано 192000 строк, текущий F1=75.64
# [val:Greedy] обработано 194000 строк, текущий F1=75.65
# [val:Greedy] обработано 196000 строк, текущий F1=75.65
# [val:Greedy] обработано 198000 строк, текущий F1=75.66
# [val:Greedy] обработано 200000 строк, текущий F1=75.67
# [val:Greedy] обработано 202000 строк, текущий F1=75.67
# [val:Greedy] обработано 204000 строк, текущий F1=75.68
# [val:Greedy] обработано 206000 строк, текущий F1=75.68
# [val:Greedy] обработано 208000 строк, текущий F1=75.68
# [val:Greedy] обработано 210000 строк, текущий F1=75.69
# [val:Greedy] обработано 212000 строк, текущий F1=75.69
# [val:Greedy] обработано 214000 строк, текущий F1=75.69
# [val:Greedy] обработано 216000 строк, текущий F1=75.69
# [val:Greedy] обработано 218000 строк, текущий F1=75.69
# [val:Greedy] обработано 220000 строк, текущий F1=75.70
# [val:Greedy] обработано 222000 строк, текущий F1=75.71
# [val:Greedy] обработано 224000 строк, текущий F1=75.71
# [val:Greedy] обработано 226000 строк, текущий F1=75.71
# [val:Greedy] обработано 228000 строк, текущий F1=75.71
# [val:Greedy] обработано 230000 строк, текущий F1=75.72
# [val:Greedy] обработано 232000 строк, текущий F1=75.71
# [val:Greedy] обработано 234000 строк, текущий F1=75.71
# [val:Greedy] обработано 236000 строк, текущий F1=75.72
# [val:Greedy] обработано 238000 строк, текущий F1=75.72
# [val:Greedy] обработано 240000 строк, текущий F1=75.71
# [val:Greedy] обработано 242000 строк, текущий F1=75.71
# [val:Greedy] обработано 244000 строк, текущий F1=75.71
# [val:Greedy] обработано 246000 строк, текущий F1=75.71
# [val:Greedy] обработано 248000 строк, текущий F1=75.72
#
# [val:Greedy] Средний F1 по позициям: 75.72
# [сравнение] DP - Greedy: 1.67 пунктов

# %%
def restore_with_positions(text_no_spaces: str, positions: set[int]) -> str:
    chars = list(text_no_spaces)
    for pos in sorted(positions, reverse=True):
        if 0 <= pos <= len(chars):
            chars.insert(pos, " ")
    return "".join(chars)


shown = 0
for line in Path(VAL_PATH).open("r", encoding="utf-8"):
    rec = json.loads(line)
    text = rec["text_no_spaces"]
    gold = set(rec["boundaries"])
    pred, _ = dp_segment(text, alpha=ALPHA, beta=BETA, gamma=GAMMA, L=L_MAX)

    print("no_spaces:", text[:140])
    print("GOLD     :", restore_with_positions(text, gold)[:140])
    print("DP       :", restore_with_positions(text, pred)[:140])
    print("F1=", f1_per_string(gold, pred))
    print("---")
    shown += 1
    if shown >= 5:
        break
# Out:
# no_spaces: Литва́(),официальноеназвание—Лито́вскаяРеспу́блика()—государство,расположенноевСевернойЕвропе.
# GOLD     : Литва́ ( ), официальное название — Лито́вская Респу́блика ( ) — государство, расположенное в Северной Европе .
# DP       : Литва́ (), официальное на звание — Лито́вская Респу́блика () — государство, рас положенное в Северной Европе.
# F1= 0.8387096774193549
# ---
# no_spaces: Так,например,существуютсозвучныетопонимынатерриторииСловакии(Lytva)иРумынии(Litua),известныесXI—XIIвеков.
# GOLD     : Так, например, существуют созвучные топонимы на территории Словакии (Lytva) и Румынии (Litua), известные с XI—XII веков .
# DP       : Так, на пример, существ ую т созвучные топонимынатерритории Словакии (Lytva) и Румынии (Litua), известные с XI— XII веков.
# F1= 0.787878787878788
# ---
# no_spaces: Феодальноекняжество,поземлямкоторогопротекалаэтарека,современемзаняловедущееположениеиназваниебылораспространенонавсёгосударство.
# GOLD     : Феодальное княжество, по землям которого протекала эта река, со временем заняло ведущее положение и название было распространено на всё госу
# DP       : Феодальное кня жество, поземлямкоторого протекала этарека, со в ременем заняло ведущее положение и название былораспространенона всё государ
# F1= 0.7999999999999999
# ---
# no_spaces: озёр(1,5%территории),крупнейшееизкоторых—ДрукшяйнаграницеЛатвии,ЛитвыиБеларуси(площадь—44,8км2),самоеглубокое—Таурагнас(60,5м),самоедлинное—
# GOLD     : озёр (1,5 % территории), крупнейшее из которых — Друкшяй на границе Латвии, Литвы и Беларуси (площадь — 44,8 км2), самое глубокое — Таурагна
# DP       : озёр (1, 5 % территории), крупнейшее из которых — Друкшяй награнице Латвии, Литвы и Беларуси (площадь —44,8 км 2), самое глубокое — Таурагна
# F1= 0.8985507246376813
# ---
# no_spaces: ВXIV—началеXVвекахтерриторияВеликогокняжестваЛитовскогостремительноросла,восновномзасчётприсоединенияземельЗападнойРуси.
# GOLD     : В XIV — начале XV веках территория Великого княжества Литовского стремительно росла, в основном за счёт присоединения земель Западной Руси.
# DP       : В XIV— начале XV веках территория Великогокня жества Литовского стремительноросла, воснов ном за счёт присоединения земель За падной Руси.
# F1= 0.8108108108108109
# ---

# %% [markdown]
# ## Эвристики

# %%
# === ЭТАП 5. ЭВРИСТИКИ ВЫСОКОЙ ТОЧНОСТИ ДЛЯ ДОКРУТКИ ПОСЛЕ DP ===
# Требует: dp_segment(text) и LEXICON/LM/HASher/фичи уже определены (из Этапов 3–4).

import re
from typing import Set, Tuple, List

# 1) Набор единиц измерения (ваш "первый вариант" — без расширений)
UNITS = ["см", "мм", "м", "км", "кг", "г", "л", "мл", "дюйм", "дюйма", "дюймов",
         "gb", "mb", "tb", "гб", "мб", "тб"]
UNITS_RE = r"(?:%s)\b" % "|".join(map(re.escape, UNITS))

# 2) Белые списки «не делить внутри» (бренд+модель, GPU и т.п.)
_WHITELIST_PATTERNS = [
    r"(?:iphone|samsung|xiaomi|huawei|sony|nokia|poco|asus|lenovo|honor|pixel|oneplus)\d+[a-z]*",
    r"(?:rtx|gtx|rx)\d{3,4}[a-z]*",
    r"(?:arc)\d+",
    r"(?:s|mi|k)\d{1,3}[a-z]*",   # s23, mi14, k50, 12t и т.п.
]
WHITELIST = [re.compile(p, flags=re.IGNORECASE) for p in _WHITELIST_PATTERNS]

# 3) Пунктуация, где пробел «почти всегда уместен» ПОСЛЕ символа
# точку сознательно НЕ включаем (числа вида 2.3кг)
AFTER_PUNCT = set(",:;!?)]»")
# 4) Открывающие скобки/кавычки — пробел обычно НУЖЕН ПЕРЕД ними
BEFORE_OPEN = set("([«")


def _collect_whitelist_spans(text: str) -> List[Tuple[int, int]]:
    spans = []
    for rgx in WHITELIST:
        for m in rgx.finditer(text):
            spans.append(m.span())
    return spans


def _pos_in_spans(pos: int, spans: List[Tuple[int, int]]) -> bool:
    # Внутри матчинга (не на краю) — не ставим пробелы
    # span = [L, R), pos — разрез между pos-1 и pos
    for L, R in spans:
        if L < pos < R:
            return True
    return False


def _add_boundary_safe(n: int, pos: int, positions: Set[int]) -> None:
    if 0 < pos < n:
        positions.add(pos)


def apply_heuristics(text: str, base_positions: Set[int]) -> Set[int]:
    """
    text: компактная строка без пробелов
    base_positions: множество позиций (0-based), где DP решил ставить пробел
    Возвращает обновлённое множество позиций с учётом эвристик.
    """
    n = len(text)
    if n <= 1:
        return set()

    positions = set(base_positions)  # копия
    spans = _collect_whitelist_spans(text)

    # H1) Число + единица измерения: 27дюймов -> 27 дюймов, 512gb -> 512 gb
    # Ищем ...<digits>(<unit>)
    for m in re.finditer(r"(\d+)" + UNITS_RE, text, flags=re.IGNORECASE):
        unit_start = m.start(
            2) if m.lastindex and m.lastindex >= 2 else m.end(1)
        # Разрез ставим ПЕРЕД unit
        if not _pos_in_spans(unit_start, spans):
            _add_boundary_safe(n, unit_start, positions)

    # H2) Буква↔цифра и цифра↔буква — ставим пробел, если НЕ попадаем в белый список
    for pos in range(1, n):
        L, R = text[pos-1], text[pos]
        is_alpha_L = L.isalpha()
        is_alpha_R = R.isalpha()
        is_dig_L = L.isdigit()
        is_dig_R = R.isdigit()
        if (is_alpha_L and is_dig_R) or (is_dig_L and is_alpha_R):
            if not _pos_in_spans(pos, spans):
                _add_boundary_safe(n, pos, positions)

    # H3) Пунктуация: пробел ПОСЛЕ , : ; ! ? ) ] »
    for pos in range(1, n):
        L, R = text[pos-1], text[pos]
        if L in AFTER_PUNCT and (R.isalpha() or R.isdigit()):
            _add_boundary_safe(n, pos, positions)

    # H4) Открывающие скобки/кавычки: пробел ПЕРЕД ( [ «
    for pos in range(1, n):
        L, R = text[pos-1], text[pos]
        if R in BEFORE_OPEN and (L.isalpha() or L.isdigit()):
            _add_boundary_safe(n, pos, positions)

    # H5) Мини-санити: не даём пробел в начале/конце (и удалим очевидный мусор)
    positions = {p for p in positions if 0 < p < n}

    return positions

# --- Быстрая проверка эффекта эвристик на валидации ---


def f1_per_string(gold_set, pred_set):
    if not gold_set and not pred_set:
        return 1.0
    if not gold_set or not pred_set:
        return 0.0
    tp = len(gold_set & pred_set)
    fp = len(pred_set - gold_set)
    fn = len(gold_set - pred_set)
    if tp == 0:
        return 0.0
    prec = tp / (tp + fp)
    rec = tp / (tp + fn)
    return 2 * prec * rec / (prec + rec)


val_path = Path("prepared_corpus/val.jsonl")
f1s_dp, f1s_dp_h = [], []
checked = 0
for line in val_path.open("r", encoding="utf-8"):
    rec = json.loads(line)
    t = rec["text_no_spaces"]
    gold = set(rec["boundaries"])
    pos_dp, _ = dp_segment(t)                 # DP без эвристик
    pos_h = apply_heuristics(t, pos_dp)       # DP + эвристики
    f1s_dp.append(f1_per_string(gold, pos_dp))
    f1s_dp_h.append(f1_per_string(gold, pos_h))
    checked += 1
    if checked % 2000 == 0:
        print(
            f"[val:heur] {checked} строк — DP={np.mean(f1s_dp)*100:.2f}, DP+H={np.mean(f1s_dp_h)*100:.2f}")

print(
    f"\n[val:heur] Итог по {checked} строкам — DP={np.mean(f1s_dp)*100:.2f}, DP+H={np.mean(f1s_dp_h)*100:.2f}")
# Out:
# [val:heur] 2000 строк — DP=76.14, DP+H=76.15
# [val:heur] 4000 строк — DP=76.93, DP+H=77.03
# [val:heur] 6000 строк — DP=77.44, DP+H=77.58
# [val:heur] 8000 строк — DP=77.82, DP+H=77.98
# [val:heur] 10000 строк — DP=78.18, DP+H=78.33
# [val:heur] 12000 строк — DP=77.83, DP+H=77.98
# [val:heur] 14000 строк — DP=77.84, DP+H=77.99
# [val:heur] 16000 строк — DP=77.69, DP+H=77.84
# [val:heur] 18000 строк — DP=78.34, DP+H=78.50
# [val:heur] 20000 строк — DP=79.11, DP+H=79.27
# [val:heur] 22000 строк — DP=79.29, DP+H=79.45
# [val:heur] 24000 строк — DP=79.22, DP+H=79.38
# [val:heur] 26000 строк — DP=78.92, DP+H=79.08
# [val:heur] 28000 строк — DP=78.74, DP+H=78.88
# [val:heur] 30000 строк — DP=78.52, DP+H=78.69
# [val:heur] 32000 строк — DP=78.34, DP+H=78.50
# [val:heur] 34000 строк — DP=78.19, DP+H=78.36
# [val:heur] 36000 строк — DP=78.05, DP+H=78.23
# [val:heur] 38000 строк — DP=78.01, DP+H=78.19
# [val:heur] 40000 строк — DP=77.90, DP+H=78.07
# [val:heur] 42000 строк — DP=77.83, DP+H=78.00
# [val:heur] 44000 строк — DP=77.81, DP+H=77.98
# [val:heur] 46000 строк — DP=77.75, DP+H=77.92
# [val:heur] 48000 строк — DP=77.68, DP+H=77.84
# [val:heur] 50000 строк — DP=77.62, DP+H=77.78
# [val:heur] 52000 строк — DP=77.58, DP+H=77.75
# [val:heur] 54000 строк — DP=77.58, DP+H=77.74
# [val:heur] 56000 строк — DP=77.51, DP+H=77.66
# [val:heur] 58000 строк — DP=77.46, DP+H=77.62
# [val:heur] 60000 строк — DP=77.42, DP+H=77.58
# [val:heur] 62000 строк — DP=77.42, DP+H=77.58
# [val:heur] 64000 строк — DP=77.40, DP+H=77.56
# [val:heur] 66000 строк — DP=77.40, DP+H=77.57
# [val:heur] 68000 строк — DP=77.38, DP+H=77.55
# [val:heur] 70000 строк — DP=77.33, DP+H=77.50
# [val:heur] 72000 строк — DP=77.32, DP+H=77.49
# [val:heur] 74000 строк — DP=77.31, DP+H=77.49
# [val:heur] 76000 строк — DP=77.30, DP+H=77.48
# [val:heur] 78000 строк — DP=77.31, DP+H=77.49
# [val:heur] 80000 строк — DP=77.32, DP+H=77.49
# [val:heur] 82000 строк — DP=77.32, DP+H=77.49
# [val:heur] 84000 строк — DP=77.34, DP+H=77.51
# [val:heur] 86000 строк — DP=77.34, DP+H=77.52
# [val:heur] 88000 строк — DP=77.34, DP+H=77.52
# [val:heur] 90000 строк — DP=77.34, DP+H=77.52
# [val:heur] 92000 строк — DP=77.33, DP+H=77.51
# [val:heur] 94000 строк — DP=77.35, DP+H=77.53
# [val:heur] 96000 строк — DP=77.34, DP+H=77.52
# [val:heur] 98000 строк — DP=77.36, DP+H=77.54
# [val:heur] 100000 строк — DP=77.34, DP+H=77.53
# [val:heur] 102000 строк — DP=77.34, DP+H=77.52
# [val:heur] 104000 строк — DP=77.35, DP+H=77.53
# [val:heur] 106000 строк — DP=77.33, DP+H=77.51
# [val:heur] 108000 строк — DP=77.32, DP+H=77.51
# [val:heur] 110000 строк — DP=77.33, DP+H=77.52
# [val:heur] 112000 строк — DP=77.33, DP+H=77.52
# [val:heur] 114000 строк — DP=77.36, DP+H=77.55
# [val:heur] 116000 строк — DP=77.35, DP+H=77.54
# [val:heur] 118000 строк — DP=77.35, DP+H=77.54
# [val:heur] 120000 строк — DP=77.34, DP+H=77.53
# [val:heur] 122000 строк — DP=77.31, DP+H=77.50
# [val:heur] 124000 строк — DP=77.30, DP+H=77.49
# [val:heur] 126000 строк — DP=77.29, DP+H=77.47
# [val:heur] 128000 строк — DP=77.29, DP+H=77.47
# [val:heur] 130000 строк — DP=77.28, DP+H=77.49
# [val:heur] 132000 строк — DP=77.27, DP+H=77.47
# [val:heur] 134000 строк — DP=77.31, DP+H=77.52
# [val:heur] 136000 строк — DP=77.30, DP+H=77.50
# [val:heur] 138000 строк — DP=77.31, DP+H=77.51
# [val:heur] 140000 строк — DP=77.29, DP+H=77.49
# [val:heur] 142000 строк — DP=77.30, DP+H=77.50
# [val:heur] 144000 строк — DP=77.29, DP+H=77.49
# [val:heur] 146000 строк — DP=77.30, DP+H=77.50
# [val:heur] 148000 строк — DP=77.29, DP+H=77.49
# [val:heur] 150000 строк — DP=77.28, DP+H=77.49
# [val:heur] 152000 строк — DP=77.29, DP+H=77.50
# [val:heur] 154000 строк — DP=77.29, DP+H=77.49
# [val:heur] 156000 строк — DP=77.28, DP+H=77.48
# [val:heur] 158000 строк — DP=77.28, DP+H=77.48
# [val:heur] 160000 строк — DP=77.29, DP+H=77.49
# [val:heur] 162000 строк — DP=77.31, DP+H=77.51
# [val:heur] 164000 строк — DP=77.33, DP+H=77.52
# [val:heur] 166000 строк — DP=77.34, DP+H=77.53
# [val:heur] 168000 строк — DP=77.34, DP+H=77.53
# [val:heur] 170000 строк — DP=77.32, DP+H=77.51
# [val:heur] 172000 строк — DP=77.32, DP+H=77.50
# [val:heur] 174000 строк — DP=77.33, DP+H=77.51
# [val:heur] 176000 строк — DP=77.33, DP+H=77.51
# [val:heur] 178000 строк — DP=77.32, DP+H=77.51
# [val:heur] 180000 строк — DP=77.32, DP+H=77.51
# [val:heur] 182000 строк — DP=77.32, DP+H=77.50
# [val:heur] 184000 строк — DP=77.32, DP+H=77.50
# [val:heur] 186000 строк — DP=77.31, DP+H=77.49
# [val:heur] 188000 строк — DP=77.32, DP+H=77.49
# [val:heur] 190000 строк — DP=77.32, DP+H=77.49
# [val:heur] 192000 строк — DP=77.32, DP+H=77.50
# [val:heur] 194000 строк — DP=77.33, DP+H=77.50
# [val:heur] 196000 строк — DP=77.33, DP+H=77.51
# [val:heur] 198000 строк — DP=77.34, DP+H=77.52
# [val:heur] 200000 строк — DP=77.34, DP+H=77.52
# [val:heur] 202000 строк — DP=77.35, DP+H=77.52
# [val:heur] 204000 строк — DP=77.35, DP+H=77.53
# [val:heur] 206000 строк — DP=77.35, DP+H=77.53
# [val:heur] 208000 строк — DP=77.36, DP+H=77.54
# [val:heur] 210000 строк — DP=77.37, DP+H=77.54
# [val:heur] 212000 строк — DP=77.36, DP+H=77.54
# [val:heur] 214000 строк — DP=77.37, DP+H=77.55
# [val:heur] 216000 строк — DP=77.37, DP+H=77.55
# [val:heur] 218000 строк — DP=77.37, DP+H=77.55
# [val:heur] 220000 строк — DP=77.38, DP+H=77.56
# [val:heur] 222000 строк — DP=77.38, DP+H=77.56
# [val:heur] 224000 строк — DP=77.38, DP+H=77.56
# [val:heur] 226000 строк — DP=77.39, DP+H=77.56
# [val:heur] 228000 строк — DP=77.39, DP+H=77.56
# [val:heur] 230000 строк — DP=77.39, DP+H=77.57
# [val:heur] 232000 строк — DP=77.38, DP+H=77.56
# [val:heur] 234000 строк — DP=77.39, DP+H=77.57
# [val:heur] 236000 строк — DP=77.40, DP+H=77.58
# [val:heur] 238000 строк — DP=77.39, DP+H=77.57
# [val:heur] 240000 строк — DP=77.38, DP+H=77.56
# [val:heur] 242000 строк — DP=77.38, DP+H=77.56
# [val:heur] 244000 строк — DP=77.38, DP+H=77.56
# [val:heur] 246000 строк — DP=77.38, DP+H=77.56
# [val:heur] 248000 строк — DP=77.39, DP+H=77.57
#
# [val:heur] Итог по 249736 строкам — DP=77.39, DP+H=77.57

# %% [markdown]
# ## Submit

# %%
# === Сабмит в формате: id, predicted_positions (JSON-строка вида "[5, 8, 13]") ===
import json
import pandas as pd
from pathlib import Path

INPUT_PATH = Path("dataset_1937770_3.txt")      # твой файл для инференса
OUTPUT_PATH = Path("submission.csv")

# берём лоадер из ранних ячеек; если его нет — вот минимальная версия:


def load_task_data_txt(path: Path) -> pd.DataFrame:
    raw = path.read_text(encoding="utf-8-sig").splitlines()
    assert raw and raw[0].strip(
    ) == "id,text_no_spaces", "Ожидается заголовок 'id,text_no_spaces'"
    rows = []
    for i, line in enumerate(raw[1:], start=2):
        if not line:
            continue
        left, right = line.split(",", 1)
        rows.append((left, right))
    df = pd.DataFrame(rows, columns=["id", "text_no_spaces"])
    df["id"] = df["id"].astype(str)
    df["text_no_spaces"] = df["text_no_spaces"].astype(str)
    return df

# форматирование позиций: JSON с пробелами (как в примере)


def format_positions_json(pos_set) -> str:
    arr = sorted(int(p) for p in pos_set)
    # даёт "[1, 4, 9]" со пробелами после запятой
    return json.dumps(arr, ensure_ascii=False)


# --- инференс для всего файла ---
task = load_task_data_txt(INPUT_PATH)

pred_col = []
for i, text in enumerate(task["text_no_spaces"].tolist(), 1):
    # твоя функция, которая возвращает множество позиций:
    # pos = infer_positions_for_row(text)  # если уже определена
    # Если она не определена в этом ноутбуке, подключи из Этапа 4–5:
    pos_dp, _ = dp_segment(text)                 # DP
    pos = apply_heuristics(text, pos_dp)         # эвристики поверх DP

    pred_col.append(format_positions_json(pos))
    if i % 500 == 0:
        print(f"[infer] обработано: {i}")

submission = task[["id", "text_no_spaces"]].copy()
submission["predicted_positions"] = pred_col

submission.to_csv(OUTPUT_PATH, index=False)
print("Сохранено:", OUTPUT_PATH.resolve())

# Быстрый просмотр
display(submission.head(5))
print(submission.dtypes)
# Out:
# [infer] обработано: 500
# [infer] обработано: 1000
# Сохранено: /Users/strafe/VSCode-Projects/Avito-Test/submission.csv
#   id                 text_no_spaces predicted_positions
# 0  0                куплюайфон14про         [7, 10, 12]
# 1  1             ищудомвПодмосковье              [6, 7]
# 2  2  сдаюквартирусмебельюитехникой             [5, 21]
# 3  3     новыйдивандоставканедорого     [5, 16, 18, 20]
# 4  4                отдамдаромкошку          [2, 5, 10]
# id                     object
# text_no_spaces         object
# predicted_positions    object
# dtype: object
